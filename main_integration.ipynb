# %%
from itertools import product,combinations
import numpy as np
import pandas as pd
from ADRprofilePrediction import Pairs2Mat,evaluation3
from APPFC import completion
from Models import loadHyperpar
import seaborn as sns 
import matplotlib.pylab as plt
from matplotlib.ticker import MultipleLocator
import matplotlib.patheffects as path_effects
import json
import pingouin as pg
from functools import reduce

# %%
class NpEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, np.ndarray):
            return obj.tolist()
        else:
            return super(NpEncoder, self).default(obj)

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 0.24.2

# %%
SEs_name = "SIDER"
metrice = "mse"

# %%
features_dict = {
    "target":Pairs2Mat(path="data/drug_target.tsv",colname1="0",colname2="1"),
    "enzyme":Pairs2Mat(path="data/drug_enzyme.tsv",colname1="0",colname2="1"),
    "Chem":pd.read_csv("data/drug_chemsfp.tsv",sep = "\t",header=0,index_col=0),
    "DGI":Pairs2Mat(path="data/interactions.tsv",colname1="drug_claim_name",colname2="gene_name"),
    "transporter":Pairs2Mat(path="data/drug_transporter.tsv",colname1="0",colname2="1"),
    "pathway":Pairs2Mat(path="data/drug_pathway.tsv",colname1="0",colname2="1"),
    "indication":Pairs2Mat(path="data/drug_indication.tsv",colname1="1_x",colname2="6")
}

# %%
filter = "all"
SEs = {}
if filter == "all":
    SIDER = Pairs2Mat(path="data/drug_se.tsv",colname1="1_x",colname2="5")
    column_sums = np.sum(SIDER, axis=0)
    SEs["SIDER"] = SIDER.loc[:, (column_sums >= 5)]

    OFFSIDES = Pairs2Mat(path="data/OFFSIDES.csv",colname1="drug_concept_name",colname2="condition_concept_name",sep = ",")
    column_sums = np.sum(OFFSIDES, axis=0)
    SEs["OFFSIDES"] = OFFSIDES.loc[:, column_sums >= 5]
elif filter == "rare":
    SIDER = Pairs2Mat(path="data/drug_se.tsv",colname1="1_x",colname2="5")
    column_sums = np.sum(SIDER, axis=0)
    SEs["SIDER"] = SIDER.loc[:, (column_sums < 50)]

    OFFSIDES = Pairs2Mat(path="data/OFFSIDES.csv",colname1="drug_concept_name",colname2="condition_concept_name",sep = ",")
    column_sums = np.sum(OFFSIDES, axis=0)
    SEs["OFFSIDES"] = OFFSIDES.loc[:, column_sums < 50]

# %%
SEs["SIDER"].shape
# Out:
# (1344, 2556)

# %%
SEs["OFFSIDES"].shape
# Out:
# (2730, 12750)

# %%
df_dict = features_dict
intersection_indices = df_dict['target'].index
for df_name, df in df_dict.items():
    intersection_indices = intersection_indices.intersection(df.index)
intersection_indices = intersection_indices.tolist()
print("Intersection indices:", intersection_indices)
print("Size of intersection set", len(intersection_indices))
# Out:
# Intersection indices: ['ACETAMINOPHEN', 'ACETAZOLAMIDE', 'ALFENTANIL', 'ALLOPURINOL', 'AMANTADINE', 'AMIODARONE', 'AMITRIPTYLINE', 'AMLODIPINE', 'AMOXICILLIN', 'AMPRENAVIR', 'ANASTROZOLE', 'APIXABAN', 'APOMORPHINE', 'ARIPIPRAZOLE', 'ATAZANAVIR', 'ATENOLOL', 'AZATHIOPRINE', 'AZELASTINE', 'AZITHROMYCIN', 'BENAZEPRIL', 'BENZOCAINE', 'BEPRIDIL', 'BETAMETHASONE', 'BEZAFIBRATE', 'BICALUTAMIDE', 'BISOPROLOL', 'BOSENTAN', 'BOSUTINIB', 'BROMOCRIPTINE', 'BUMETANIDE', 'BUPRENORPHINE', 'BUSPIRONE', 'CABERGOLINE', 'CANAGLIFLOZIN', 'CANDESARTAN', 'CARBAMAZEPINE', 'CARBOPLATIN', 'CARVEDILOL', 'CEFACLOR', 'CEFAZOLIN', 'CEFTRIAXONE', 'CELECOXIB', 'CERIVASTATIN', 'CHLORAMBUCIL', 'CHLORPROMAZINE', 'CHLORPROPAMIDE', 'CIDOFOVIR', 'CIMETIDINE', 'CINOXACIN', 'CIPROFLOXACIN', 'CISPLATIN', 'CITALOPRAM', 'CLADRIBINE', 'CLARITHROMYCIN', 'CLOBAZAM', 'CLOMIPRAMINE', 'CLONIDINE', 'CLOPIDOGREL', 'CLOTRIMAZOLE', 'CODEINE', 'COLCHICINE', 'CRIZOTINIB', 'CYPROHEPTADINE', 'DAPAGLIFLOZIN', 'DARUNAVIR', 'DASATINIB', 'DESIPRAMINE', 'DEXAMETHASONE', 'DIAZEPAM', 'DICLOFENAC', 'DIFLUNISAL', 'DIGOXIN', 'DIHYDROERGOTAMINE', 'DILTIAZEM', 'DIPHENHYDRAMINE', 'DISOPYRAMIDE', 'DOCETAXEL', 'DOFETILIDE', 'DOLUTEGRAVIR', 'DOMPERIDONE', 'DONEPEZIL', 'DOPAMINE', 'DOXAZOSIN', 'DOXORUBICIN', 'DRONEDARONE', 'DULOXETINE', 'EFAVIRENZ', 'ELETRIPTAN', 'EMTRICITABINE', 'EPINASTINE', 'EPINEPHRINE', 'ERGOTAMINE', 'ERLOTINIB', 'ERYTHROMYCIN', 'ESOMEPRAZOLE', 'ESTRADIOL', 'ESTRAMUSTINE', 'ESTRONE', 'ETODOLAC', 'ETOPOSIDE', 'ETRAVIRINE', 'EVEROLIMUS', 'EZETIMIBE', 'FAMOTIDINE', 'FELODIPINE', 'FENOFIBRATE', 'FENTANYL', 'FLECAINIDE', 'FLUCLOXACILLIN', 'FLUCONAZOLE', 'FLUOXETINE', 'FLUPHENAZINE', 'FLURAZEPAM', 'FLURBIPROFEN', 'FLUTAMIDE', 'FLUVASTATIN', 'FLUVOXAMINE', 'FUROSEMIDE', 'GABAPENTIN', 'GALANTAMINE', 'GEFITINIB', 'GEMCITABINE', 'GLIMEPIRIDE', 'GLIPIZIDE', 'GUANFACINE', 'HALOPERIDOL', 'HYDROCORTISONE', 'HYDROXYUREA', 'HYDROXYZINE', 'IBUPROFEN', 'IDARUBICIN', 'IMATINIB', 'IMIPRAMINE', 'INDINAVIR', 'INDOMETHACIN', 'IRINOTECAN', 'ISRADIPINE', 'ITRACONAZOLE', 'KETOCONAZOLE', 'KETOPROFEN', 'LABETALOL', 'LAMIVUDINE', 'LAMOTRIGINE', 'LANSOPRAZOLE', 'LAPATINIB', 'LATANOPROST', 'LEFLUNOMIDE', 'LETROZOLE', 'LIDOCAINE', 'LINAGLIPTIN', 'LORATADINE', 'LOSARTAN', 'LOVASTATIN', 'MEFLOQUINE', 'MELOXICAM', 'MEMANTINE', 'MEPYRAMINE', 'METHADONE', 'METHOTREXATE', 'METHYLPREDNISOLONE', 'METHYLTESTOSTERONE', 'METOCLOPRAMIDE', 'METOPROLOL', 'METRONIDAZOLE', 'MICONAZOLE', 'MIDAZOLAM', 'MIFEPRISTONE', 'MIRTAZAPINE', 'MITOXANTRONE', 'MONTELUKAST', 'MORPHINE', 'NALOXONE', 'NAPROXEN', 'NATEGLINIDE', 'NEFAZODONE', 'NELFINAVIR', 'NEVIRAPINE', 'NICARDIPINE', 'NIFEDIPINE', 'NILOTINIB', 'NISOLDIPINE', 'NITROFURANTOIN', 'NIZATIDINE', 'NORFLOXACIN', 'NORTRIPTYLINE', 'OFLOXACIN', 'OLOPATADINE', 'OMEPRAZOLE', 'OSELTAMIVIR', 'OXCARBAZEPINE', 'PACLITAXEL', 'PANCURONIUM', 'PANTOPRAZOLE', 'PAROXETINE', 'PAZOPANIB', 'PEMETREXED', 'PHENOBARBITAL', 'PHENYTOIN', 'PIMOZIDE', 'PINDOLOL', 'PIOGLITAZONE', 'PITAVASTATIN', 'POSACONAZOLE', 'PREDNISOLONE', 'PREDNISONE', 'PRIMAQUINE', 'PRIMIDONE', 'PROCAINAMIDE', 'PROGESTERONE', 'PROMETHAZINE', 'PROPAFENONE', 'PROPRANOLOL', 'QUETIAPINE', 'QUINAPRIL', 'QUINIDINE', 'RABEPRAZOLE', 'RALOXIFENE', 'RAMIPRIL', 'RANITIDINE', 'REBOXETINE', 'REPAGLINIDE', 'RIBAVIRIN', 'RIFABUTIN', 'RILPIVIRINE', 'RISPERIDONE', 'RITONAVIR', 'RIVAROXABAN', 'ROFECOXIB', 'ROSIGLITAZONE', 'ROSUVASTATIN', 'SAQUINAVIR', 'SAXAGLIPTIN', 'SERTRALINE', 'SIMVASTATIN', 'SITAGLIPTIN', 'SORAFENIB', 'SPARFLOXACIN', 'SPIRONOLACTONE', 'SULFAMETHOXAZOLE', 'SULINDAC', 'SUMATRIPTAN', 'SUNITINIB', 'TACROLIMUS', 'TAMOXIFEN', 'TELITHROMYCIN', 'TELMISARTAN', 'TEMSIROLIMUS', 'TENIPOSIDE', 'TENOFOVIR', 'TENOXICAM', 'TERBINAFINE', 'TESTOSTERONE', 'THIOTHIXENE', 'TIMOLOL', 'TIOTROPIUM', 'TOLBUTAMIDE', 'TOLMETIN', 'TOPIRAMATE', 'TORASEMIDE', 'TOREMIFENE', 'TRAZODONE', 'TRIFLUOPERAZINE', 'TRIMIPRAMINE', 'TROGLITAZONE', 'VALSARTAN', 'VANDETANIB', 'VENLAFAXINE', 'VERAPAMIL', 'VIGABATRIN', 'VINBLASTINE', 'VINCRISTINE', 'ZAFIRLUKAST', 'ZALCITABINE', ...
# Size of intersection set 276

# %%
features_names = ["target", "enzyme", "Chem", "DGI", "transporter", "pathway", "indication"]
# SEs_names = ["SIDER", "OFFSIDES"]
# methods = ["SKR", "KR", "KRR", "Naive", "LNSM_RLN", "LNSM_jaccard", "VKR"]
methods = ["SKR", "KRR", "VKR", "Naive", "LNSM_RLN", "LNSM_jaccard"]
# methods = ["SKR", "KR", "KRR", "Naive", "LNSM_RLN", "LNSM_jaccard", "VKR", "SVM", "OCCA", "SCCA", "RF", "BRF"]
tuning_metrices=["AUROC", "AUPR", "AUROCperdrug", "AUPRperdrug"]
metrice_names = ["AUPR+AUROC", "AUPR+AUROCperdrug", "AUROC", "AUPR", "AUROCperdrug", "AUPRperdrug"]

# %%
A = 10**np.arange(-2, 3, 1, dtype=float)
C = np.arange(5, 205, 50, dtype=int)
C2 = np.arange(0.1, 1, 0.1, dtype=float)
all_hyperparlist = {
    "MKRR":[A,A,C2],
    "TNMF":[C],
    "TWNMF":[C]
}

# %%
fhyperpars = {}
fhyperpars["nested_cv"] = {}
fhyperpars["cv"] = {}
fhyperparsOut = {}
fhyperparsOut["nested_cv"] = {}
fhyperparsOut["cv"] = {}
fresults = {}
fresults["nested_cv"] = {}
fresults["cv"] = {}

# %%
method = "TNMF"
validation = "completion"
hyperparList = loadHyperpar(*all_hyperparlist[method],method_option=method)
features_new = completion(Y=SEs[SEs_name], X=features_dict,method_option=method,tuning_metrice=metrice,hyperparList=hyperparList,hyperparfixed=(105,),Validation=validation,n_jobs=1)
# Out:
# The TNMF requires hyperparameter k
# common drugs chosen to be the test set:  set()
# TNMF starts:
# TNMF ends:

# %%
hyperpars = {}
hyperpars["nested_cv"] = {}
hyperpars["cv"] = {}
hyperparsOut = {}
hyperparsOut["nested_cv"] = {}
hyperparsOut["cv"] = {}
results = {}
results["nested_cv"] = {}
results["cv"] = {}

# %%
# selected_features = ["DGI", "Chem"]
# selected_features = ["target", "transporter"]
selected_features = list(combinations(list(features_dict.keys()), 2))

# %%
len(selected_features)
# Out:
# 21

# %%
for i in range(len(selected_features)):
    print(selected_features[i])
    features_dict_subset = {key: features_dict[key] for key in selected_features[i]}
    features_new_subset = {key: features_new[key] for key in selected_features[i]}
    method = "MKRR"
    metrice = "AUPR"
    validation = "nested_cv"
    hyperparsOut[validation][method] = {}
    results[validation][method] = {}
    hyperparsOut[validation][method]["noAPPFC"] = {}
    results[validation][method]["noAPPFC"] = {}
    hyperparsOut[validation][method]["APPFC"] = {}
    results[validation][method]["APPFC"] = {}
    print("without APPFC")
    hyperparList = loadHyperpar(*all_hyperparlist[method],method_option=method)
    results[validation][method]["noAPPFC"], hyperparsOut[validation][method]["APPFC"] = evaluation3(Y=SEs[SEs_name], X=features_dict_subset, X2=features_dict_subset, method_option=method,tuning_metrice=metrice,hyperparList=hyperparList,Validation=validation,n_jobs=10)
    print("with APPFC")
    hyperparList = loadHyperpar(*all_hyperparlist[method],method_option=method)
    results[validation][method]["APPFC"], hyperparsOut[validation][method]["APPFC"] = evaluation3(Y=SEs[SEs_name], X=features_dict_subset, X2=features_new_subset, method_option=method,tuning_metrice=metrice,hyperparList=hyperparList,Validation=validation,n_jobs=10)
    method = "MKRR"
    metrice = "AUPR"
    validation = "cv"
    hyperparsOut[validation][method] = {}
    results[validation][method] = {}
    hyperparsOut[validation][method]["noAPPFC"] = {}
    results[validation][method]["noAPPFC"] = {}
    hyperparsOut[validation][method]["APPFC"] = {}
    results[validation][method]["APPFC"] = {}
    print("without APPFC")
    hyperparList = loadHyperpar(*all_hyperparlist[method],method_option=method)
    results[validation][method]["noAPPFC"], hyperparsOut[validation][method]["APPFC"] = evaluation3(Y=SEs[SEs_name], X=features_dict_subset, X2=features_dict_subset, method_option=method,tuning_metrice=metrice,hyperparList=hyperparList,Validation=validation,n_jobs=10)
    print("with APPFC")
    hyperparList = loadHyperpar(*all_hyperparlist[method],method_option=method)
    results[validation][method]["APPFC"], hyperparsOut[validation][method]["APPFC"] = evaluation3(Y=SEs[SEs_name], X=features_dict_subset, X2=features_new_subset, method_option=method,tuning_metrice=metrice,hyperparList=hyperparList,Validation=validation,n_jobs=10)

    print('integration results:')
    df = pd.DataFrame()
    for m, mes in results["nested_cv"]["MKRR"].items():
        for me, scores in mes.items():
            temp_df = pd.DataFrame({
                'method': m,
                'metric': me,
                "score": scores
            })
            df = pd.concat([df, temp_df], ignore_index=True)
    
    metrice_names = ["AUPR+AUROC", "AUPR+AUROCperdrug", "AUROC", "AUPR", "AUROCperdrug", "AUPRperdrug"]
    APPFC = ["APPFC", "noAPPFC"]
    df['method'] = pd.Categorical(df['method'], categories=APPFC, ordered=True)
    df['metric'] = pd.Categorical(df['metric'], categories=metrice_names, ordered=True)
    df2 = pd.pivot_table(df, values=['score'], index=["method"], aggfunc={'score': ["mean","std"]}, columns=["metric"])
    df3 = df2.sort_index(axis=1, level='metric').sort_index(level='feature')
    df3.to_excel(f'results/nested_cv_results_integration_{SEs_name}_{method}_{selected_features[i][0]}_{selected_features[i][1]}.xlsx')
    print(df3)
    df = pd.DataFrame()
    for m, mes in results["cv"]["MKRR"].items():
        for me, scores in mes.items():
            temp_df = pd.DataFrame({
                'method': m,
                'metric': me,
                "score": scores
            },index=["1"])
            df = pd.concat([df, temp_df], ignore_index=True)
    df['method'] = pd.Categorical(df['method'], categories=APPFC, ordered=True)
    df['metric'] = pd.Categorical(df['metric'], categories=metrice_names, ordered=True)
    df2 = pd.pivot_table(df, values=['score'], index=["method"], columns="metric")
    df2.to_excel(f'results/cv_results_integration_{SEs_name}_{method}_{selected_features[i][0]}_{selected_features[i][1]}.xlsx')
    print(df2)
# Out:
# ('target', 'enzyme')
# without APPFC
# The MKRR requires hyperparameter lambda, sigma_X
# ---------- nested cv start ----------
# Fold: 0
# number of hyperpars combination:  225
# first few training idx:  [20 23 28 29 31 36 39 42 44 45]
# first few testing idx:  [ 100  192  252  315  530  560  983 1170 1189 1266]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (10.0, 10.0, 0.1)
# AUPR: 0.39717999716760705
# AUPR for each fold: [0.37487083 0.37538756 0.42640776 0.41205384]
# --- tuning end ---
# target size: 104
# ------ best hyper pars:  (10.0, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.42749730937266806
# AUROCperdrug: 0.8808568572995166
# AUPR+AUROCperdrug: 1.3083541666721845
# AUPR: 0.38242306944912907
# AUROC: 0.8590692080245685
# AUPR+AUROC: 1.2414922774736976
# -----------
# Fold: 1
# number of hyperpars combination:  225
# first few training idx:  [20 29 36 39 42 44 49 51 54 56]
# first few testing idx:  [  31  128  312  333  446  565  871  885  951 1125]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (1.0, 10.0, 0.1)
# AUPR: 0.3966852259513178
# AUPR for each fold: [0.41127269 0.37411064 0.40205354 0.39930403]
# --- tuning end ---
# target size: 104
# ------ best hyper pars:  (1.0, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.4443782347868409
# AUROCperdrug: 0.8841518458250481
# AUPR+AUROCperdrug: 1.328530080611889
# AUPR: 0.3970423940974185
# AUROC: 0.85261393173333
# AUPR+AUROC: 1.2496563258307485
# -----------
# Fold: 2
# number of hyperpars combination:  225
# first few training idx:  [20 23 28 31 36 39 42 45 47 49]
# first few testing idx:  [ 180  334  351  395  455  682  919 1120 1270 1341]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (1.0, 10.0, 0.1)
# AUPR: 0.3954123965151516
# AUPR for each fold: [0.40441104 0.38604979 0.38935313 0.40183563]
# --- tuning end ---
# target size: 104
# ------ best hyper pars:  (1.0, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.4520373575017343
# AUROCperdrug: 0.883874234226997
# AUPR+AUROCperdrug: 1.3359115917287312
# AUPR: 0.40611391038194833
# AUROC: 0.8713159058074632
# AUPR+AUROC: 1.2774298161894115
# -----------
# Fold: 3
# number of hyperpars combination:  225
# first few training idx:  [20 23 28 29 31 39 44 45 47 49]
# first few testing idx:  [ 238  248  291  476  572  660  692  694  982 1326]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (1.0, 10.0, 0.1)
# AUPR: 0.3956258432786538
# AUPR for each fold: [0.37914064 0.38391974 0.40339702 0.41604597]
# --- tuning end ---
# target size: 104
# ------ best hyper pars:  (1.0, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.4535521414963679
# AUROCperdrug: 0.8871726844182019
# AUPR+AUROCperdrug: 1.3407248259145699
# AUPR: 0.4073146221148824
# AUROC: 0.8651200679582783
# AUPR+AUROC: 1.2724346900731607
# -----------
# Fold: 4
# number of hyperpars combination:  225
# first few training idx:  [23 28 29 31 36 42 44 45 47 49]
# first few testing idx:  [ 199  275  534  581  622  676  699 1019 1095 1207]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (1.0, 10.0, 0.1)
# AUPR: 0.3958367554105724
# AUPR for each fold: [0.40419766 0.36964699 0.37305185 0.43645052]
# --- tuning end ---
# target size: 104
# ------ best hyper pars:  (1.0, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.4385621401771267
# AUROCperdrug: 0.8815553687358407
# AUPR+AUROCperdrug: 1.3201175089129675
# AUPR: 0.39628704065537357
# AUROC: 0.8694076538873614
# AUPR+AUROC: 1.265694694542735
# -----------
# Mean AUPRperdrug: 0.4432054366669476, std: 0.009536645608124351
# Mean AUROCperdrug: 0.8835221981011209, std: 0.0022279540112932774
# Mean AUPR+AUROCperdrug: 1.3267276347680683, std: 0.011530770400607652
# Mean AUPR: 0.3978362073397504, std: 0.008932587428279052
# Mean AUROC: 0.8635053534822003, std: 0.006881157384782339
# Mean AUPR+AUROC: 1.261341560821951, std: 0.013648282066125143
# -----------
# with APPFC
# The MKRR requires hyperparameter lambda, sigma_X
# ---------- nested cv start ----------
# Fold: 0
# number of hyperpars combination:  225
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [ 100  192  252  315  530  560  983 1170 1189 1266]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.01, 10.0, 0.1)
# AUPR: 0.41894061235491076
# AUPR for each fold: [0.41192492 0.40023625 0.4443024  0.41929889]
# --- tuning end ---
# target size: 104
# ------ best hyper pars:  (0.01, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.4391302020727444
# AUROCperdrug: 0.8869853835130557
# AUPR+AUROCperdrug: 1.3261155855858
# AUPR: 0.4123123458313679
# AUROC: 0.8653979191147505
# AUPR+AUROC: 1.2777102649461183
# -----------
# Fold: 1
# number of hyperpars combination:  225
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [  31  128  312  333  446  565  871  885  951 1125]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.01, 10.0, 0.1)
# AUPR: 0.4169976253763276
# AUPR for each fold: [0.4247678  0.39657018 0.42087375 0.42577876]
# --- tuning end ---
# target size: 104
# ------ best hyper pars:  (0.01, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.4599183167938751
# AUROCperdrug: 0.892536957728886
# AUPR+AUROCperdrug: 1.3524552745227612
# AUPR: 0.44054830927461675
# AUROC: 0.8629827709910324
# AUPR+AUROC: 1.3035310802656492
# -----------
# Fold: 2
# number of hyperpars combination:  225
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [ 180  334  351  395  455  682  919 1120 1270 1341]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.01, 10.0, 0.1)
# AUPR: 0.4205460994536963
# AUPR for each fold: [0.42680569 0.40834583 0.42595262 0.42108026]
# --- tuning end ---
# target size: 104
# ------ best hyper pars:  (0.01, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.4633813854339512
# AUROCperdrug: 0.8903897878582191
# AUPR+AUROCperdrug: 1.3537711732921702
# AUPR: 0.4177455920680816
# AUROC: 0.8737457238801853
# AUPR+AUROC: 1.2914913159482668
# -----------
# Fold: 3
# number of hyperpars combination:  225
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [ 238  248  291  476  572  660  692  694  982 1326]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.01, 10.0, 0.1)
# AUPR: 0.41454069630686163
# AUPR for each fold: [0.40088835 0.41204162 0.42164714 0.42358568]
# --- tuning end ---
# target size: 104
# ------ best hyper pars:  (0.01, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.46704056717936177
# AUROCperdrug: 0.8945778879572202
# AUPR+AUROCperdrug: 1.361618455136582
# AUPR: 0.43558701666905514
# AUROC: 0.8731639236320214
# AUPR+AUROC: 1.3087509403010766
# -----------
# Fold: 4
# number of hyperpars combination:  225
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [ 199  275  534  581  622  676  699 1019 1095 1207]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.01, 10.0, 0.1)
# AUPR: 0.4208070049422978
# AUPR for each fold: [0.42858563 0.38958802 0.40516429 0.45989008]
# --- tuning end ---
# target size: 104
# ------ best hyper pars:  (0.01, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.45416860172751927
# AUROCperdrug: 0.8886260648426249
# AUPR+AUROCperdrug: 1.342794666570144
# AUPR: 0.42207357953998104
# AUROC: 0.8681712845919132
# AUPR+AUROC: 1.2902448641318942
# -----------
# Mean AUPRperdrug: 0.4567278146414903, std: 0.009767576076394339
# Mean AUROCperdrug: 0.8906232163800011, std: 0.002704764845229617
# Mean AUPR+AUROCperdrug: 1.3473510310214913, std: 0.012186349077895384
# Mean AUPR: 0.4256533686766205, std: 0.010713237881857627
# Mean AUROC: 0.8686923244419805, std: 0.004225059402969313
# Mean AUPR+AUROC: 1.294345693118601, std: 0.010895725963146766
# -----------
# without APPFC
# The MKRR requires hyperparameter lambda, sigma_X
# ---------- cv start ----------
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# best hyperpar: (1.0, 10.0, 0.1)
# AUPR: 0.39853273221935404
# AUPR for each fold: [0.38590569 0.39704239 0.40611391 0.40731462 0.39628704]
# --- tuning end ---
# target size: 169
# ------ best hyper pars:  (1.0, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.4788424435041385
# AUROCperdrug: 0.8814326169637164
# AUPR+AUROCperdrug: 1.3602750604678548
# AUPR: 0.43138747142614975
# AUROC: 0.8588551753899266
# AUPR+AUROC: 1.2902426468160764
# -----------
# with APPFC
# The MKRR requires hyperparameter lambda, sigma_X
# ---------- cv start ----------
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# best hyperpar: (0.01, 10.0, 0.1)
# AUPR: 0.4256533686766205
# AUPR for each fold: [0.41231235 0.44054831 0.41774559 0.43558702 0.42207358]
# --- tuning end ---
# target size: 169
# ------ best hyper pars:  (0.01, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.49434739128493566
# AUROCperdrug: 0.8902965027915305
# AUPR+AUROCperdrug: 1.3846438940764663
# AUPR: 0.47202602793055737
# AUROC: 0.8696322756726318
# AUPR+AUROC: 1.341658303603189
# -----------
# integration results:
#              score                                                           \
#               mean        std              mean               std      mean
# metric  AUPR+AUROC AUPR+AUROC AUPR+AUROCperdrug AUPR+AUROCperdrug     AUROC
# method
# APPFC     1.294346   0.012182          1.347351          0.013625  0.868692
# noAPPFC   1.261342   0.015259          1.326728          0.012892  0.863505
#
#                                                                              \
#               std      mean       std         mean          std        mean
# metric      AUROC      AUPR      AUPR AUROCperdrug AUROCperdrug AUPRperdrug
# method
# APPFC    0.004724  0.425653  0.011978     0.890623     0.003024    0.456728
# noAPPFC  0.007693  0.397836  0.009987     0.883522     0.002491    0.443205
#
#
#                 std
# metric  AUPRperdrug
# method
# APPFC      0.010920
# noAPPFC    0.010662
#              score                                                     \
# metric  AUPR+AUROC AUPR+AUROCperdrug     AUROC      AUPR AUROCperdrug
# method
# APPFC     1.341658          1.384644  0.869632  0.472026     0.890297
# noAPPFC   1.290243          1.360275  0.858855  0.431387     0.881433
#
#
# metric  AUPRperdrug
# method
# APPFC      0.494347
# noAPPFC    0.478842
# ('target', 'Chem')
# without APPFC
# The MKRR requires hyperparameter lambda, sigma_X
# ---------- nested cv start ----------
# Fold: 0
# number of hyperpars combination:  225
# first few training idx:  [20 23 25 28 29 31 36 40 42 43]
# first few testing idx:  [ 217  251  477  524  682  823  936 1017 1071 1207]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (1.0, 10.0, 0.1)
# AUPR: 0.40499848373424613
# AUPR for each fold: [0.38936014 0.39622011 0.4257393  0.40867438]
# --- tuning end ---
# target size: 123
# ------ best hyper pars:  (1.0, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.4563800296247426
# AUROCperdrug: 0.8807472117237607
# AUPR+AUROCperdrug: 1.3371272413485034
# AUPR: 0.3904731435386345
# AUROC: 0.8414298194349626
# AUPR+AUROC: 1.2319029629735971
# -----------
# Fold: 1
# number of hyperpars combination:  225
# first few training idx:  [23 25 28 31 36 40 43 44 45 47]
# first few testing idx:  [  20  295  402  489  669  676 1126 1240 1306 1339]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (1.0, 10.0, 0.1)
# AUPR: 0.39344851014525
# AUPR for each fold: [0.41351401 0.39209146 0.37859935 0.38958922]
# --- tuning end ---
# target size: 123
# ------ best hyper pars:  (1.0, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.4865461686930574
# AUROCperdrug: 0.8936742183673974
# AUPR+AUROCperdrug: 1.3802203870604548
# AUPR: 0.4390255894657158
# AUROC: 0.8707813871685577
# AUPR+AUROC: 1.3098069766342735
# -----------
# Fold: 2
# number of hyperpars combination:  225
# first few training idx:  [20 23 29 31 36 40 42 44 45 46]
# first few testing idx:  [  43  132  201  268  339  428  658  859  900 1235]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (1.0, 10.0, 0.1)
# AUPR: 0.3982054862219454
# AUPR for each fold: [0.38250713 0.39729751 0.39457577 0.41844153]
# --- tuning end ---
# target size: 123
# ------ best hyper pars:  (1.0, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.4509708587756238
# AUROCperdrug: 0.8740052106045031
# AUPR+AUROCperdrug: 1.324976069380127
# AUPR: 0.4101465032064639
# AUROC: 0.8576257970356957
# AUPR+AUROC: 1.2677723002421597
# -----------
# Fold: 3
# number of hyperpars combination:  225
# first few training idx:  [20 23 25 28 29 36 42 43 44 45]
# first few testing idx:  [  47   88  360  447  484  543  771  948  981 1206]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (1.0, 10.0, 0.1)
# AUPR: 0.39748966463370927
# AUPR for each fold: [0.40305099 0.3906702  0.39423716 0.40200031]
# --- tuning end ---
# target size: 123
# ------ best hyper pars:  (1.0, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.4711324780901964
# AUROCperdrug: 0.8828589508327294
# AUPR+AUROCperdrug: 1.3539914289229258
# AUPR: 0.43714436489256586
# AUROC: 0.8670829363815357
# AUPR+AUROC: 1.3042273012741015
# -----------
# Fold: 4
# number of hyperpars combination:  225
# first few training idx:  [20 25 28 29 31 40 42 43 45 46]
# first few testing idx:  [ 254  351  493  797  844  911  992 1006 1019 1029]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (1.0, 10.0, 0.1)
# AUPR: 0.4062254252954519
# AUPR for each fold: [0.42540128 0.41618374 0.38716523 0.39615145]
# --- tuning end ---
# target size: 123
# ------ best hyper pars:  (1.0, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.46485787587143135
# AUROCperdrug: 0.8889347655567733
# AUPR+AUROCperdrug: 1.3537926414282047
# AUPR: 0.3884893376509636
# AUROC: 0.8438966566767535
# AUPR+AUROC: 1.2323859943277171
# -----------
# Mean AUPRperdrug: 0.4659774822110103, std: 0.012395226561414239
# Mean AUROCperdrug: 0.8840440714170328, std: 0.006778069644137843
# Mean AUPR+AUROCperdrug: 1.3500215536280433, std: 0.018630566948468857
# Mean AUPR: 0.41305578775086876, std: 0.021802019982138193
# Mean AUROC: 0.8561633193395011, std: 0.01185421289441132
# Mean AUPR+AUROC: 1.2692191070903698, std: 0.03353867878049125
# -----------
# with APPFC
# The MKRR requires hyperparameter lambda, sigma_X
# ---------- nested cv start ----------
# Fold: 0
# number of hyperpars combination:  225
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [ 217  251  477  524  682  823  936 1017 1071 1207]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (1.0, 10.0, 0.1)
# AUPR: 0.41014695046161576
# AUPR for each fold: [0.39034045 0.39629723 0.4310115  0.42293862]
# --- tuning end ---
# target size: 123
# ------ best hyper pars:  (1.0, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.4643543942032155
# AUROCperdrug: 0.8845908531824358
# AUPR+AUROCperdrug: 1.3489452473856514
# AUPR: 0.4021863994971018
# AUROC: 0.8482976751073665
# AUPR+AUROC: 1.2504840746044683
# -----------
# Fold: 1
# number of hyperpars combination:  225
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [  20  295  402  489  669  676 1126 1240 1306 1339]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (1.0, 10.0, 0.1)
# AUPR: 0.40120979609846524
# AUPR for each fold: [0.4164472  0.39672169 0.38875093 0.40291936]
# --- tuning end ---
# target size: 123
# ------ best hyper pars:  (1.0, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.4957064137230138
# AUROCperdrug: 0.8982902437105451
# AUPR+AUROCperdrug: 1.393996657433559
# AUPR: 0.4581176143067748
# AUROC: 0.8755443289738938
# AUPR+AUROC: 1.3336619432806684
# -----------
# Fold: 2
# number of hyperpars combination:  225
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [  43  132  201  268  339  428  658  859  900 1235]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0, 0.1)
# AUPR: 0.4124667948938041
# AUPR for each fold: [0.39837375 0.41262862 0.40515891 0.43370589]
# --- tuning end ---
# target size: 123
# ------ best hyper pars:  (0.1, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.4588324044369858
# AUROCperdrug: 0.8654844351564216
# AUPR+AUROCperdrug: 1.3243168395934073
# AUPR: 0.44381690039418287
# AUROC: 0.8456104397152575
# AUPR+AUROC: 1.2894273401094405
# -----------
# Fold: 3
# number of hyperpars combination:  225
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [  47   88  360  447  484  543  771  948  981 1206]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0, 0.1)
# AUPR: 0.41335785453025653
# AUPR for each fold: [0.42759519 0.40543194 0.4090751  0.41132918]
# --- tuning end ---
# target size: 123
# ------ best hyper pars:  (0.1, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.4696908140766775
# AUROCperdrug: 0.8752011616534975
# AUPR+AUROCperdrug: 1.344891975730175
# AUPR: 0.4393819553605195
# AUROC: 0.8545036542011142
# AUPR+AUROC: 1.2938856095616336
# -----------
# Fold: 4
# number of hyperpars combination:  225
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [ 254  351  493  797  844  911  992 1006 1019 1029]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0, 0.1)
# AUPR: 0.4235636016703361
# AUPR for each fold: [0.4341834  0.43512734 0.41813825 0.40680541]
# --- tuning end ---
# target size: 123
# ------ best hyper pars:  (0.1, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.4714127616087219
# AUROCperdrug: 0.876069442536913
# AUPR+AUROCperdrug: 1.347482204145635
# AUPR: 0.3986987455101315
# AUROC: 0.8217406764070285
# AUPR+AUROC: 1.2204394219171601
# -----------
# Mean AUPRperdrug: 0.4719993576097229, std: 0.012645252856396085
# Mean AUROCperdrug: 0.8799272272479625, std: 0.010997838176125723
# Mean AUPR+AUROCperdrug: 1.3519265848576854, std: 0.022848700876462312
# Mean AUPR: 0.428440323013742, std: 0.02370961830675946
# Mean AUROC: 0.8491393548809321, std: 0.017261793726322815
# Mean AUPR+AUROC: 1.2775796778946742, std: 0.038860395183641365
# -----------
# without APPFC
# The MKRR requires hyperparameter lambda, sigma_X
# ---------- cv start ----------
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# best hyperpar: (1.0, 10.0, 0.1)
# AUPR: 0.41305578775086876
# AUPR for each fold: [0.39047314 0.43902559 0.4101465  0.43714436 0.38848934]
# --- tuning end ---
# target size: 196
# ------ best hyper pars:  (1.0, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.4773022952400514
# AUROCperdrug: 0.8812064143519645
# AUPR+AUROCperdrug: 1.3585087095920159
# AUPR: 0.4269910342521457
# AUROC: 0.8507351418481803
# AUPR+AUROC: 1.277726176100326
# -----------
# with APPFC
# The MKRR requires hyperparameter lambda, sigma_X
# ---------- cv start ----------
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# best hyperpar: (0.1, 10.0, 0.1)
# AUPR: 0.4333654543248901
# AUPR for each fold: [0.42227693 0.46265274 0.4438169  0.43938196 0.39869875]
# --- tuning end ---
# target size: 196
# ------ best hyper pars:  (0.1, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.48518258964736777
# AUROCperdrug: 0.8777841327045441
# AUPR+AUROCperdrug: 1.362966722351912
# AUPR: 0.4674710414886157
# AUROC: 0.8557380736288294
# AUPR+AUROC: 1.323209115117445
# -----------
# integration results:
#              score                                                           \
#               mean        std              mean               std      mean
# metric  AUPR+AUROC AUPR+AUROC AUPR+AUROCperdrug AUPR+AUROCperdrug     AUROC
# method
# APPFC     1.277580   0.043447          1.351927          0.025546  0.849139
# noAPPFC   1.269219   0.037497          1.350022          0.020830  0.856163
#
#                                                                              \
#               std      mean       std         mean          std        mean
# metric      AUROC      AUPR      AUPR AUROCperdrug AUROCperdrug AUPRperdrug
# method
# APPFC    0.019299  0.428440  0.026508     0.879927     0.012296    0.471999
# noAPPFC  0.013253  0.413056  0.024375     0.884044     0.007578    0.465977
#
#
#                 std
# metric  AUPRperdrug
# method
# APPFC      0.014138
# noAPPFC    0.013858
#              score                                                     \
# metric  AUPR+AUROC AUPR+AUROCperdrug     AUROC      AUPR AUROCperdrug
# method
# APPFC     1.323209          1.362967  0.855738  0.467471     0.877784
# noAPPFC   1.277726          1.358509  0.850735  0.426991     0.881206
#
#
# metric  AUPRperdrug
# method
# APPFC      0.485183
# noAPPFC    0.477302
# ('target', 'DGI')
# without APPFC
# The MKRR requires hyperparameter lambda, sigma_X
# ---------- nested cv start ----------
# Fold: 0
# number of hyperpars combination:  225
# first few training idx:  [20 22 23 25 28 29 31 39 40 41]
# first few testing idx:  [ 256  373  476  676  764  909  972 1008 1087 1244]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0, 0.1)
# AUPR: 0.423747678057779
# AUPR for each fold: [0.43350238 0.41966758 0.42524975 0.416571  ]
# --- tuning end ---
# target size: 134
# ------ best hyper pars:  (0.1, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.4741882214807611
# AUROCperdrug: 0.8975736194841558
# AUPR+AUROCperdrug: 1.371761840964917
# AUPR: 0.43473751670858723
# AUROC: 0.8692342549343753
# AUPR+AUROC: 1.3039717716429626
# -----------
# Fold: 1
# number of hyperpars combination:  225
# first few training idx:  [22 23 25 28 29 31 36 40 41 42]
# first few testing idx:  [ 59 150 270 398 415 553 587 721 782 920]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0, 0.1)
# AUPR: 0.42589633331154236
# AUPR for each fold: [0.41312058 0.41202232 0.42396231 0.45448013]
# --- tuning end ---
# target size: 134
# ------ best hyper pars:  (0.1, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.4922050391256017
# AUROCperdrug: 0.8894596685188305
# AUPR+AUROCperdrug: 1.3816647076444322
# AUPR: 0.4430338485634824
# AUROC: 0.8530104957749527
# AUPR+AUROC: 1.296044344338435
# -----------
# Fold: 2
# number of hyperpars combination:  225
# first few training idx:  [20 22 25 29 31 36 39 41 42 43]
# first few testing idx:  [  40  165  210  315  662  699  748  776 1272 1275]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0, 0.1)
# AUPR: 0.41817832247657016
# AUPR for each fold: [0.38963724 0.42542231 0.44241592 0.41523782]
# --- tuning end ---
# target size: 134
# ------ best hyper pars:  (0.1, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.45935454336106635
# AUROCperdrug: 0.8845035454637368
# AUPR+AUROCperdrug: 1.343858088824803
# AUPR: 0.44447491503823117
# AUROC: 0.8657884931462068
# AUPR+AUROC: 1.310263408184438
# -----------
# Fold: 3
# number of hyperpars combination:  225
# first few training idx:  [20 22 23 28 31 36 39 40 41 42]
# first few testing idx:  [ 458  550  568  750  797  839  917 1072 1183 1194]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0, 0.1)
# AUPR: 0.4343715508635924
# AUPR for each fold: [0.44781099 0.45139092 0.41470455 0.42357974]
# --- tuning end ---
# target size: 134
# ------ best hyper pars:  (0.1, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.4617712354790445
# AUROCperdrug: 0.8868033088499429
# AUPR+AUROCperdrug: 1.3485745443289874
# AUPR: 0.40350622242031126
# AUROC: 0.8623034439624965
# AUPR+AUROC: 1.2658096663828078
# -----------
# Fold: 4
# number of hyperpars combination:  225
# first few training idx:  [20 23 25 28 29 36 39 40 42 43]
# first few testing idx:  [  46  111  235  312  319  403  416  555 1091 1286]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0, 0.1)
# AUPR: 0.41923773966757555
# AUPR for each fold: [0.42275444 0.42124688 0.43155728 0.40139236]
# --- tuning end ---
# target size: 134
# ------ best hyper pars:  (0.1, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.46696515646783704
# AUROCperdrug: 0.8960913265826158
# AUPR+AUROCperdrug: 1.3630564830504528
# AUPR: 0.43294568405829464
# AUROC: 0.8699128344559369
# AUPR+AUROC: 1.3028585185142316
# -----------
# Mean AUPRperdrug: 0.4708968391828622, std: 0.011805354268291077
# Mean AUROCperdrug: 0.8908862937798563, std: 0.005123635295245192
# Mean AUPR+AUROCperdrug: 1.3617831329627184, std: 0.014087207435861655
# Mean AUPR: 0.43173963735778137, std: 0.014814277252936185
# Mean AUROC: 0.8640499044547936, std: 0.006151305503436763
# Mean AUPR+AUROC: 1.295789541812575, std: 0.01565420058302525
# -----------
# with APPFC
# The MKRR requires hyperparameter lambda, sigma_X
# ---------- nested cv start ----------
# Fold: 0
# number of hyperpars combination:  225
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [ 256  373  476  676  764  909  972 1008 1087 1244]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0, 0.1)
# AUPR: 0.4517770962160216
# AUPR for each fold: [0.47150574 0.43894142 0.45539605 0.44126517]
# --- tuning end ---
# target size: 134
# ------ best hyper pars:  (0.1, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.48471524922101245
# AUROCperdrug: 0.9076297382214022
# AUPR+AUROCperdrug: 1.3923449874424147
# AUPR: 0.4654010576474377
# AUROC: 0.8791132845474335
# AUPR+AUROC: 1.3445143421948713
# -----------
# Fold: 1
# number of hyperpars combination:  225
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [ 59 150 270 398 415 553 587 721 782 920]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0, 0.1)
# AUPR: 0.43853589111857877
# AUPR for each fold: [0.40873384 0.43350974 0.4304726  0.48142739]
# --- tuning end ---
# target size: 134
# ------ best hyper pars:  (0.1, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.5154769221631822
# AUROCperdrug: 0.907653014359583
# AUPR+AUROCperdrug: 1.4231299365227652
# AUPR: 0.4802393264543242
# AUROC: 0.8829452196343209
# AUPR+AUROC: 1.3631845460886451
# -----------
# Fold: 2
# number of hyperpars combination:  225
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [  40  165  210  315  662  699  748  776 1272 1275]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0, 0.1)
# AUPR: 0.44145160274021594
# AUPR for each fold: [0.38671152 0.45229142 0.4769091  0.44989437]
# --- tuning end ---
# target size: 134
# ------ best hyper pars:  (0.1, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.46767317165551503
# AUROCperdrug: 0.8932956546773086
# AUPR+AUROCperdrug: 1.3609688263328237
# AUPR: 0.45937006368828004
# AUROC: 0.87405331034243
# AUPR+AUROC: 1.33342337403071
# -----------
# Fold: 3
# number of hyperpars combination:  225
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [ 458  550  568  750  797  839  917 1072 1183 1194]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0, 0.1)
# AUPR: 0.4557739119299163
# AUPR for each fold: [0.47476175 0.47935548 0.42931067 0.43966775]
# --- tuning end ---
# target size: 134
# ------ best hyper pars:  (0.1, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.4797193106554314
# AUROCperdrug: 0.9043148496015535
# AUPR+AUROCperdrug: 1.3840341602569848
# AUPR: 0.4128638608129075
# AUROC: 0.881132860477936
# AUPR+AUROC: 1.2939967212908434
# -----------
# Fold: 4
# number of hyperpars combination:  225
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [  46  111  235  312  319  403  416  555 1091 1286]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0, 0.1)
# AUPR: 0.44414733696388164
# AUPR for each fold: [0.44373849 0.45199427 0.43901589 0.4418407 ]
# --- tuning end ---
# target size: 134
# ------ best hyper pars:  (0.1, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.48104838705845593
# AUROCperdrug: 0.9073451348708584
# AUPR+AUROCperdrug: 1.3883935219293144
# AUPR: 0.45913767462739963
# AUROC: 0.8851484048101169
# AUPR+AUROC: 1.3442860794375164
# -----------
# Mean AUPRperdrug: 0.4857266081507194, std: 0.01593740239685381
# Mean AUROCperdrug: 0.9040476783461411, std: 0.00552051109421999
# Mean AUPR+AUROCperdrug: 1.3897742864968605, std: 0.0199189256101062
# Mean AUPR: 0.4554023966460699, std: 0.022610033252099895
# Mean AUROC: 0.8804786159624476, std: 0.0037806819391590506
# Mean AUPR+AUROC: 1.3358810126085174, std: 0.023026056176470678
# -----------
# without APPFC
# The MKRR requires hyperparameter lambda, sigma_X
# ---------- cv start ----------
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# best hyperpar: (0.1, 10.0, 0.1)
# AUPR: 0.43173963735778137
# AUPR for each fold: [0.43473752 0.44303385 0.44447492 0.40350622 0.43294568]
# --- tuning end ---
# target size: 216
# ------ best hyper pars:  (0.1, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.48373477037459456
# AUROCperdrug: 0.8888203431990741
# AUPR+AUROCperdrug: 1.3725551135736687
# AUPR: 0.4568295723732534
# AUROC: 0.8632302891214113
# AUPR+AUROC: 1.3200598614946646
# -----------
# with APPFC
# The MKRR requires hyperparameter lambda, sigma_X
# ---------- cv start ----------
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# best hyperpar: (0.1, 10.0, 0.1)
# AUPR: 0.4554023966460699
# AUPR for each fold: [0.46540106 0.48023933 0.45937006 0.41286386 0.45913767]
# --- tuning end ---
# target size: 216
# ------ best hyper pars:  (0.1, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.5015224758756558
# AUROCperdrug: 0.9068655681182923
# AUPR+AUROCperdrug: 1.408388043993948
# AUPR: 0.48932708351900267
# AUROC: 0.8870040145595003
# AUPR+AUROC: 1.376331098078503
# -----------
# integration results:
#              score                                                           \
#               mean        std              mean               std      mean
# metric  AUPR+AUROC AUPR+AUROC AUPR+AUROCperdrug AUPR+AUROCperdrug     AUROC
# method
# APPFC     1.335881   0.025744          1.389774           0.02227  0.880479
# noAPPFC   1.295790   0.017502          1.361783           0.01575  0.864050
#
#                                                                              \
#               std      mean       std         mean          std        mean
# metric      AUROC      AUPR      AUPR AUROCperdrug AUROCperdrug AUPRperdrug
# method
# APPFC    0.004227  0.455402  0.025279     0.904048     0.006172    0.485727
# noAPPFC  0.006877  0.431740  0.016563     0.890886     0.005728    0.470897
#
#
#                 std
# metric  AUPRperdrug
# method
# APPFC      0.017819
# noAPPFC    0.013199
#              score                                                     \
# metric  AUPR+AUROC AUPR+AUROCperdrug     AUROC      AUPR AUROCperdrug
# method
# APPFC     1.376331          1.408388  0.887004  0.489327     0.906866
# noAPPFC   1.320060          1.372555  0.863230  0.456830     0.888820
#
#
# metric  AUPRperdrug
# method
# APPFC      0.501522
# noAPPFC    0.483735
# ('target', 'transporter')
# without APPFC
# The MKRR requires hyperparameter lambda, sigma_X
# ---------- nested cv start ----------
# Fold: 0
# number of hyperpars combination:  225
# first few training idx:  [23 25 28 29 31 39 42 43 45 49]
# first few testing idx:  [ 233  258  289  319  474  510 1048 1092 1135 1280]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (1.0, 10.0, 0.1)
# AUPR: 0.4132271918870944
# AUPR for each fold: [0.42366324 0.41659382 0.40147498 0.41117673]
# --- tuning end ---
# target size: 74
# ------ best hyper pars:  (1.0, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.5134533637975529
# AUROCperdrug: 0.8906086405784158
# AUPR+AUROCperdrug: 1.4040620043759686
# AUPR: 0.46928127202515774
# AUROC: 0.878006474702107
# AUPR+AUROC: 1.3472877467272648
# -----------
# Fold: 1
# number of hyperpars combination:  225
# first few training idx:  [23 28 29 39 43 45 49 61 62 67]
# first few testing idx:  [ 235  371  534  543  701  782  939  988 1147 1226]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (1.0, 10.0, 0.1)
# AUPR: 0.43200659434677613
# AUPR for each fold: [0.43422091 0.42229913 0.43611139 0.43539495]
# --- tuning end ---
# target size: 74
# ------ best hyper pars:  (1.0, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.46911251448039337
# AUROCperdrug: 0.8897407338378001
# AUPR+AUROCperdrug: 1.3588532483181934
# AUPR: 0.39711763831196445
# AUROC: 0.8613766311615729
# AUPR+AUROC: 1.2584942694735375
# -----------
# Fold: 2
# number of hyperpars combination:  225
# first few training idx:  [23 25 28 29 31 39 42 43 51 61]
# first few testing idx:  [  49  255  268  291  331  423  680 1049 1080 1162]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (1.0, 10.0, 0.1)
# AUPR: 0.41982945547173367
# AUPR for each fold: [0.43737463 0.42260557 0.39851245 0.42082517]
# --- tuning end ---
# target size: 74
# ------ best hyper pars:  (1.0, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.497611809679146
# AUROCperdrug: 0.8891605408491716
# AUPR+AUROCperdrug: 1.3867723505283176
# AUPR: 0.4387092481832152
# AUROC: 0.8564431328589618
# AUPR+AUROC: 1.295152381042177
# -----------
# Fold: 3
# number of hyperpars combination:  225
# first few training idx:  [23 25 29 31 42 45 49 51 61 62]
# first few testing idx:  [  28  116  434  532  615  679  804  864  950 1243]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (1.0, 10.0, 0.1)
# AUPR: 0.4312390562048402
# AUPR for each fold: [0.43020551 0.45449799 0.41037503 0.4298777 ]
# --- tuning end ---
# target size: 74
# ------ best hyper pars:  (1.0, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.4453071161237192
# AUROCperdrug: 0.8867701180641315
# AUPR+AUROCperdrug: 1.3320772341878508
# AUPR: 0.40871149519624994
# AUROC: 0.8728541979411428
# AUPR+AUROC: 1.2815656931373929
# -----------
# Fold: 4
# number of hyperpars combination:  225
# first few training idx:  [25 28 31 39 42 43 45 49 51 61]
# first few testing idx:  [ 385  560  596  682  700  748  808 1018 1032 1327]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (1.0, 10.0, 0.1)
# AUPR: 0.42644587151872465
# AUPR for each fold: [0.42975778 0.42463245 0.43793124 0.41346202]
# --- tuning end ---
# target size: 74
# ------ best hyper pars:  (1.0, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.46247155706692444
# AUROCperdrug: 0.8877450433502245
# AUPR+AUROCperdrug: 1.350216600417149
# AUPR: 0.41633771541219655
# AUROC: 0.8618727847850872
# AUPR+AUROC: 1.2782105001972837
# -----------
# Mean AUPRperdrug: 0.4775912722295471, std: 0.024615740437516662
# Mean AUROCperdrug: 0.8888050153359487, std: 0.001379810062138479
# Mean AUPR+AUROCperdrug: 1.366396287565496, std: 0.025808399046643633
# Mean AUPR: 0.4260314738257568, std: 0.025539113152078005
# Mean AUROC: 0.8661106442897744, std: 0.008010211080766924
# Mean AUPR+AUROC: 1.2921421181155313, std: 0.029960742645146605
# -----------
# with APPFC
# The MKRR requires hyperparameter lambda, sigma_X
# ---------- nested cv start ----------
# Fold: 0
# number of hyperpars combination:  225
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [ 233  258  289  319  474  510 1048 1092 1135 1280]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.01, 10.0, 0.1)
# AUPR: 0.4419116015343282
# AUPR for each fold: [0.4395819  0.4231739  0.45001117 0.45487944]
# --- tuning end ---
# target size: 74
# ------ best hyper pars:  (0.01, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.5293476466452443
# AUROCperdrug: 0.8971797473964892
# AUPR+AUROCperdrug: 1.4265273940417336
# AUPR: 0.4994823825971835
# AUROC: 0.8815721407758019
# AUPR+AUROC: 1.3810545233729854
# -----------
# Fold: 1
# number of hyperpars combination:  225
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [ 235  371  534  543  701  782  939  988 1147 1226]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.01, 10.0, 0.1)
# AUPR: 0.46331099219797606
# AUPR for each fold: [0.48480815 0.43584397 0.47957676 0.45301508]
# --- tuning end ---
# target size: 74
# ------ best hyper pars:  (0.01, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.47828340866393415
# AUROCperdrug: 0.8954966951200595
# AUPR+AUROCperdrug: 1.3737801037839936
# AUPR: 0.42523902054896273
# AUROC: 0.8644507799458487
# AUPR+AUROC: 1.2896898004948114
# -----------
# Fold: 2
# number of hyperpars combination:  225
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [  49  255  268  291  331  423  680 1049 1080 1162]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (1.0, 1.0, 0.1)
# AUPR: 0.4465905080306738
# AUPR for each fold: [0.44042596 0.46610084 0.44914021 0.43069503]
# --- tuning end ---
# target size: 74
# ------ best hyper pars:  (1.0, 1.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.5053313284832359
# AUROCperdrug: 0.8791157158002684
# AUPR+AUROCperdrug: 1.3844470442835042
# AUPR: 0.41202156894435277
# AUROC: 0.8070687349769585
# AUPR+AUROC: 1.2190903039213112
# -----------
# Fold: 3
# number of hyperpars combination:  225
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [  28  116  434  532  615  679  804  864  950 1243]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.01, 10.0, 0.1)
# AUPR: 0.45947461340944634
# AUPR for each fold: [0.4618697  0.46818634 0.44478573 0.46305669]
# --- tuning end ---
# target size: 74
# ------ best hyper pars:  (0.01, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.4658004948585832
# AUROCperdrug: 0.8936935920994697
# AUPR+AUROCperdrug: 1.359494086958053
# AUPR: 0.4299672140071053
# AUROC: 0.8807503688732741
# AUPR+AUROC: 1.3107175828803794
# -----------
# Fold: 4
# number of hyperpars combination:  225
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [ 385  560  596  682  700  748  808 1018 1032 1327]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0, 0.1)
# AUPR: 0.4500313150162144
# AUPR for each fold: [0.46904999 0.44121774 0.45117822 0.4386793 ]
# --- tuning end ---
# target size: 74
# ------ best hyper pars:  (0.1, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.47425132467386416
# AUROCperdrug: 0.8932464793750992
# AUPR+AUROCperdrug: 1.3674978040489634
# AUPR: 0.44375484805681875
# AUROC: 0.8690316607335239
# AUPR+AUROC: 1.3127865087903428
# -----------
# Mean AUPRperdrug: 0.4906028406649724, std: 0.023462247042417023
# Mean AUROCperdrug: 0.8917464459582771, std: 0.006467796471211854
# Mean AUPR+AUROCperdrug: 1.3823492866232496, std: 0.02354766800854469
# Mean AUPR: 0.4420930068308847, std: 0.030435785676948258
# Mean AUROC: 0.8605747370610815, std: 0.027558601587353286
# Mean AUPR+AUROC: 1.3026677438919658, std: 0.05189468565293004
# -----------
# without APPFC
# The MKRR requires hyperparameter lambda, sigma_X
# ---------- cv start ----------
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# best hyperpar: (1.0, 10.0, 0.1)
# AUPR: 0.4260314738257568
# AUPR for each fold: [0.46928127 0.39711764 0.43870925 0.4087115  0.41633772]
# --- tuning end ---
# target size: 107
# ------ best hyper pars:  (1.0, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.518991728748271
# AUROCperdrug: 0.888358475453408
# AUPR+AUROCperdrug: 1.407350204201679
# AUPR: 0.4653995400556433
# AUROC: 0.8679728417550121
# AUPR+AUROC: 1.3333723818106553
# -----------
# with APPFC
# The MKRR requires hyperparameter lambda, sigma_X
# ---------- cv start ----------
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# best hyperpar: (0.01, 10.0, 0.1)
# AUPR: 0.4563495740313197
# AUPR for each fold: [0.49948238 0.42523902 0.47610482 0.42996721 0.45095444]
# --- tuning end ---
# target size: 107
# ------ best hyper pars:  (0.01, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.5302225270593997
# AUROCperdrug: 0.8944443618372652
# AUPR+AUROCperdrug: 1.424666888896665
# AUPR: 0.4743694492680766
# AUROC: 0.8711601325990199
# AUPR+AUROC: 1.3455295818670965
# -----------
# integration results:
#              score                                                           \
#               mean        std              mean               std      mean
# metric  AUPR+AUROC AUPR+AUROC AUPR+AUROCperdrug AUPR+AUROCperdrug     AUROC
# method
# APPFC     1.302668   0.058020          1.382349          0.026327  0.860575
# noAPPFC   1.292142   0.033497          1.366396          0.028855  0.866111
#
#                                                                              \
#               std      mean       std         mean          std        mean
# metric      AUROC      AUPR      AUPR AUROCperdrug AUROCperdrug AUPRperdrug
# method
# APPFC    0.030811  0.442093  0.034028     0.891746     0.007231    0.490603
# noAPPFC  0.008956  0.426031  0.028554     0.888805     0.001543    0.477591
#
#
#                 std
# metric  AUPRperdrug
# method
# APPFC      0.026232
# noAPPFC    0.027521
#              score                                                     \
# metric  AUPR+AUROC AUPR+AUROCperdrug     AUROC      AUPR AUROCperdrug
# method
# APPFC     1.345530          1.424667  0.871160  0.474369     0.894444
# noAPPFC   1.333372          1.407350  0.867973  0.465400     0.888358
#
#
# metric  AUPRperdrug
# method
# APPFC      0.530223
# noAPPFC    0.518992
# ('target', 'pathway')
# without APPFC
# The MKRR requires hyperparameter lambda, sigma_X
# ---------- nested cv start ----------
# Fold: 0
# number of hyperpars combination:  225
# first few training idx:  [20 29 31 39 41 43 49 51 54 58]
# first few testing idx:  [ 241  291  534  972 1094 1100 1186 1258 1268 1306]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.01, 10.0, 0.1)
# AUPR: 0.4558538623139609
# AUPR for each fold: [0.43789162 0.44207693 0.47248884 0.47095805]
# --- tuning end ---
# target size: 92
# ------ best hyper pars:  (0.01, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.5293855041061208
# AUROCperdrug: 0.8972215949730683
# AUPR+AUROCperdrug: 1.426607099079189
# AUPR: 0.4515812830812489
# AUROC: 0.8589042772562947
# AUPR+AUROC: 1.3104855603375436
# -----------
# Fold: 1
# number of hyperpars combination:  225
# first few training idx:  [20 29 31 39 40 41 43 49 54 59]
# first few testing idx:  [ 312  458  545  617  646  750  883  884 1061 1240]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.01, 10.0, 0.1)
# AUPR: 0.449065339330842
# AUPR for each fold: [0.44522064 0.46064629 0.46367297 0.42672145]
# --- tuning end ---
# target size: 92
# ------ best hyper pars:  (0.01, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.5078328358076055
# AUROCperdrug: 0.8955333181215309
# AUPR+AUROCperdrug: 1.4033661539291364
# AUPR: 0.4675510011156563
# AUROC: 0.8626852453134591
# AUPR+AUROC: 1.3302362464291155
# -----------
# Fold: 2
# number of hyperpars combination:  225
# first few training idx:  [20 39 40 41 49 51 58 59 61 62]
# first few testing idx:  [  80  409  449  484  676  784  981 1140 1246 1328]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.01, 10.0, 0.1)
# AUPR: 0.45457457275940993
# AUPR for each fold: [0.47144876 0.441724   0.45786932 0.44725621]
# --- tuning end ---
# target size: 92
# ------ best hyper pars:  (0.01, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.49033864895446777
# AUROCperdrug: 0.881552160857134
# AUPR+AUROCperdrug: 1.3718908098116018
# AUPR: 0.45648682801425244
# AUROC: 0.8506883178383413
# AUPR+AUROC: 1.3071751458525938
# -----------
# Fold: 3
# number of hyperpars combination:  225
# first few training idx:  [20 29 31 39 40 43 51 54 58 59]
# first few testing idx:  [ 199  255  262  348  543  651  752  854  940 1329]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.01, 10.0, 0.1)
# AUPR: 0.453599032983551
# AUPR for each fold: [0.45358047 0.44169985 0.48438177 0.43473405]
# --- tuning end ---
# target size: 92
# ------ best hyper pars:  (0.01, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.5062318867539751
# AUROCperdrug: 0.8942495295398496
# AUPR+AUROCperdrug: 1.4004814162938248
# AUPR: 0.457915872801128
# AUROC: 0.8698729992036499
# AUPR+AUROC: 1.327788872004778
# -----------
# Fold: 4
# number of hyperpars combination:  225
# first few training idx:  [29 31 40 41 43 49 51 54 58 59]
# first few testing idx:  [ 316  555  572  616  699  801  825  968 1010 1340]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.01, 10.0, 0.1)
# AUPR: 0.4483866490771919
# AUPR for each fold: [0.45762311 0.45300634 0.42431237 0.45860478]
# --- tuning end ---
# target size: 92
# ------ best hyper pars:  (0.01, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.5115042183706385
# AUROCperdrug: 0.906366191943073
# AUPR+AUROCperdrug: 1.4178704103137116
# AUPR: 0.48809146831105876
# AUROC: 0.8842826815760979
# AUPR+AUROC: 1.3723741498871567
# -----------
# Mean AUPRperdrug: 0.5090586187985615, std: 0.012482735697996671
# Mean AUROCperdrug: 0.8949845590869312, std: 0.0079475357582696
# Mean AUPR+AUROCperdrug: 1.404043177885493, std: 0.01869353993277702
# Mean AUPR: 0.4643252906646689, std: 0.012962779572229776
# Mean AUROC: 0.8652867042375686, std: 0.011335758507731962
# Mean AUPR+AUROC: 1.3296119949022374, std: 0.023244560914142107
# -----------
# with APPFC
# The MKRR requires hyperparameter lambda, sigma_X
# ---------- nested cv start ----------
# Fold: 0
# number of hyperpars combination:  225
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [ 241  291  534  972 1094 1100 1186 1258 1268 1306]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.01, 10.0, 0.1)
# AUPR: 0.4732580574926066
# AUPR for each fold: [0.45595212 0.46316299 0.49234041 0.48157672]
# --- tuning end ---
# target size: 92
# ------ best hyper pars:  (0.01, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.5266445600403776
# AUROCperdrug: 0.9079728804801558
# AUPR+AUROCperdrug: 1.4346174405205334
# AUPR: 0.476855037259629
# AUROC: 0.8831675321180288
# AUPR+AUROC: 1.3600225693776578
# -----------
# Fold: 1
# number of hyperpars combination:  225
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [ 312  458  545  617  646  750  883  884 1061 1240]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.01, 10.0, 0.1)
# AUPR: 0.47866160388026113
# AUPR for each fold: [0.47390148 0.48240863 0.50048077 0.45785553]
# --- tuning end ---
# target size: 92
# ------ best hyper pars:  (0.01, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.5050349066588662
# AUROCperdrug: 0.9061358100474031
# AUPR+AUROCperdrug: 1.4111707167062693
# AUPR: 0.47191188707151815
# AUROC: 0.874462039571369
# AUPR+AUROC: 1.3463739266428871
# -----------
# Fold: 2
# number of hyperpars combination:  225
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [  80  409  449  484  676  784  981 1140 1246 1328]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.01, 10.0, 0.1)
# AUPR: 0.4739652625095102
# AUPR for each fold: [0.47539611 0.4759416  0.48558719 0.45893616]
# --- tuning end ---
# target size: 92
# ------ best hyper pars:  (0.01, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.4947717901574078
# AUROCperdrug: 0.8971464210654105
# AUPR+AUROCperdrug: 1.3919182112228183
# AUPR: 0.48541561905987624
# AUROC: 0.8708514388566917
# ...
# --- tuning end ---
# target size: 73
# ------ best hyper pars:  (0.1, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.5278898469401692
# AUROCperdrug: 0.8980385395402372
# AUPR+AUROCperdrug: 1.4259283864804062
# AUPR: 0.4698859546184301
# AUROC: 0.8539697399968974
# AUPR+AUROC: 1.3238556946153275
# -----------
# Fold: 2
# number of hyperpars combination:  225
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [  45  254  267  331  426  682  787  862 1015 1162]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0, 0.1)
# AUPR: 0.49812452702470655
# AUPR for each fold: [0.50036645 0.48232151 0.53191973 0.47789042]
# --- tuning end ---
# target size: 73
# ------ best hyper pars:  (0.1, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.5351178720192927
# AUROCperdrug: 0.8980663097811913
# AUPR+AUROCperdrug: 1.433184181800484
# AUPR: 0.5255233949834598
# AUROC: 0.868622116238869
# AUPR+AUROC: 1.3941455112223289
# -----------
# Fold: 3
# number of hyperpars combination:  225
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [  28  534  617  680  804  883  943  984 1102 1244]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0, 0.1)
# AUPR: 0.5073227106356816
# AUPR for each fold: [0.50326865 0.52065562 0.50991668 0.49544989]
# --- tuning end ---
# target size: 73
# ------ best hyper pars:  (0.1, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.5126334142018508
# AUROCperdrug: 0.8960965818651317
# AUPR+AUROCperdrug: 1.4087299960669826
# AUPR: 0.5142454295728305
# AUROC: 0.8789018368719318
# AUPR+AUROC: 1.3931472664447622
# -----------
# Fold: 4
# number of hyperpars combination:  225
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [ 385  574  683  700  765  808  885 1000 1018 1340]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0, 0.1)
# AUPR: 0.49998704465951166
# AUPR for each fold: [0.53152746 0.50653038 0.4886714  0.47321894]
# --- tuning end ---
# target size: 73
# ------ best hyper pars:  (0.1, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.5399286621839653
# AUROCperdrug: 0.9071654515955795
# AUPR+AUROCperdrug: 1.4470941137795448
# AUPR: 0.5267980469533161
# AUROC: 0.8855675780596526
# AUPR+AUROC: 1.4123656250129688
# -----------
# Mean AUPRperdrug: 0.5330978274281912, std: 0.012486949176547009
# Mean AUROCperdrug: 0.9015226152966948, std: 0.005110279416098882
# Mean AUPR+AUROCperdrug: 1.434620442724886, std: 0.0170756773134994
# Mean AUPR: 0.5139312510944857, std: 0.022853603391550875
# Mean AUROC: 0.8753874712928779, std: 0.01288716041524553
# Mean AUPR+AUROC: 1.3893187223873635, std: 0.034624599519403866
# -----------
# without APPFC
# The MKRR requires hyperparameter lambda, sigma_X
# ---------- cv start ----------
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# best hyperpar: (0.1, 10.0, 0.1)
# AUPR: 0.49615609359772944
# AUPR for each fold: [0.5046372  0.46371867 0.50077645 0.49307425 0.5185739 ]
# --- tuning end ---
# target size: 110
# ------ best hyper pars:  (0.1, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.5507730910077894
# AUROCperdrug: 0.8895991805556087
# AUPR+AUROCperdrug: 1.440372271563398
# AUPR: 0.5461445323526706
# AUROC: 0.8777025455848062
# AUPR+AUROC: 1.4238470779374768
# -----------
# with APPFC
# The MKRR requires hyperparameter lambda, sigma_X
# ---------- cv start ----------
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# best hyperpar: (0.1, 10.0, 0.1)
# AUPR: 0.5139312510944857
# AUPR for each fold: [0.53320343 0.46988595 0.52552339 0.51424543 0.52679805]
# --- tuning end ---
# target size: 110
# ------ best hyper pars:  (0.1, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.5666291335843612
# AUROCperdrug: 0.8990302944633849
# AUPR+AUROCperdrug: 1.4656594280477462
# AUPR: 0.560679967091898
# AUROC: 0.8805948038672522
# AUPR+AUROC: 1.4412747709591502
# -----------
# integration results:
#              score                                                           \
#               mean        std              mean               std      mean
# metric  AUPR+AUROC AUPR+AUROC AUPR+AUROCperdrug AUPR+AUROCperdrug     AUROC
# method
# APPFC     1.389319   0.038711           1.43462          0.019091  0.875387
# noAPPFC   1.363274   0.034009           1.40146          0.022596  0.867118
#
#                                                                              \
#               std      mean       std         mean          std        mean
# metric      AUROC      AUPR      AUPR AUROCperdrug AUROCperdrug AUPRperdrug
# method
# APPFC    0.014408  0.513931  0.025551     0.901523     0.005713    0.533098
# noAPPFC  0.017839  0.496156  0.020356     0.888660     0.009312    0.512800
#
#
#                 std
# metric  AUPRperdrug
# method
# APPFC      0.013961
# noAPPFC    0.014059
#              score                                                     \
# metric  AUPR+AUROC AUPR+AUROCperdrug     AUROC      AUPR AUROCperdrug
# method
# APPFC     1.441275          1.465659  0.880595  0.560680     0.899030
# noAPPFC   1.423847          1.440372  0.877703  0.546145     0.889599
#
#
# metric  AUPRperdrug
# method
# APPFC      0.566629
# noAPPFC    0.550773
# ('pathway', 'indication')
# without APPFC
# The MKRR requires hyperparameter lambda, sigma_X
# ---------- nested cv start ----------
# Fold: 0
# number of hyperpars combination:  225
# first few training idx:  [13 20 29 30 33 39 40 41 43 48]
# first few testing idx:  [ 163  557  745  787  931  943  972 1097 1161 1246]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0, 0.1)
# AUPR: 0.4639114610779149
# AUPR for each fold: [0.46847895 0.46160357 0.44566784 0.47989549]
# --- tuning end ---
# target size: 103
# ------ best hyper pars:  (0.1, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.5428753090389344
# AUROCperdrug: 0.8975726627231507
# AUPR+AUROCperdrug: 1.4404479717620853
# AUPR: 0.5338116801730645
# AUROC: 0.8794920911466683
# AUPR+AUROC: 1.4133037713197327
# -----------
# Fold: 1
# number of hyperpars combination:  225
# first few training idx:  [13 30 31 33 40 41 43 49 51 54]
# first few testing idx:  [ 113  117  292  574  651  968 1061 1092 1159 1340]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0, 0.1)
# AUPR: 0.48000748999764387
# AUPR for each fold: [0.48179599 0.48308621 0.47789038 0.47725738]
# --- tuning end ---
# target size: 103
# ------ best hyper pars:  (0.1, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.4920437409721433
# AUROCperdrug: 0.8939465134647826
# AUPR+AUROCperdrug: 1.3859902544369258
# AUPR: 0.4495542188564918
# AUROC: 0.8604534568923722
# AUPR+AUROC: 1.3100076757488641
# -----------
# Fold: 2
# number of hyperpars combination:  225
# first few training idx:  [13 20 29 30 31 33 39 40 48 49]
# first few testing idx:  [  58   84  188  596 1140 1149 1239 1306 1327 1341]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0, 0.1)
# AUPR: 0.48077333145133944
# AUPR for each fold: [0.46385286 0.49142194 0.48435448 0.48346404]
# --- tuning end ---
# target size: 103
# ------ best hyper pars:  (0.1, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.4995945093254166
# AUROCperdrug: 0.8854679944515749
# AUPR+AUROCperdrug: 1.3850625037769915
# AUPR: 0.47351506069045396
# AUROC: 0.8612164981066543
# AUPR+AUROC: 1.3347315587971083
# -----------
# Fold: 3
# number of hyperpars combination:  225
# first few training idx:  [13 20 29 30 31 39 41 43 48 49]
# first few testing idx:  [167 226 229 237 282 471 555 635 712 809]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0, 0.1)
# AUPR: 0.4825797338604185
# AUPR for each fold: [0.47084634 0.47606223 0.49468155 0.48872881]
# --- tuning end ---
# target size: 103
# ------ best hyper pars:  (0.1, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.49883586330311347
# AUROCperdrug: 0.8895306235224317
# AUPR+AUROCperdrug: 1.3883664868255452
# AUPR: 0.5007316414056077
# AUROC: 0.8735661487566783
# AUPR+AUROC: 1.374297790162286
# -----------
# Fold: 4
# number of hyperpars combination:  225
# first few training idx:  [20 29 31 33 39 40 41 43 48 49]
# first few testing idx:  [267 493 526 559 606 650 671 685 850 873]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0, 0.1)
# AUPR: 0.47421919241927324
# AUPR for each fold: [0.48144237 0.45708488 0.47637808 0.48197144]
# --- tuning end ---
# target size: 103
# ------ best hyper pars:  (0.1, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.5064590168798764
# AUROCperdrug: 0.9026516492583595
# AUPR+AUROCperdrug: 1.4091106661382358
# AUPR: 0.5033437672085205
# AUROC: 0.8791966596184553
# AUPR+AUROC: 1.3825404268269756
# -----------
# Mean AUPRperdrug: 0.507961687903897, std: 0.018043782017625562
# Mean AUROCperdrug: 0.8938338886840599, std: 0.006004170126881713
# Mean AUPR+AUROCperdrug: 1.4017955765879566, std: 0.021249294452604477
# Mean AUPR: 0.49219127366682763, std: 0.02862269590759733
# Mean AUROC: 0.8707849709041657, std: 0.008397633638631915
# Mean AUPR+AUROC: 1.3629762445709936, std: 0.03646155818967761
# -----------
# with APPFC
# The MKRR requires hyperparameter lambda, sigma_X
# ---------- nested cv start ----------
# Fold: 0
# number of hyperpars combination:  225
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [ 163  557  745  787  931  943  972 1097 1161 1246]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0, 0.1)
# AUPR: 0.4666362975216078
# AUPR for each fold: [0.47101564 0.48018559 0.44458668 0.47075728]
# --- tuning end ---
# target size: 103
# ------ best hyper pars:  (0.1, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.5485872081370009
# AUROCperdrug: 0.9073205578129431
# AUPR+AUROCperdrug: 1.455907765949944
# AUPR: 0.5292911900685384
# AUROC: 0.887517843280383
# AUPR+AUROC: 1.4168090333489214
# -----------
# Fold: 1
# number of hyperpars combination:  225
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [ 113  117  292  574  651  968 1061 1092 1159 1340]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0, 0.1)
# AUPR: 0.482793764662699
# AUPR for each fold: [0.4938931  0.49525936 0.48804017 0.45398243]
# --- tuning end ---
# target size: 103
# ------ best hyper pars:  (0.1, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.49687340761178117
# AUROCperdrug: 0.9023520362877173
# AUPR+AUROCperdrug: 1.3992254438994984
# AUPR: 0.4552578464680981
# AUROC: 0.8671074415274901
# AUPR+AUROC: 1.3223652879955883
# -----------
# Fold: 2
# number of hyperpars combination:  225
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [  58   84  188  596 1140 1149 1239 1306 1327 1341]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0, 0.1)
# AUPR: 0.4870314023329849
# AUPR for each fold: [0.45603734 0.49629226 0.49987257 0.49592344]
# --- tuning end ---
# target size: 103
# ------ best hyper pars:  (0.1, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.497491172842328
# AUROCperdrug: 0.8960143976517274
# AUPR+AUROCperdrug: 1.3935055704940553
# AUPR: 0.4649106427870432
# AUROC: 0.8644848265438114
# AUPR+AUROC: 1.3293954693308545
# -----------
# Fold: 3
# number of hyperpars combination:  225
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [167 226 229 237 282 471 555 635 712 809]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0, 0.1)
# AUPR: 0.4749030482128588
# AUPR for each fold: [0.46772359 0.45940518 0.48934509 0.48313834]
# --- tuning end ---
# target size: 103
# ------ best hyper pars:  (0.1, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.5018269085338194
# AUROCperdrug: 0.8999715951093343
# AUPR+AUROCperdrug: 1.4017985036431537
# AUPR: 0.5084522583782068
# AUROC: 0.8874387884367483
# AUPR+AUROC: 1.3958910468149552
# -----------
# Fold: 4
# number of hyperpars combination:  225
# first few training idx:  [ 0  2  4  7  9 10 11 12 16 17]
# first few testing idx:  [267 493 526 559 606 650 671 685 850 873]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0, 0.1)
# AUPR: 0.47740812373426045
# AUPR for each fold: [0.46137335 0.4692993  0.48306838 0.49589146]
# --- tuning end ---
# target size: 103
# ------ best hyper pars:  (0.1, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.5064559334935899
# AUROCperdrug: 0.910301187261335
# AUPR+AUROCperdrug: 1.4167571207549248
# AUPR: 0.49304184756486286
# AUROC: 0.8860475119658981
# AUPR+AUROC: 1.379089359530761
# -----------
# Mean AUPRperdrug: 0.5102469261237038, std: 0.019477195821569187
# Mean AUROCperdrug: 0.9031919548246113, std: 0.005102549466473413
# Mean AUPR+AUROCperdrug: 1.4134388809483152, std: 0.02258085007659738
# Mean AUPR: 0.4901907570533499, std: 0.027312441959636485
# Mean AUROC: 0.8785192823508663, std: 0.01043457703534939
# Mean AUPR+AUROC: 1.368710039404216, std: 0.03702302546207028
# -----------
# without APPFC
# The MKRR requires hyperparameter lambda, sigma_X
# ---------- cv start ----------
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# best hyperpar: (0.1, 10.0, 0.1)
# AUPR: 0.49219127366682763
# AUPR for each fold: [0.53381168 0.44955422 0.47351506 0.50073164 0.50334377]
# --- tuning end ---
# target size: 175
# ------ best hyper pars:  (0.1, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.5272263490902989
# AUROCperdrug: 0.8954308967315957
# AUPR+AUROCperdrug: 1.4226572458218945
# AUPR: 0.5094995844458448
# AUROC: 0.8739947721252327
# AUPR+AUROC: 1.3834943565710773
# -----------
# with APPFC
# The MKRR requires hyperparameter lambda, sigma_X
# ---------- cv start ----------
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# best hyperpar: (0.1, 10.0, 0.1)
# AUPR: 0.4901907570533499
# AUPR for each fold: [0.52929119 0.45525785 0.46491064 0.50845226 0.49304185]
# --- tuning end ---
# target size: 175
# ------ best hyper pars:  (0.1, 10.0, 0.1) ------
# MKRR starts:
# MKRR ends:
# -----------
# AUPRperdrug: 0.5295296589167512
# AUROCperdrug: 0.902551727867784
# AUPR+AUROCperdrug: 1.4320813867845352
# AUPR: 0.5073886449959044
# AUROC: 0.8763556579194193
# AUPR+AUROC: 1.3837443029153236
# -----------
# integration results:
#              score                                                           \
#               mean        std              mean               std      mean
# metric  AUPR+AUROC AUPR+AUROC AUPR+AUROCperdrug AUPR+AUROCperdrug     AUROC
# method
# APPFC     1.368710   0.041393          1.413439          0.025246  0.878519
# noAPPFC   1.362976   0.040765          1.401796          0.023757  0.870785
#
#                                                                              \
#               std      mean       std         mean          std        mean
# metric      AUROC      AUPR      AUPR AUROCperdrug AUROCperdrug AUPRperdrug
# method
# APPFC    0.011666  0.490191  0.030536     0.903192     0.005705    0.510247
# noAPPFC  0.009389  0.492191  0.032001     0.893834     0.006713    0.507962
#
#
#                 std
# metric  AUPRperdrug
# method
# APPFC      0.021776
# noAPPFC    0.020174
#              score                                                     \
# metric  AUPR+AUROC AUPR+AUROCperdrug     AUROC      AUPR AUROCperdrug
# method
# APPFC     1.383744          1.432081  0.876356  0.507389     0.902552
# noAPPFC   1.383494          1.422657  0.873995  0.509500     0.895431
#
#
# metric  AUPRperdrug
# method
# APPFC      0.529530
# noAPPFC    0.527226

# %%
results
# Out:
# {'nested_cv': {'MKRR': {'noAPPFC': {'AUPRperdrug': [0.5428753090389344,
#      0.4920437409721433,
#      0.4995945093254166,
#      0.49883586330311347,
#      0.5064590168798764],
#     'AUROCperdrug': [0.8975726627231507,
#      0.8939465134647826,
#      0.8854679944515749,
#      0.8895306235224317,
#      0.9026516492583595],
#     'AUPR+AUROCperdrug': [1.4404479717620853,
#      1.3859902544369258,
#      1.3850625037769915,
#      1.3883664868255452,
#      1.4091106661382358],
#     'AUPR': [0.5338116801730645,
#      0.4495542188564918,
#      0.47351506069045396,
#      0.5007316414056077,
#      0.5033437672085205],
#     'AUROC': [0.8794920911466683,
#      0.8604534568923722,
#      0.8612164981066543,
#      0.8735661487566783,
#      0.8791966596184553],
#     'AUPR+AUROC': [1.4133037713197327,
#      1.3100076757488641,
#      1.3347315587971083,
#      1.374297790162286,
#      1.3825404268269756]},
#    'APPFC': {'AUPRperdrug': [0.5485872081370009,
#      0.49687340761178117,
#      0.497491172842328,
#      0.5018269085338194,
#      0.5064559334935899],
#     'AUROCperdrug': [0.9073205578129431,
#      0.9023520362877173,
#      0.8960143976517274,
#      0.8999715951093343,
#      0.910301187261335],
#     'AUPR+AUROCperdrug': [1.455907765949944,
#      1.3992254438994984,
#      1.3935055704940553,
#      1.4017985036431537,
#      1.4167571207549248],
#     'AUPR': [0.5292911900685384,
#      0.4552578464680981,
#      0.4649106427870432,
#      0.5084522583782068,
#      0.49304184756486286],
#     'AUROC': [0.887517843280383,
#      0.8671074415274901,
#      0.8644848265438114,
#      0.8874387884367483,
#      0.8860475119658981],
#     'AUPR+AUROC': [1.4168090333489214,
#      1.3223652879955883,
#      1.3293954693308545,
#      1.3958910468149552,
#      1.379089359530761]}}},
#  'cv': {'MKRR': {'noAPPFC': {'AUPRperdrug': 0.5272263490902989,
#     'AUROCperdrug': 0.8954308967315957,
#     'AUPR+AUROCperdrug': 1.4226572458218945,
#     'AUPR': 0.5094995844458448,
#     'AUROC': 0.8739947721252327,
#     'AUPR+AUROC': 1.3834943565710773},
#    'APPFC': {'AUPRperdrug': 0.5295296589167512,
#     'AUROCperdrug': 0.902551727867784,
#     'AUPR+AUROCperdrug': 1.4320813867845352,
#     'AUPR': 0.5073886449959044,
#     'AUROC': 0.8763556579194193,
#     'AUPR+AUROC': 1.3837443029153236}}}}
