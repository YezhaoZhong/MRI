# %%
from itertools import product
import numpy as np
import pandas as pd
from ADRprofilePrediction import Pairs2Mat, evaluation, evaluation2
from APPFC import completion
from Models import loadHyperpar
import seaborn as sns 
import matplotlib.pylab as plt
from matplotlib.ticker import MultipleLocator
import matplotlib.patheffects as path_effects
import json
import pingouin as pg
from functools import reduce

# %%
class NpEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        elif isinstance(obj, np.floating):
            return float(obj)
        elif isinstance(obj, np.ndarray):
            return obj.tolist()
        else:
            return super(NpEncoder, self).default(obj)

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 0.24.2

# %%
SEs_name = "SIDER"
metrice = "mse"

# %%
features_dict = {
    "target":Pairs2Mat(path="data/drug_target.tsv",colname1="0",colname2="1"),
    "enzyme":Pairs2Mat(path="data/drug_enzyme.tsv",colname1="0",colname2="1"),
    "Chem":pd.read_csv("data/drug_chemsfp.tsv",sep = "\t",header=0,index_col=0),
    "DGI":Pairs2Mat(path="data/interactions.tsv",colname1="drug_claim_name",colname2="gene_name"),
    "transporter":Pairs2Mat(path="data/drug_transporter.tsv",colname1="0",colname2="1"),
    "pathway":Pairs2Mat(path="data/drug_pathway.tsv",colname1="0",colname2="1"),
    "indication":Pairs2Mat(path="data/drug_indication.tsv",colname1="1_x",colname2="6")
}

# %%
filter = "all"
SEs = {}
if filter == "all":
    SIDER = Pairs2Mat(path="data/drug_se.tsv",colname1="1_x",colname2="5")
    column_sums = np.sum(SIDER, axis=0)
    SEs["SIDER"] = SIDER.loc[:, (column_sums >= 5)]

    OFFSIDES = Pairs2Mat(path="data/OFFSIDES.csv",colname1="drug_concept_name",colname2="condition_concept_name",sep = ",")
    column_sums = np.sum(OFFSIDES, axis=0)
    SEs["OFFSIDES"] = OFFSIDES.loc[:, column_sums >= 5]
elif filter == "rare":
    SIDER = Pairs2Mat(path="data/drug_se.tsv",colname1="1_x",colname2="5")
    column_sums = np.sum(SIDER, axis=0)
    SEs["SIDER"] = SIDER.loc[:, (column_sums < 50)]

    OFFSIDES = Pairs2Mat(path="data/OFFSIDES.csv",colname1="drug_concept_name",colname2="condition_concept_name",sep = ",")
    column_sums = np.sum(OFFSIDES, axis=0)
    SEs["OFFSIDES"] = OFFSIDES.loc[:, column_sums < 50]

# %%
SEs["SIDER"].shape
# Out:
# (1344, 2556)

# %%
SEs["OFFSIDES"].shape
# Out:
# (2730, 12750)

# %%
df_dict = features_dict
intersection_indices = df_dict['target'].index
for df_name, df in df_dict.items():
    intersection_indices = intersection_indices.intersection(df.index)
intersection_indices = intersection_indices.tolist()
print("Intersection indices:", intersection_indices)
print("Size of intersection set", len(intersection_indices))
# Out:
# Intersection indices: ['ACETAMINOPHEN', 'ACETAZOLAMIDE', 'ALFENTANIL', 'ALLOPURINOL', 'AMANTADINE', 'AMIODARONE', 'AMITRIPTYLINE', 'AMLODIPINE', 'AMOXICILLIN', 'AMPRENAVIR', 'ANASTROZOLE', 'APIXABAN', 'APOMORPHINE', 'ARIPIPRAZOLE', 'ATAZANAVIR', 'ATENOLOL', 'AZATHIOPRINE', 'AZELASTINE', 'AZITHROMYCIN', 'BENAZEPRIL', 'BENZOCAINE', 'BEPRIDIL', 'BETAMETHASONE', 'BEZAFIBRATE', 'BICALUTAMIDE', 'BISOPROLOL', 'BOSENTAN', 'BOSUTINIB', 'BROMOCRIPTINE', 'BUMETANIDE', 'BUPRENORPHINE', 'BUSPIRONE', 'CABERGOLINE', 'CANAGLIFLOZIN', 'CANDESARTAN', 'CARBAMAZEPINE', 'CARBOPLATIN', 'CARVEDILOL', 'CEFACLOR', 'CEFAZOLIN', 'CEFTRIAXONE', 'CELECOXIB', 'CERIVASTATIN', 'CHLORAMBUCIL', 'CHLORPROMAZINE', 'CHLORPROPAMIDE', 'CIDOFOVIR', 'CIMETIDINE', 'CINOXACIN', 'CIPROFLOXACIN', 'CISPLATIN', 'CITALOPRAM', 'CLADRIBINE', 'CLARITHROMYCIN', 'CLOBAZAM', 'CLOMIPRAMINE', 'CLONIDINE', 'CLOPIDOGREL', 'CLOTRIMAZOLE', 'CODEINE', 'COLCHICINE', 'CRIZOTINIB', 'CYPROHEPTADINE', 'DAPAGLIFLOZIN', 'DARUNAVIR', 'DASATINIB', 'DESIPRAMINE', 'DEXAMETHASONE', 'DIAZEPAM', 'DICLOFENAC', 'DIFLUNISAL', 'DIGOXIN', 'DIHYDROERGOTAMINE', 'DILTIAZEM', 'DIPHENHYDRAMINE', 'DISOPYRAMIDE', 'DOCETAXEL', 'DOFETILIDE', 'DOLUTEGRAVIR', 'DOMPERIDONE', 'DONEPEZIL', 'DOPAMINE', 'DOXAZOSIN', 'DOXORUBICIN', 'DRONEDARONE', 'DULOXETINE', 'EFAVIRENZ', 'ELETRIPTAN', 'EMTRICITABINE', 'EPINASTINE', 'EPINEPHRINE', 'ERGOTAMINE', 'ERLOTINIB', 'ERYTHROMYCIN', 'ESOMEPRAZOLE', 'ESTRADIOL', 'ESTRAMUSTINE', 'ESTRONE', 'ETODOLAC', 'ETOPOSIDE', 'ETRAVIRINE', 'EVEROLIMUS', 'EZETIMIBE', 'FAMOTIDINE', 'FELODIPINE', 'FENOFIBRATE', 'FENTANYL', 'FLECAINIDE', 'FLUCLOXACILLIN', 'FLUCONAZOLE', 'FLUOXETINE', 'FLUPHENAZINE', 'FLURAZEPAM', 'FLURBIPROFEN', 'FLUTAMIDE', 'FLUVASTATIN', 'FLUVOXAMINE', 'FUROSEMIDE', 'GABAPENTIN', 'GALANTAMINE', 'GEFITINIB', 'GEMCITABINE', 'GLIMEPIRIDE', 'GLIPIZIDE', 'GUANFACINE', 'HALOPERIDOL', 'HYDROCORTISONE', 'HYDROXYUREA', 'HYDROXYZINE', 'IBUPROFEN', 'IDARUBICIN', 'IMATINIB', 'IMIPRAMINE', 'INDINAVIR', 'INDOMETHACIN', 'IRINOTECAN', 'ISRADIPINE', 'ITRACONAZOLE', 'KETOCONAZOLE', 'KETOPROFEN', 'LABETALOL', 'LAMIVUDINE', 'LAMOTRIGINE', 'LANSOPRAZOLE', 'LAPATINIB', 'LATANOPROST', 'LEFLUNOMIDE', 'LETROZOLE', 'LIDOCAINE', 'LINAGLIPTIN', 'LORATADINE', 'LOSARTAN', 'LOVASTATIN', 'MEFLOQUINE', 'MELOXICAM', 'MEMANTINE', 'MEPYRAMINE', 'METHADONE', 'METHOTREXATE', 'METHYLPREDNISOLONE', 'METHYLTESTOSTERONE', 'METOCLOPRAMIDE', 'METOPROLOL', 'METRONIDAZOLE', 'MICONAZOLE', 'MIDAZOLAM', 'MIFEPRISTONE', 'MIRTAZAPINE', 'MITOXANTRONE', 'MONTELUKAST', 'MORPHINE', 'NALOXONE', 'NAPROXEN', 'NATEGLINIDE', 'NEFAZODONE', 'NELFINAVIR', 'NEVIRAPINE', 'NICARDIPINE', 'NIFEDIPINE', 'NILOTINIB', 'NISOLDIPINE', 'NITROFURANTOIN', 'NIZATIDINE', 'NORFLOXACIN', 'NORTRIPTYLINE', 'OFLOXACIN', 'OLOPATADINE', 'OMEPRAZOLE', 'OSELTAMIVIR', 'OXCARBAZEPINE', 'PACLITAXEL', 'PANCURONIUM', 'PANTOPRAZOLE', 'PAROXETINE', 'PAZOPANIB', 'PEMETREXED', 'PHENOBARBITAL', 'PHENYTOIN', 'PIMOZIDE', 'PINDOLOL', 'PIOGLITAZONE', 'PITAVASTATIN', 'POSACONAZOLE', 'PREDNISOLONE', 'PREDNISONE', 'PRIMAQUINE', 'PRIMIDONE', 'PROCAINAMIDE', 'PROGESTERONE', 'PROMETHAZINE', 'PROPAFENONE', 'PROPRANOLOL', 'QUETIAPINE', 'QUINAPRIL', 'QUINIDINE', 'RABEPRAZOLE', 'RALOXIFENE', 'RAMIPRIL', 'RANITIDINE', 'REBOXETINE', 'REPAGLINIDE', 'RIBAVIRIN', 'RIFABUTIN', 'RILPIVIRINE', 'RISPERIDONE', 'RITONAVIR', 'RIVAROXABAN', 'ROFECOXIB', 'ROSIGLITAZONE', 'ROSUVASTATIN', 'SAQUINAVIR', 'SAXAGLIPTIN', 'SERTRALINE', 'SIMVASTATIN', 'SITAGLIPTIN', 'SORAFENIB', 'SPARFLOXACIN', 'SPIRONOLACTONE', 'SULFAMETHOXAZOLE', 'SULINDAC', 'SUMATRIPTAN', 'SUNITINIB', 'TACROLIMUS', 'TAMOXIFEN', 'TELITHROMYCIN', 'TELMISARTAN', 'TEMSIROLIMUS', 'TENIPOSIDE', 'TENOFOVIR', 'TENOXICAM', 'TERBINAFINE', 'TESTOSTERONE', 'THIOTHIXENE', 'TIMOLOL', 'TIOTROPIUM', 'TOLBUTAMIDE', 'TOLMETIN', 'TOPIRAMATE', 'TORASEMIDE', 'TOREMIFENE', 'TRAZODONE', 'TRIFLUOPERAZINE', 'TRIMIPRAMINE', 'TROGLITAZONE', 'VALSARTAN', 'VANDETANIB', 'VENLAFAXINE', 'VERAPAMIL', 'VIGABATRIN', 'VINBLASTINE', 'VINCRISTINE', 'ZAFIRLUKAST', 'ZALCITABINE', ...
# Size of intersection set 276

# %%
features_names = ["target", "enzyme", "Chem", "DGI", "transporter", "pathway", "indication"]
# SEs_names = ["SIDER", "OFFSIDES"]
# methods = ["SKR", "KR", "KRR", "Naive", "LNSM_RLN", "LNSM_jaccard", "VKR"]
methods = ["SKR", "KRR", "VKR", "Naive", "LNSM_RLN", "LNSM_jaccard"]
# methods = ["SKR", "KR", "KRR", "Naive", "LNSM_RLN", "LNSM_jaccard", "VKR", "SVM", "OCCA", "SCCA", "RF", "BRF"]
tuning_metrices=["AUROC", "AUPR", "AUROCperdrug", "AUPRperdrug"]
metrice_names = ["AUPR+AUROC", "AUPR+AUROCperdrug", "AUROC", "AUPR", "AUROCperdrug", "AUPRperdrug"]

# %%
A = 10**np.arange(-2, 3, 1, dtype=float)
B = np.arange(0.1, 1, 0.1, dtype=float)
C = np.arange(5, 205, 50, dtype=int)
C2 = np.arange(5, 20, 5, dtype=int)
A10 = 10**np.arange(1, 2, 1, dtype=float)
A100 = 10**np.arange(2, 3, 1, dtype=float)
all_hyperparlist = {
    "SKR":[A,B,A10,A100], 
    # "KR":[A,A], 
    "KRR":[A,A],
    "VKR":[A,A,C2], 
    # "Naive":[], 
    # "LNSM_RLN":[B,A], 
    # "LNSM_jaccard":[B], 
    # "SVM":[A,A,A], 
    # "OCCA":[], 
    # "SCCA":[A], 
    # "RF":[C], 
    # "BRF":[C],
    "TNMF":[C],
    "SRI":[],
    "MICE":[],
    "TRF":[],
    "TKNN":[C2],
    "TWNMF":[C]
    
}

# %%
fhyperpars = {}
fhyperpars["nested_cv"] = {}
fhyperpars["cv"] = {}
fhyperparsOut = {}
fhyperparsOut["nested_cv"] = {}
fhyperparsOut["cv"] = {}
fresults = {}
fresults["nested_cv"] = {}
fresults["cv"] = {}

# %%
# Open and read the JSON file
# with open(f'results/hyperpars_{SEs_name}.xml', 'r') as xml_file:

#     hyperpars = json.load(xml_file)

# %%
# method = "TNMF"
# validation = "nested_cv"
# fhyperparsOut[validation][method] = {}
# fresults[validation][method] = {}
# hyperparList = loadHyperpar(*all_hyperparlist[method],method_option=method)
# fresults[validation][method], fhyperparsOut[validation][method], features_new = completion(Y=SEs[SEs_name], X=features_dict, method_option=method,tuning_metrice=metrice,hyperparList=hyperparList,Validation=validation,n_jobs=3)

# validation = "cv"
# fhyperparsOut[validation][method] = {}
# fresults[validation][method] = {}
# hyperparList = loadHyperpar(*all_hyperparlist[method],method_option=method)
# fresults[validation], fhyperparsOut[validation][method], features_new = completion(Y=SEs[SEs_name], X=features_dict, method_option=method,tuning_metrice=metrice,hyperparList=hyperparList,Validation=validation,n_jobs=1)

# %%
# fhyperparsOut

# %%
# with open(f'results/fhyperpars_{SEs_name}.xml', 'w') as xml_file:
#    json.dump(fhyperparsOut, xml_file, cls=NpEncoder)
# with open(f'results/fresults_{SEs_name}_{method}.xml', 'w') as xml_file:
#    json.dump(fresults, xml_file)

# %%
# method = "KRR"
# validation = "nested_cv"
# hyperparsOut[validation][method] = {}
# results[validation][method] = {}
# str = "DGI"
# hyperparList = loadHyperpar(*all_hyperparlist[method],method_option=method)
# results[validation][method]["noAPPFC"][str], hyperparsOut[validation][method][str]["noAPPFC"] = evaluation(Y=SEs["SIDER"], X=features_dict[str], method_option=method,tuning_metrice=metrice, hyperparList=hyperparList,Validation=validation,n_jobs=1)

# %%
method = "SRI"
validation = "completion"
hyperparList = loadHyperpar(*all_hyperparlist[method],method_option=method)
features_new = completion(Y=SEs[SEs_name], X=features_dict,method_option=method,tuning_metrice=metrice,hyperparList=hyperparList,hyperparfixed=(),Validation=validation,n_jobs=1)
# Out:
# The SRI requires no hyperparameter
# common drugs chosen to be the test set:  set()
# SRI starts:
# SRI ends:

# %%
hyperpars = {}
hyperpars["nested_cv"] = {}
hyperpars["cv"] = {}
hyperparsOut = {}
hyperparsOut["nested_cv"] = {}
hyperparsOut["cv"] = {}
results = {}
results["nested_cv"] = {}
results["cv"] = {}

# %%
method = "KRR"
metrice = "AUPR"
validation = "nested_cv"
hyperparsOut[validation][method] = {}
results[validation][method] = {}
hyperparsOut[validation][method]["noAPPFC"] = {}
results[validation][method]["noAPPFC"] = {}
hyperparsOut[validation][method]["APPFC"] = {}
results[validation][method]["APPFC"] = {}
for str in features_names:
    print(f"using feature {str}")
    # print("without APPFC")
    # hyperparList = loadHyperpar(*all_hyperparlist[method],method_option=method)
    # results[validation][method]["noAPPFC"][str], hyperparsOut[validation][method]["noAPPFC"][str] = evaluation(Y=SEs[SEs_name], X=features_dict[str], method_option=method,tuning_metrice=metrice,hyperparList=hyperparList,Validation=validation,n_jobs=1)
    print("with APPFC")
    hyperparList = loadHyperpar(*all_hyperparlist[method],method_option=method)
    results[validation][method]["APPFC"][str], hyperparsOut[validation][method]["APPFC"][str] = evaluation2(Y=SEs[SEs_name], X=features_dict[str], X2=features_new[str], method_option=method,tuning_metrice=metrice,hyperparList=hyperparList,Validation=validation,n_jobs=10)
# Out:
# using feature target
# with APPFC
# The KRR requires hyperparameter lambda, sigma_X
# ---------- nested cv start ----------
# Fold: 0
# number of hyperpars combination:  25
# first few training idx:  [ 0  1  2  3  4  7  9 10 11 12]
# first few testing idx:  [ 153  283  397  440  800  857  858 1177 1230 1327]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0)
# AUPR: 0.40456389441441315
# AUPR for each fold: [0.42848554 0.40130395 0.3897826  0.39868349]
# --- tuning end ---
# target size: 142
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.45821384568125034
# AUROCperdrug: 0.8953835004601001
# AUPR+AUROCperdrug: 1.3535973461413504
# AUPR: 0.40402631828469626
# AUROC: 0.8635411281677559
# AUPR+AUROC: 1.267567446452452
# -----------
# Fold: 1
# number of hyperpars combination:  25
# first few training idx:  [ 0  1  2  3  4  7  9 10 11 12]
# first few testing idx:  [ 125  164  480  518  552  696  913  919 1277 1310]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0)
# AUPR: 0.39712219393927806
# AUPR for each fold: [0.39478444 0.43430194 0.39776396 0.36163843]
# --- tuning end ---
# target size: 142
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.46152219456068294
# AUROCperdrug: 0.9000763411537441
# AUPR+AUROCperdrug: 1.3615985357144271
# AUPR: 0.4019428977402559
# AUROC: 0.8666269579774848
# AUPR+AUROC: 1.2685698557177407
# -----------
# Fold: 2
# number of hyperpars combination:  25
# first few training idx:  [ 0  1  2  3  4  7  9 10 11 12]
# first few testing idx:  [ 210  425  672  709  807  864 1014 1027 1049 1228]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0)
# AUPR: 0.40223728078075927
# AUPR for each fold: [0.40439411 0.41244306 0.40342793 0.38868402]
# --- tuning end ---
# target size: 142
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.4481689006619399
# AUROCperdrug: 0.8931442589260332
# AUPR+AUROCperdrug: 1.341313159587973
# AUPR: 0.39709078278066456
# AUROC: 0.8685860205872864
# AUPR+AUROC: 1.2656768033679509
# -----------
# Fold: 3
# number of hyperpars combination:  25
# first few training idx:  [ 0  1  2  3  4  7  9 10 11 12]
# first few testing idx:  [  45   58   79  192  286  658  678  782  809 1022]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0)
# AUPR: 0.3871609711991959
# AUPR for each fold: [0.36672146 0.40486164 0.38095186 0.39610893]
# --- tuning end ---
# target size: 142
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.4938027524993612
# AUROCperdrug: 0.8997260028047741
# AUPR+AUROCperdrug: 1.3935287553041353
# AUPR: 0.4420562447712523
# AUROC: 0.8731338176032852
# AUPR+AUROC: 1.3151900623745376
# -----------
# Fold: 4
# number of hyperpars combination:  25
# first few training idx:  [ 0  1  2  3  4  7  9 10 11 12]
# first few testing idx:  [  46  110  294  381  396  511 1025 1066 1093 1286]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0)
# AUPR: 0.4007254589728696
# AUPR for each fold: [0.39440382 0.41610192 0.40676019 0.38563591]
# --- tuning end ---
# target size: 142
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.4480530159915469
# AUROCperdrug: 0.8984589710040175
# AUPR+AUROCperdrug: 1.3465119869955644
# AUPR: 0.39725256974623047
# AUROC: 0.8700592400875571
# AUPR+AUROC: 1.2673118098337874
# -----------
# Mean AUPRperdrug: 0.46195214187895617, std: 0.016803479097683524
# Mean AUROCperdrug: 0.8973578148697339, std: 0.0026781790516460244
# Mean AUPR+AUROCperdrug: 1.35930995674869, std: 0.01841993716632909
# Mean AUPR: 0.4084737626646199, std: 0.017004131640076976
# Mean AUROC: 0.8683894328846739, std: 0.0032233046894258317
# Mean AUPR+AUROC: 1.276863195549294, std: 0.019185950571156095
# -----------
# using feature enzyme
# with APPFC
# The KRR requires hyperparameter lambda, sigma_X
# ---------- nested cv start ----------
# Fold: 0
# number of hyperpars combination:  25
# first few training idx:  [ 0  1  2  3  4  7  9 10 11 12]
# first few testing idx:  [ 296  392  440  510  560 1147 1198 1207 1261 1300]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (10.0, 10.0)
# AUPR: 0.38972861512037527
# AUPR for each fold: [0.40500929 0.3952916  0.37579446 0.38281911]
# --- tuning end ---
# target size: 108
# ------ best hyper pars:  (10.0, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.4471103820595515
# AUROCperdrug: 0.8876970362269074
# AUPR+AUROCperdrug: 1.3348074182864589
# AUPR: 0.4068855196835319
# AUROC: 0.8722014484514247
# AUPR+AUROC: 1.2790869681349566
# -----------
# Fold: 1
# number of hyperpars combination:  25
# first few training idx:  [ 0  1  2  3  4  7  9 10 11 12]
# first few testing idx:  [ 107  110  423  445  477  660 1128 1132 1157 1162]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (10.0, 10.0)
# AUPR: 0.3866773797921803
# AUPR for each fold: [0.38921551 0.37790422 0.37063062 0.40895917]
# --- tuning end ---
# target size: 108
# ------ best hyper pars:  (10.0, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.45470753252900636
# AUROCperdrug: 0.8864017750344871
# AUPR+AUROCperdrug: 1.3411093075634934
# AUPR: 0.4123583385163818
# AUROC: 0.8698739777303507
# AUPR+AUROC: 1.2822323162467324
# -----------
# Fold: 2
# number of hyperpars combination:  25
# first few training idx:  [ 0  1  2  3  4  7  9 10 11 12]
# first few testing idx:  [  67  164  302  334  387  390  509  721  787 1102]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (10.0, 10.0)
# AUPR: 0.40203584244799234
# AUPR for each fold: [0.41227646 0.39100987 0.42903893 0.37581811]
# --- tuning end ---
# target size: 108
# ------ best hyper pars:  (10.0, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.42057013955741857
# AUROCperdrug: 0.8860379694046285
# AUPR+AUROCperdrug: 1.3066081089620472
# AUPR: 0.35872951559594424
# AUROC: 0.8650096564792857
# AUPR+AUROC: 1.22373917207523
# -----------
# Fold: 3
# number of hyperpars combination:  25
# first few training idx:  [ 0  1  2  3  4  7  9 10 11 12]
# first few testing idx:  [  80   87  393  521  558  593  873 1101 1125 1253]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (10.0, 10.0)
# AUPR: 0.38826100751103676
# AUPR for each fold: [0.35534976 0.39743919 0.39762922 0.40262587]
# --- tuning end ---
# target size: 108
# ------ best hyper pars:  (10.0, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.44574621013799554
# AUROCperdrug: 0.8856442617939655
# AUPR+AUROCperdrug: 1.331390471931961
# AUPR: 0.4124825933624545
# AUROC: 0.87241618740345
# AUPR+AUROC: 1.2848987807659045
# -----------
# Fold: 4
# number of hyperpars combination:  25
# first few training idx:  [ 0  1  2  3  4  7  9 10 11 12]
# first few testing idx:  [ 139  209  404  504  512  623  697  983 1163 1192]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (10.0, 10.0)
# AUPR: 0.3972275103339552
# AUPR for each fold: [0.39211983 0.37783142 0.40358697 0.41537182]
# --- tuning end ---
# target size: 108
# ------ best hyper pars:  (10.0, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.4359763934688957
# AUROCperdrug: 0.8843172626714962
# AUPR+AUROCperdrug: 1.320293656140392
# AUPR: 0.38270432777289576
# AUROC: 0.8547247266692322
# AUPR+AUROC: 1.2374290544421278
# -----------
# Mean AUPRperdrug: 0.44082213155057354, std: 0.011749190286804179
# Mean AUROCperdrug: 0.8860196610262969, std: 0.0010953555238057248
# Mean AUPR+AUROCperdrug: 1.3268417925768705, std: 0.012165391108630253
# Mean AUPR: 0.39463205898624165, std: 0.02104411203328416
# Mean AUROC: 0.8668451993467488, std: 0.006620783736702836
# Mean AUPR+AUROC: 1.2614772583329903, std: 0.02565899953685806
# -----------
# using feature Chem
# with APPFC
# The KRR requires hyperparameter lambda, sigma_X
# ---------- nested cv start ----------
# Fold: 0
# number of hyperpars combination:  25
# first few training idx:  [ 0  1  2  3  4  7  9 10 11 12]
# first few testing idx:  [  42  356  481  524  545  661  770 1235 1312 1331]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (10.0, 10.0)
# AUPR: 0.39736204459003055
# AUPR for each fold: [0.41329752 0.39895373 0.38227089 0.39492604]
# --- tuning end ---
# target size: 129
# ------ best hyper pars:  (10.0, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.44933909819293627
# AUROCperdrug: 0.8946753945635139
# AUPR+AUROCperdrug: 1.3440144927564501
# AUPR: 0.3935331869081746
# AUROC: 0.8689242510558527
# AUPR+AUROC: 1.2624574379640272
# -----------
# Fold: 1
# number of hyperpars combination:  25
# first few training idx:  [ 0  1  2  3  4  7  9 10 11 12]
# first few testing idx:  [  89   92   94  146  199  205  398  813 1183 1228]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (10.0, 10.0)
# AUPR: 0.3837784205639154
# AUPR for each fold: [0.3652531  0.378882   0.40247174 0.38850684]
# --- tuning end ---
# target size: 129
# ------ best hyper pars:  (10.0, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.49164978306207835
# AUROCperdrug: 0.8982697541483375
# AUPR+AUROCperdrug: 1.3899195372104158
# AUPR: 0.4345939389362259
# AUROC: 0.8763588388782056
# AUPR+AUROC: 1.3109527778144314
# -----------
# Fold: 2
# number of hyperpars combination:  25
# first few training idx:  [ 0  1  2  3  4  7  9 10 11 12]
# first few testing idx:  [  80  211  312  439  660  765  909  911  962 1240]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (10.0, 10.0)
# AUPR: 0.3899462894103942
# AUPR for each fold: [0.40284316 0.3899552  0.38517581 0.38181099]
# --- tuning end ---
# target size: 129
# ------ best hyper pars:  (10.0, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.4611552946399728
# AUROCperdrug: 0.8937598061345867
# AUPR+AUROCperdrug: 1.3549151007745595
# AUPR: 0.40264415017327326
# AUROC: 0.871246288565367
# AUPR+AUROC: 1.2738904387386403
# -----------
# Fold: 3
# number of hyperpars combination:  25
# first few training idx:  [ 0  1  2  3  4  7  9 10 11 12]
# first few testing idx:  [  56  176  208  339  386  554  616  808 1016 1253]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (10.0, 10.0)
# AUPR: 0.3985222600450309
# AUPR for each fold: [0.39103681 0.38975966 0.41890843 0.39438414]
# --- tuning end ---
# target size: 129
# ------ best hyper pars:  (10.0, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.440651773477929
# AUROCperdrug: 0.8919561598419329
# AUPR+AUROCperdrug: 1.332607933319862
# AUPR: 0.38092465707486545
# AUROC: 0.8647067011870146
# AUPR+AUROC: 1.24563135826188
# -----------
# Fold: 4
# number of hyperpars combination:  25
# first few training idx:  [ 0  1  2  3  4  7  9 10 11 12]
# first few testing idx:  [  48  115  232  242  316  546 1049 1084 1126 1283]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (10.0, 10.0)
# AUPR: 0.39866424402018175
# AUPR for each fold: [0.40109241 0.39927339 0.41369255 0.38059861]
# --- tuning end ---
# target size: 129
# ------ best hyper pars:  (10.0, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.44336381360065763
# AUROCperdrug: 0.888513297160033
# AUPR+AUROCperdrug: 1.3318771107606906
# AUPR: 0.38382405917396817
# AUROC: 0.8499534257384114
# AUPR+AUROC: 1.2337774849123795
# -----------
# Mean AUPRperdrug: 0.45723195259471483, std: 0.018598410879401128
# Mean AUROCperdrug: 0.8934348823696808, std: 0.003207149898648128
# Mean AUPR+AUROCperdrug: 1.3506668349643955, std: 0.02136470789464897
# Mean AUPR: 0.39910399845330147, std: 0.019323909999206083
# Mean AUROC: 0.8662379010849703, std: 0.008969531911695045
# Mean AUPR+AUROC: 1.2653418995382717, std: 0.02663294037931135
# -----------
# using feature DGI
# with APPFC
# The KRR requires hyperparameter lambda, sigma_X
# ---------- nested cv start ----------
# Fold: 0
# number of hyperpars combination:  25
# first few training idx:  [ 0  1  2  3  4  7  9 10 11 12]
# first few testing idx:  [ 167  216  247  334  416  604  681  786 1162 1222]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (1.0, 10.0)
# AUPR: 0.4038294189956714
# AUPR for each fold: [0.40869661 0.40718344 0.39776581 0.40167182]
# --- tuning end ---
# target size: 150
# ------ best hyper pars:  (1.0, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.4483761339525286
# AUROCperdrug: 0.8956747425969889
# AUPR+AUROCperdrug: 1.3440508765495176
# AUPR: 0.41661964001245777
# AUROC: 0.8792086428339712
# AUPR+AUROC: 1.295828282846429
# -----------
# Fold: 1
# number of hyperpars combination:  25
# first few training idx:  [ 0  1  2  3  4  7  9 10 12 13]
# first few testing idx:  [  92  102  121  206  316  433  442  460  739 1262]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0)
# AUPR: 0.4065216582768285
# AUPR for each fold: [0.4326074  0.41219751 0.4166162  0.36466552]
# --- tuning end ---
# target size: 150
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.4553620040066253
# AUROCperdrug: 0.8841524775735615
# AUPR+AUROCperdrug: 1.3395144815801867
# AUPR: 0.4008846606257249
# AUROC: 0.8456352420671306
# AUPR+AUROC: 1.2465199026928555
# -----------
# Fold: 2
# number of hyperpars combination:  25
# first few training idx:  [ 0  1  2  3  4  7  9 10 11 12]
# first few testing idx:  [ 23 191 197 388 398 526 709 838 928 958]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0)
# AUPR: 0.4053774680249848
# AUPR for each fold: [0.40982655 0.40915849 0.41448104 0.38804378]
# --- tuning end ---
# target size: 150
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.4558050277125806
# AUROCperdrug: 0.88285968302193
# AUPR+AUROCperdrug: 1.3386647107345104
# AUPR: 0.4333902484569538
# AUROC: 0.8636709026798473
# AUPR+AUROC: 1.297061151136801
# -----------
# Fold: 3
# number of hyperpars combination:  25
# first few training idx:  [ 0  1  2  3  4  7  9 10 11 12]
# first few testing idx:  [  78  210  226  431  530  750  766  784 1166 1246]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0)
# AUPR: 0.4104237310802968
# AUPR for each fold: [0.40894832 0.40214861 0.41928157 0.41131642]
# --- tuning end ---
# target size: 150
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.44650234685523554
# AUROCperdrug: 0.8720353964391943
# AUPR+AUROCperdrug: 1.3185377432944299
# AUPR: 0.4079830745654529
# AUROC: 0.8337725604432293
# AUPR+AUROC: 1.2417556350086822
# -----------
# Fold: 4
# number of hyperpars combination:  25
# first few training idx:  [ 0  1  2  3  4  7  9 10 11 12]
# first few testing idx:  [  42   94  201  209  462  910  912 1075 1128 1303]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0)
# AUPR: 0.4090723165295246
# AUPR for each fold: [0.42903091 0.39895896 0.39005589 0.41824351]
# --- tuning end ---
# target size: 150
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.4591605970769206
# AUROCperdrug: 0.8781050931333565
# AUPR+AUROCperdrug: 1.337265690210277
# AUPR: 0.4291354807890003
# AUROC: 0.8439801120089003
# AUPR+AUROC: 1.2731155927979008
# -----------
# Mean AUPRperdrug: 0.4530412219207781, std: 0.004795650886390382
# Mean AUROCperdrug: 0.8825654785530063, std: 0.007813265557384838
# Mean AUPR+AUROCperdrug: 1.3356067004737842, std: 0.00883207603754262
# Mean AUPR: 0.4176026208899179, std: 0.012290225058447145
# Mean AUROC: 0.8532534920066157, std: 0.016160026626867698
# Mean AUPR+AUROC: 1.2708561128965337, std: 0.023471290935881437
# -----------
# using feature transporter
# with APPFC
# The KRR requires hyperparameter lambda, sigma_X
# ---------- nested cv start ----------
# Fold: 0
# number of hyperpars combination:  25
# first few training idx:  [ 0  1  2  3  4  7  9 10 11 12]
# first few testing idx:  [ 131  255  305  371  509  654 1015 1028 1128 1242]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (1.0, 10.0)
# AUPR: 0.4291280397713726
# AUPR for each fold: [0.40455263 0.4119303  0.43831227 0.46171697]
# --- tuning end ---
# target size: 74
# ------ best hyper pars:  (1.0, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.45298205974414196
# AUROCperdrug: 0.877371653884023
# AUPR+AUROCperdrug: 1.3303537136281651
# AUPR: 0.38420678465184505
# AUROC: 0.8412927485565623
# AUPR+AUROC: 1.2254995332084073
# -----------
# Fold: 1
# number of hyperpars combination:  25
# first few training idx:  [ 0  1  2  3  4  7  9 10 11 12]
# first few testing idx:  [ 233  518  545  551  617  717  939 1008 1226 1306]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (1.0, 10.0)
# AUPR: 0.4084340418984507
# AUPR for each fold: [0.3884764  0.40063015 0.41647119 0.42815843]
# --- tuning end ---
# target size: 74
# ------ best hyper pars:  (1.0, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.524001605827908
# AUROCperdrug: 0.8915014724370509
# AUPR+AUROCperdrug: 1.415503078264959
# AUPR: 0.4681830456395171
# AUROC: 0.8682939079539613
# AUPR+AUROC: 1.3364769535934784
# -----------
# Fold: 2
# number of hyperpars combination:  25
# first few training idx:  [ 0  1  2  3  4  7  9 10 11 12]
# first few testing idx:  [  45  254  267  319  393  422  635  871 1017 1162]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (1.0, 10.0)
# AUPR: 0.4214316249694937
# AUPR for each fold: [0.43716306 0.41760409 0.40682846 0.42413089]
# --- tuning end ---
# target size: 74
# ------ best hyper pars:  (1.0, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.46272816436277237
# AUROCperdrug: 0.885652081008592
# AUPR+AUROCperdrug: 1.3483802453713645
# AUPR: 0.4147078861812386
# AUROC: 0.8646720551730678
# AUPR+AUROC: 1.2793799413543063
# -----------
# Fold: 3
# number of hyperpars combination:  25
# first few training idx:  [ 0  1  2  3  4  7  9 10 11 12]
# first few testing idx:  [ 604  676  764  790  910  932  969 1102 1158 1243]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (1.0, 10.0)
# AUPR: 0.4254311114305963
# AUPR for each fold: [0.45038116 0.40616733 0.42911774 0.41605821]
# --- tuning end ---
# target size: 74
# ------ best hyper pars:  (1.0, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.43911124154893666
# AUROCperdrug: 0.8802219090484197
# AUPR+AUROCperdrug: 1.3193331505973562
# AUPR: 0.3940504700919488
# AUROC: 0.8530175430061824
# AUPR+AUROC: 1.247068013098131
# -----------
# Fold: 4
# number of hyperpars combination:  25
# first few training idx:  [ 0  1  2  3  4  7  9 10 11 12]
# first few testing idx:  [ 379  679  692  750  795  809  882  984 1010 1327]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (1.0, 10.0)
# AUPR: 0.4120065601173081
# AUPR for each fold: [0.39396703 0.41395257 0.41933311 0.42077352]
# --- tuning end ---
# target size: 74
# ------ best hyper pars:  (1.0, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.4966240072868489
# AUROCperdrug: 0.8907075099118208
# AUPR+AUROCperdrug: 1.3873315171986698
# AUPR: 0.4525362317666286
# AUROC: 0.870152151399384
# AUPR+AUROC: 1.3226883831660126
# -----------
# Mean AUPRperdrug: 0.4750894157541216, std: 0.030958377590391814
# Mean AUROCperdrug: 0.8850909252579813, std: 0.00559017895024929
# Mean AUPR+AUROCperdrug: 1.360180341012103, std: 0.036042071384624806
# Mean AUPR: 0.4227368836662356, std: 0.03263525222742422
# Mean AUROC: 0.8594856812178315, std: 0.010872686235839266
# Mean AUPR+AUROC: 1.282222564884067, std: 0.042526336512187915
# -----------
# using feature pathway
# with APPFC
# The KRR requires hyperparameter lambda, sigma_X
# ---------- nested cv start ----------
# Fold: 0
# number of hyperpars combination:  25
# first few training idx:  [ 0  1  2  3  4  7  9 10 11 12]
# first few testing idx:  [ 142  212  239  421  476  926 1006 1017 1211 1228]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0)
# AUPR: 0.4340878974249769
# AUPR for each fold: [0.42729491 0.44848425 0.43905592 0.42151651]
# --- tuning end ---
# target size: 106
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.47109605502777374
# AUROCperdrug: 0.8997861197602711
# AUPR+AUROCperdrug: 1.3708821747880449
# AUPR: 0.41109912289514394
# AUROC: 0.8675071031061429
# AUPR+AUROC: 1.278606226001287
# -----------
# Fold: 1
# number of hyperpars combination:  25
# first few training idx:  [ 0  1  2  3  4  7  9 10 11 12]
# first few testing idx:  [ 242  315  495  545  711  984 1003 1049 1144 1221]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0)
# AUPR: 0.4236196158627062
# AUPR for each fold: [0.41329662 0.42567867 0.41739341 0.43810976]
# --- tuning end ---
# target size: 106
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.4943201974992955
# AUROCperdrug: 0.9082724446232202
# AUPR+AUROCperdrug: 1.4025926421225157
# AUPR: 0.457099684727152
# AUROC: 0.8812514333287038
# AUPR+AUROC: 1.3383511180558558
# -----------
# Fold: 2
# number of hyperpars combination:  25
# first few training idx:  [ 0  1  2  3  4  7  9 10 11 12]
# first few testing idx:  [  72  154  171  307  395  511  524  755 1080 1091]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0)
# AUPR: 0.4277539442463922
# AUPR for each fold: [0.42887821 0.41703546 0.41154992 0.45355218]
# --- tuning end ---
# target size: 106
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.48983945172085636
# AUROCperdrug: 0.9005183488452705
# AUPR+AUROCperdrug: 1.3903578005661268
# AUPR: 0.4409097132963574
# AUROC: 0.87047668697903
# AUPR+AUROC: 1.3113864002753874
# -----------
# Fold: 3
# number of hyperpars combination:  25
# first few training idx:  [ 0  1  2  3  4  7  9 10 11 12]
# first few testing idx:  [  92  267  286  543  559  598  651  654 1059 1094]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0)
# AUPR: 0.4322900473490927
# AUPR for each fold: [0.414464   0.44661758 0.43330571 0.4347729 ]
# --- tuning end ---
# target size: 106
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.48780765244275
# AUROCperdrug: 0.9027835550544722
# AUPR+AUROCperdrug: 1.3905912074972222
# AUPR: 0.437747531903841
# AUROC: 0.8731624626341734
# AUPR+AUROC: 1.3109099945380145
# -----------
# Fold: 4
# number of hyperpars combination:  25
# first few training idx:  [ 0  1  2  3  4  7  9 10 11 12]
# first few testing idx:  [  80  289  416  526  685  834  972 1029 1102 1261]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0)
# AUPR: 0.42801206018372145
# AUPR for each fold: [0.42397741 0.45766708 0.41072596 0.41967779]
# --- tuning end ---
# target size: 106
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.49713994839205644
# AUROCperdrug: 0.9068447337525499
# AUPR+AUROCperdrug: 1.4039846821446065
# AUPR: 0.4639819598755176
# AUROC: 0.8824612379808411
# AUPR+AUROC: 1.3464431978563587
# -----------
# Mean AUPRperdrug: 0.48804066101654636, std: 0.009084483719930574
# Mean AUROCperdrug: 0.9036410404071568, std: 0.0033781785914429184
# Mean AUPR+AUROCperdrug: 1.3916817014237033, std: 0.011882543164691338
# Mean AUPR: 0.44216760253960236, std: 0.018358665537703194
# Mean AUROC: 0.8749717848057783, std: 0.00591146206115727
# Mean AUPR+AUROC: 1.3171393873453807, std: 0.023938912040203313
# -----------
# using feature indication
# with APPFC
# The KRR requires hyperparameter lambda, sigma_X
# ---------- nested cv start ----------
# Fold: 0
# number of hyperpars combination:  25
# first few training idx:  [ 0  1  2  3  4  7 10 11 12 13]
# first few testing idx:  [  74  231  339  343  374  412  752  811  823 1329]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0)
# AUPR: 0.44792869399835633
# AUPR for each fold: [0.42512223 0.44201592 0.45328376 0.47129287]
# --- tuning end ---
# target size: 193
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.46973983712391726
# AUROCperdrug: 0.8878340842304231
# AUPR+AUROCperdrug: 1.3575739213543403
# AUPR: 0.45226794769576373
# AUROC: 0.865644993299857
# AUPR+AUROC: 1.3179129409956207
# -----------
# Fold: 1
# number of hyperpars combination:  25
# first few training idx:  [ 0  1  2  3  9 10 11 12 16 17]
# first few testing idx:  [  85  361  455  534  543  588  770  839 1243 1247]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0)
# AUPR: 0.43836261009895106
# AUPR for each fold: [0.42740187 0.47730226 0.39799347 0.45075284]
# --- tuning end ---
# target size: 193
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.45872170014081215
# AUROCperdrug: 0.8920818852448601
# AUPR+AUROCperdrug: 1.3508035853856724
# AUPR: 0.4673133734360987
# AUROC: 0.8782133815055821
# AUPR+AUROC: 1.3455267549416807
# -----------
# Fold: 2
# number of hyperpars combination:  25
# first few training idx:  [ 1  2  3  4  7  9 10 11 13 17]
# first few testing idx:  [ 114  243  391  449  758  759  877  992 1040 1186]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0)
# AUPR: 0.4440229616882036
# AUPR for each fold: [0.44611909 0.45273052 0.43471139 0.44253086]
# --- tuning end ---
# target size: 193
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.4651915810152881
# AUROCperdrug: 0.8938183423022608
# AUPR+AUROCperdrug: 1.359009923317549
# AUPR: 0.45022583752157463
# AUROC: 0.8692830763477607
# AUPR+AUROC: 1.3195089138693352
# -----------
# Fold: 3
# number of hyperpars combination:  25
# first few training idx:  [ 0  1  2  3  4  7  9 11 12 13]
# first few testing idx:  [  19   87  512  638  694  943 1098 1137 1249 1284]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0)
# AUPR: 0.43768135200301705
# AUPR for each fold: [0.42121288 0.43322435 0.44731017 0.44897801]
# --- tuning end ---
# target size: 193
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.47270386358326366
# AUROCperdrug: 0.8934197174201607
# AUPR+AUROCperdrug: 1.3661235810034245
# AUPR: 0.4671373864542348
# AUROC: 0.8730490800504238
# AUPR+AUROC: 1.3401864665046586
# -----------
# Fold: 4
# number of hyperpars combination:  25
# first few training idx:  [ 0  1  3  4  7  9 10 12 13 16]
# first few testing idx:  [  22   70  161  218  381  883  956 1085 1110 1281]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0)
# AUPR: 0.44700405235215296
# AUPR for each fold: [0.42502413 0.4442779  0.46841179 0.45030239]
# --- tuning end ---
# target size: 193
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.460799824404727
# AUROCperdrug: 0.8943413354484129
# AUPR+AUROCperdrug: 1.3551411598531398
# AUPR: 0.45736165551078567
# AUROC: 0.8733686232576564
# AUPR+AUROC: 1.330730278768442
# -----------
# Mean AUPRperdrug: 0.46543136125360157, std: 0.005253197785229113
# Mean AUROCperdrug: 0.8922990729292234, std: 0.0023544916339140864
# Mean AUPR+AUROCperdrug: 1.3577304341828254, std: 0.00503571401246095
# Mean AUPR: 0.4588612401236915, std: 0.007214202558389238
# Mean AUROC: 0.871911830892256, std: 0.00422631573928554
# Mean AUPR+AUROC: 1.3307730710159476, std: 0.010941199345108904
# -----------

# %%
method = "KRR"
validation = "cv"
hyperparsOut[validation][method] = {}
results[validation][method] = {}
hyperparsOut[validation][method]["noAPPFC"] = {}
results[validation][method]["noAPPFC"] = {}
hyperparsOut[validation][method]["APPFC"] = {}
results[validation][method]["APPFC"] = {}
for str in features_names:
    print(f"using feature {str}")
    # print("without APPFC")
    # hyperparList = loadHyperpar(*all_hyperparlist[method],method_option=method)
    # results[validation][method]["noAPPFC"][str], hyperparsOut[validation][method]["noAPPFC"][str] = evaluation(Y=SEs[SEs_name], X=features_dict[str], method_option=method,tuning_metrice=metrice,hyperparList=hyperparList,Validation=validation,n_jobs=1)
    print("with APPFC")
    hyperparList = loadHyperpar(*all_hyperparlist[method],method_option=method)
    results[validation][method]["APPFC"][str], hyperparsOut[validation][method]["APPFC"][str] = evaluation2(Y=SEs[SEs_name], X=features_dict[str], X2=features_new[str], method_option=method,tuning_metrice=metrice,hyperparList=hyperparList,Validation=validation,n_jobs=10)
# Out:
# using feature target
# with APPFC
# The KRR requires hyperparameter lambda, sigma_X
# ---------- cv start ----------
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# best hyperpar: (0.1, 10.0)
# AUPR: 0.4084737626646199
# AUPR for each fold: [0.40402632 0.4019429  0.39709078 0.44205624 0.39725257]
# --- tuning end ---
# target size: 227
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.4721830315540797
# AUROCperdrug: 0.8976792883282373
# AUPR+AUROCperdrug: 1.369862319882317
# AUPR: 0.4182427218163188
# AUROC: 0.8679787471602908
# AUPR+AUROC: 1.2862214689766096
# -----------
# using feature enzyme
# with APPFC
# The KRR requires hyperparameter lambda, sigma_X
# ---------- cv start ----------
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# best hyperpar: (10.0, 10.0)
# AUPR: 0.39463205898624165
# AUPR for each fold: [0.40688552 0.41235834 0.35872952 0.41248259 0.38270433]
# --- tuning end ---
# target size: 175
# ------ best hyper pars:  (10.0, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.47744233736553593
# AUROCperdrug: 0.8829597273319926
# AUPR+AUROCperdrug: 1.3604020646975286
# AUPR: 0.4273406805830272
# AUROC: 0.8622329619308555
# AUPR+AUROC: 1.2895736425138828
# -----------
# using feature Chem
# with APPFC
# The KRR requires hyperparameter lambda, sigma_X
# ---------- cv start ----------
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# best hyperpar: (10.0, 10.0)
# AUPR: 0.39910399845330147
# AUPR for each fold: [0.39353319 0.43459394 0.40264415 0.38092466 0.38382406]
# --- tuning end ---
# target size: 212
# ------ best hyper pars:  (10.0, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.47029706478092453
# AUROCperdrug: 0.89167936055575
# AUPR+AUROCperdrug: 1.3619764253366746
# AUPR: 0.4086109093367922
# AUROC: 0.862765522589012
# AUPR+AUROC: 1.271376431925804
# -----------
# using feature DGI
# with APPFC
# The KRR requires hyperparameter lambda, sigma_X
# ---------- cv start ----------
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# best hyperpar: (0.1, 10.0)
# AUPR: 0.41650799865784344
# AUPR for each fold: [0.41114653 0.40088466 0.43339025 0.40798307 0.42913548]
# --- tuning end ---
# target size: 241
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.4692039558316218
# AUROCperdrug: 0.8811371124377071
# AUPR+AUROCperdrug: 1.3503410682693289
# AUPR: 0.44342887919371976
# AUROC: 0.8520583190434683
# AUPR+AUROC: 1.295487198237188
# -----------
# using feature transporter
# with APPFC
# The KRR requires hyperparameter lambda, sigma_X
# ---------- cv start ----------
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# best hyperpar: (1.0, 10.0)
# AUPR: 0.4227368836662356
# AUPR for each fold: [0.38420678 0.46818305 0.41470789 0.39405047 0.45253623]
# --- tuning end ---
# target size: 110
# ------ best hyper pars:  (1.0, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.507240378148377
# AUROCperdrug: 0.8821863657123117
# AUPR+AUROCperdrug: 1.3894267438606887
# AUPR: 0.4563261325803217
# AUROC: 0.8630371717772878
# AUPR+AUROC: 1.3193633043576094
# -----------
# using feature pathway
# with APPFC
# The KRR requires hyperparameter lambda, sigma_X
# ---------- cv start ----------
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# best hyperpar: (0.1, 10.0)
# AUPR: 0.44216760253960236
# AUPR for each fold: [0.41109912 0.45709968 0.44090971 0.43774753 0.46398196]
# --- tuning end ---
# target size: 180
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.5112918390098018
# AUROCperdrug: 0.9041877364327048
# AUPR+AUROCperdrug: 1.4154795754425065
# AUPR: 0.46417734522466947
# AUROC: 0.874428293424764
# AUPR+AUROC: 1.3386056386494336
# -----------
# using feature indication
# with APPFC
# The KRR requires hyperparameter lambda, sigma_X
# ---------- cv start ----------
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# best hyperpar: (0.1, 10.0)
# AUPR: 0.4588612401236915
# AUPR for each fold: [0.45226795 0.46731337 0.45022584 0.46713739 0.45736166]
# --- tuning end ---
# target size: 315
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.48225447608951294
# AUROCperdrug: 0.8945959189240666
# AUPR+AUROCperdrug: 1.3768503950135795
# AUPR: 0.4807090935362547
# AUROC: 0.8729248061260554
# AUPR+AUROC: 1.35363389966231
# -----------

# %%
df = pd.DataFrame()
for m, fs in results["nested_cv"]["KRR"].items():
    for f, mes in fs.items():
        for me, scores in mes.items():
            temp_df = pd.DataFrame({
                'method': m,
                'feature': f,
                'metric': me,
                "score": scores
            })
            df = pd.concat([df, temp_df], ignore_index=True)

custom_order = ["pathway","Chem", "DGI", "indication", "target", "transporter", "enzyme"]
metrice_names = ["AUROC", "AUPR", "AUROCperdrug", "AUPRperdrug"]
# APPFC = ["APPFC", "noAPPFC"]
df['feature'] = pd.Categorical(df['feature'], categories=custom_order, ordered=True)
# df['method'] = pd.Categorical(df['method'], categories=APPFC, ordered=True)
df['metric'] = pd.Categorical(df['metric'], categories=metrice_names, ordered=True)
df2 = pd.pivot_table(df, values=['score'], index=["feature", "method"], aggfunc={'score': ["mean","std"]}, columns=["metric"])
df3 = df2.sort_index(axis=1, level='metric').sort_index(level='feature')
df3.to_excel(f'results/nested_cv_results_{SEs_name}_{method}_SRI.xlsx')
df3
# Out:
#                        score                                             \
#                         mean       std      mean       std         mean
# metric                 AUROC     AUROC      AUPR      AUPR AUROCperdrug
# feature     method
# pathway     APPFC   0.874972  0.006609  0.442168  0.020526     0.903641
# Chem        APPFC   0.866238  0.010028  0.399104  0.021605     0.893435
# DGI         APPFC   0.853253  0.018067  0.417603  0.013741     0.882565
# indication  APPFC   0.871912  0.004725  0.458861  0.008066     0.892299
# target      APPFC   0.868389  0.003604  0.408474  0.019011     0.897358
# transporter APPFC   0.859486  0.012156  0.422737  0.036487     0.885091
# enzyme      APPFC   0.866845  0.007402  0.394632  0.023528     0.886020
#
#
#                             std        mean         std
# metric             AUROCperdrug AUPRperdrug AUPRperdrug
# feature     method
# pathway     APPFC      0.003777    0.488041    0.010157
# Chem        APPFC      0.003586    0.457232    0.020794
# DGI         APPFC      0.008735    0.453041    0.005362
# indication  APPFC      0.002632    0.465431    0.005873
# target      APPFC      0.002994    0.461952    0.018787
# transporter APPFC      0.006250    0.475089    0.034613
# enzyme      APPFC      0.001225    0.440822    0.013136

# %%
df = pd.DataFrame()
for m, fs in results["cv"]["KRR"].items():
    for f, mes in fs.items():
        for me, scores in mes.items():
            temp_df = pd.DataFrame({
                'method': m,
                'feature': f,
                'metric': me,
                "score": scores
            },index=["1"])
            df = pd.concat([df, temp_df], ignore_index=True)
df['feature'] = pd.Categorical(df['feature'], categories=custom_order, ordered=True)
# df['method'] = pd.Categorical(df['method'], categories=APPFC, ordered=True)
df['metric'] = pd.Categorical(df['metric'], categories=metrice_names, ordered=True)
df2 = pd.pivot_table(df, values=['score'], index=["feature", "method"], columns="metric")
df2.to_excel(f'results/cv_results_{SEs_name}_{method}_SRI.xlsx')
df2
# Out:
#                        score
# metric                 AUROC      AUPR AUROCperdrug AUPRperdrug
# feature     method
# pathway     APPFC   0.874428  0.464177     0.904188    0.511292
# Chem        APPFC   0.862766  0.408611     0.891679    0.470297
# DGI         APPFC   0.852058  0.443429     0.881137    0.469204
# indication  APPFC   0.872925  0.480709     0.894596    0.482254
# target      APPFC   0.867979  0.418243     0.897679    0.472183
# transporter APPFC   0.863037  0.456326     0.882186    0.507240
# enzyme      APPFC   0.862233  0.427341     0.882960    0.477442

# %%
method = "TKNN"
validation = "nested_cv"
fhyperparsOut[validation][method] = {}
fresults[validation][method] = {}
hyperparList = loadHyperpar(*all_hyperparlist[method],method_option=method)
fresults[validation][method], fhyperparsOut[validation][method], features_new = completion(Y=SEs[SEs_name], X=features_dict, method_option=method,tuning_metrice=metrice,hyperparList=hyperparList,Validation=validation,n_jobs=1)

validation = "cv"
fhyperparsOut[validation][method] = {}
fresults[validation][method] = {}
hyperparList = loadHyperpar(*all_hyperparlist[method],method_option=method)
fresults[validation], fhyperparsOut[validation][method], features_new = completion(Y=SEs[SEs_name], X=features_dict, method_option=method,tuning_metrice=metrice,hyperparList=hyperparList,Validation=validation,n_jobs=1)
# Out:
# The TKNN requires hyperparameter k
# common drugs chosen to be the test set:  set()
# ---------- nested cv start ----------
# Fold: 0
# number of hyperpars combination:  3
# Inner Fold: 0
# Imputing row 1/1344 with 8021 missing, elapsed time: 220.607
# Imputing row 1/1344 with 8021 missing, elapsed time: 221.668
# Imputing row 1/1344 with 8021 missing, elapsed time: 221.611
# Imputing row 1/1344 with 8021 missing, elapsed time: 222.117
# Imputing row 101/1344 with 2283 missing, elapsed time: 256.244
# Imputing row 101/1344 with 2283 missing, elapsed time: 260.844
# Imputing row 101/1344 with 2283 missing, elapsed time: 260.937
# Imputing row 101/1344 with 2283 missing, elapsed time: 262.962
# Imputing row 201/1344 with 8021 missing, elapsed time: 291.002
# Imputing row 201/1344 with 8021 missing, elapsed time: 295.927
# Imputing row 201/1344 with 8021 missing, elapsed time: 296.099
# Imputing row 201/1344 with 8021 missing, elapsed time: 296.687
# Imputing row 301/1344 with 10982 missing, elapsed time: 328.405
# Imputing row 301/1344 with 10982 missing, elapsed time: 334.012
# Imputing row 301/1344 with 10982 missing, elapsed time: 334.112
# Imputing row 301/1344 with 10982 missing, elapsed time: 334.178
# Imputing row 401/1344 with 4905 missing, elapsed time: 373.742
# Imputing row 401/1344 with 4905 missing, elapsed time: 379.971
# Imputing row 401/1344 with 4905 missing, elapsed time: 380.617
# Imputing row 401/1344 with 4905 missing, elapsed time: 379.428
# Imputing row 501/1344 with 10982 missing, elapsed time: 404.958
# Imputing row 501/1344 with 10982 missing, elapsed time: 411.812
# Imputing row 501/1344 with 10982 missing, elapsed time: 412.810
# Imputing row 501/1344 with 10982 missing, elapsed time: 410.985
# Imputing row 601/1344 with 11072 missing, elapsed time: 444.140
# Imputing row 601/1344 with 11072 missing, elapsed time: 452.306
# Imputing row 601/1344 with 11072 missing, elapsed time: 453.883
# Imputing row 601/1344 with 11072 missing, elapsed time: 451.415
# Imputing row 701/1344 with 555 missing, elapsed time: 482.094
# Imputing row 701/1344 with 555 missing, elapsed time: 490.356
# Imputing row 701/1344 with 555 missing, elapsed time: 492.183
# Imputing row 701/1344 with 555 missing, elapsed time: 488.092
# Imputing row 801/1344 with 830 missing, elapsed time: 521.418
# Imputing row 801/1344 with 830 missing, elapsed time: 530.038
# Imputing row 801/1344 with 830 missing, elapsed time: 532.837
# Imputing row 801/1344 with 830 missing, elapsed time: 527.699
# Imputing row 901/1344 with 6632 missing, elapsed time: 555.364
# Imputing row 901/1344 with 6632 missing, elapsed time: 564.453
# Imputing row 901/1344 with 6632 missing, elapsed time: 567.994
# Imputing row 901/1344 with 6632 missing, elapsed time: 561.676
# Imputing row 1001/1344 with 90 missing, elapsed time: 595.233
# Imputing row 1001/1344 with 90 missing, elapsed time: 604.154
# Imputing row 1001/1344 with 90 missing, elapsed time: 608.121
# Imputing row 1001/1344 with 90 missing, elapsed time: 600.610
# Imputing row 1101/1344 with 2558 missing, elapsed time: 626.698
# Imputing row 1101/1344 with 2558 missing, elapsed time: 636.005
# Imputing row 1101/1344 with 2558 missing, elapsed time: 640.359
# Imputing row 1101/1344 with 2558 missing, elapsed time: 632.027
# Imputing row 1201/1344 with 8699 missing, elapsed time: 664.865
# Imputing row 1201/1344 with 8699 missing, elapsed time: 674.377
# Imputing row 1201/1344 with 8699 missing, elapsed time: 679.064
# Imputing row 1201/1344 with 8699 missing, elapsed time: 669.598
# Imputing row 1301/1344 with 90 missing, elapsed time: 705.347
# Imputing row 1301/1344 with 90 missing, elapsed time: 715.596
# Imputing row 1301/1344 with 90 missing, elapsed time: 710.167
# Imputing row 1301/1344 with 90 missing, elapsed time: 720.985
# [KNN] Warning: 752896/14880768 still missing after imputation, replacing with 0
# [KNN] Warning: 752896/14880768 still missing after imputation, replacing with 0
# [KNN] Warning: 752896/14880768 still missing after imputation, replacing with 0
# [KNN] Warning: 752896/14880768 still missing after imputation, replacing with 0
# Imputing row 1/1344 with 8021 missing, elapsed time: 80.983
# Imputing row 101/1344 with 2283 missing, elapsed time: 86.423
# Imputing row 201/1344 with 8021 missing, elapsed time: 90.935
# Imputing row 301/1344 with 10982 missing, elapsed time: 95.580
# Imputing row 401/1344 with 4905 missing, elapsed time: 101.171
# Imputing row 501/1344 with 10982 missing, elapsed time: 105.177
# Imputing row 601/1344 with 11072 missing, elapsed time: 110.385
# Imputing row 701/1344 with 555 missing, elapsed time: 115.208
# Imputing row 801/1344 with 830 missing, elapsed time: 120.047
# Imputing row 901/1344 with 6632 missing, elapsed time: 124.542
# Imputing row 1001/1344 with 90 missing, elapsed time: 129.470
# Imputing row 1101/1344 with 2558 missing, elapsed time: 133.346
# Imputing row 1201/1344 with 8699 missing, elapsed time: 138.199
# Imputing row 1301/1344 with 90 missing, elapsed time: 143.483
# [KNN] Warning: 752896/14880768 still missing after imputation, replacing with 0
# Imputing row 1/1344 with 8021 missing, elapsed time: 79.846
# Imputing row 101/1344 with 2283 missing, elapsed time: 85.269
# Imputing row 201/1344 with 8021 missing, elapsed time: 89.675
# Imputing row 301/1344 with 10982 missing, elapsed time: 94.265
# Imputing row 401/1344 with 4905 missing, elapsed time: 99.886
# Imputing row 501/1344 with 10982 missing, elapsed time: 103.825
# Imputing row 601/1344 with 11072 missing, elapsed time: 108.891
# Imputing row 701/1344 with 555 missing, elapsed time: 113.594
# Imputing row 801/1344 with 830 missing, elapsed time: 118.444
# Imputing row 901/1344 with 6632 missing, elapsed time: 122.932
# Imputing row 1001/1344 with 90 missing, elapsed time: 127.657
# Imputing row 1101/1344 with 2558 missing, elapsed time: 131.547
# Imputing row 1201/1344 with 8699 missing, elapsed time: 136.336
# Imputing row 1301/1344 with 90 missing, elapsed time: 141.583
# [KNN] Warning: 752896/14880768 still missing after imputation, replacing with 0
# Inner Fold: 1
# Imputing row 1/1344 with 8021 missing, elapsed time: 80.003
# Imputing row 101/1344 with 0 missing, elapsed time: 84.873
# Imputing row 201/1344 with 8021 missing, elapsed time: 89.856
# Imputing row 301/1344 with 7931 missing, elapsed time: 94.527
# Imputing row 401/1344 with 830 missing, elapsed time: 98.965
# Imputing row 501/1344 with 7931 missing, elapsed time: 103.011
# Imputing row 601/1344 with 8021 missing, elapsed time: 108.704
# Imputing row 701/1344 with 1579 missing, elapsed time: 113.691
# Imputing row 801/1344 with 830 missing, elapsed time: 118.961
# Imputing row 901/1344 with 465 missing, elapsed time: 123.683
# Imputing row 1001/1344 with 555 missing, elapsed time: 128.353
# Imputing row 1101/1344 with 3416 missing, elapsed time: 131.863
# Imputing row 1201/1344 with 4815 missing, elapsed time: 136.654
# Imputing row 1301/1344 with 2648 missing, elapsed time: 141.695
# [KNN] Warning: 697536/14880768 still missing after imputation, replacing with 0
# Imputing row 1/1344 with 8021 missing, elapsed time: 81.077
# Imputing row 101/1344 with 0 missing, elapsed time: 86.342
# Imputing row 201/1344 with 8021 missing, elapsed time: 91.423
# Imputing row 301/1344 with 7931 missing, elapsed time: 96.195
# Imputing row 401/1344 with 830 missing, elapsed time: 100.633
# Imputing row 501/1344 with 7931 missing, elapsed time: 104.774
# Imputing row 601/1344 with 8021 missing, elapsed time: 110.624
# Imputing row 701/1344 with 1579 missing, elapsed time: 115.811
# Imputing row 801/1344 with 830 missing, elapsed time: 121.179
# Imputing row 901/1344 with 465 missing, elapsed time: 126.242
# Imputing row 1001/1344 with 555 missing, elapsed time: 131.101
# Imputing row 1101/1344 with 3416 missing, elapsed time: 134.779
# Imputing row 1201/1344 with 4815 missing, elapsed time: 139.676
# Imputing row 1301/1344 with 2648 missing, elapsed time: 144.878
# [KNN] Warning: 697536/14880768 still missing after imputation, replacing with 0
# Imputing row 1/1344 with 8021 missing, elapsed time: 80.562
# Imputing row 101/1344 with 0 missing, elapsed time: 85.633
# Imputing row 201/1344 with 8021 missing, elapsed time: 90.625
# Imputing row 301/1344 with 7931 missing, elapsed time: 95.220
# Imputing row 401/1344 with 830 missing, elapsed time: 99.712
# Imputing row 501/1344 with 7931 missing, elapsed time: 103.723
# Imputing row 601/1344 with 8021 missing, elapsed time: 109.471
# Imputing row 701/1344 with 1579 missing, elapsed time: 114.688
# Imputing row 801/1344 with 830 missing, elapsed time: 120.285
# Imputing row 901/1344 with 465 missing, elapsed time: 125.399
# Imputing row 1001/1344 with 555 missing, elapsed time: 130.205
# Imputing row 1101/1344 with 3416 missing, elapsed time: 133.802
# Imputing row 1201/1344 with 4815 missing, elapsed time: 138.559
# Imputing row 1301/1344 with 2648 missing, elapsed time: 143.640
# [KNN] Warning: 697536/14880768 still missing after imputation, replacing with 0
# Inner Fold: 2
# Imputing row 1/1344 with 8021 missing, elapsed time: 81.110
# Imputing row 101/1344 with 275 missing, elapsed time: 86.926
# Imputing row 201/1344 with 8021 missing, elapsed time: 91.502
# Imputing row 301/1344 with 7931 missing, elapsed time: 96.208
# Imputing row 401/1344 with 4714 missing, elapsed time: 101.405
# Imputing row 501/1344 with 7931 missing, elapsed time: 105.733
# Imputing row 601/1344 with 8021 missing, elapsed time: 111.242
# Imputing row 701/1344 with 555 missing, elapsed time: 116.663
# Imputing row 801/1344 with 3113 missing, elapsed time: 121.433
# Imputing row 901/1344 with 3516 missing, elapsed time: 126.172
# Imputing row 1001/1344 with 3397 missing, elapsed time: 131.279
# Imputing row 1101/1344 with 4159 missing, elapsed time: 135.315
# Imputing row 1201/1344 with 4905 missing, elapsed time: 139.869
# Imputing row 1301/1344 with 4998 missing, elapsed time: 145.227
# [KNN] Warning: 664320/14880768 still missing after imputation, replacing with 0
# Imputing row 1/1344 with 8021 missing, elapsed time: 80.753
# Imputing row 101/1344 with 275 missing, elapsed time: 86.483
# Imputing row 201/1344 with 8021 missing, elapsed time: 90.933
# Imputing row 301/1344 with 7931 missing, elapsed time: 95.610
# Imputing row 401/1344 with 4714 missing, elapsed time: 100.784
# Imputing row 501/1344 with 7931 missing, elapsed time: 105.051
# Imputing row 601/1344 with 8021 missing, elapsed time: 110.471
# Imputing row 701/1344 with 555 missing, elapsed time: 115.792
# Imputing row 801/1344 with 3113 missing, elapsed time: 120.582
# Imputing row 901/1344 with 3516 missing, elapsed time: 125.059
# Imputing row 1001/1344 with 3397 missing, elapsed time: 130.106
# Imputing row 1101/1344 with 4159 missing, elapsed time: 134.115
# Imputing row 1201/1344 with 4905 missing, elapsed time: 138.637
# Imputing row 1301/1344 with 4998 missing, elapsed time: 143.998
# [KNN] Warning: 664320/14880768 still missing after imputation, replacing with 0
# Imputing row 1/1344 with 8021 missing, elapsed time: 80.122
# Imputing row 101/1344 with 275 missing, elapsed time: 85.867
# Imputing row 201/1344 with 8021 missing, elapsed time: 90.334
# Imputing row 301/1344 with 7931 missing, elapsed time: 94.985
# Imputing row 401/1344 with 4714 missing, elapsed time: 100.226
# Imputing row 501/1344 with 7931 missing, elapsed time: 104.560
# Imputing row 601/1344 with 8021 missing, elapsed time: 110.171
# Imputing row 701/1344 with 555 missing, elapsed time: 115.723
# Imputing row 801/1344 with 3113 missing, elapsed time: 120.536
# Imputing row 901/1344 with 3516 missing, elapsed time: 125.087
# Imputing row 1001/1344 with 3397 missing, elapsed time: 130.122
# Imputing row 1101/1344 with 4159 missing, elapsed time: 134.062
# Imputing row 1201/1344 with 4905 missing, elapsed time: 138.535
# Imputing row 1301/1344 with 4998 missing, elapsed time: 143.771
# [KNN] Warning: 664320/14880768 still missing after imputation, replacing with 0
# Inner Fold: 3
# Imputing row 1/1344 with 8021 missing, elapsed time: 80.590
# Imputing row 101/1344 with 0 missing, elapsed time: 86.113
# Imputing row 201/1344 with 8021 missing, elapsed time: 90.825
# Imputing row 301/1344 with 7931 missing, elapsed time: 95.164
# Imputing row 401/1344 with 3113 missing, elapsed time: 99.876
# Imputing row 501/1344 with 7931 missing, elapsed time: 104.097
# Imputing row 601/1344 with 8021 missing, elapsed time: 110.184
# Imputing row 701/1344 with 830 missing, elapsed time: 115.208
# Imputing row 801/1344 with 3881 missing, elapsed time: 120.409
# Imputing row 901/1344 with 465 missing, elapsed time: 125.335
# Imputing row 1001/1344 with 3974 missing, elapsed time: 130.042
# Imputing row 1101/1344 with 1299 missing, elapsed time: 134.275
# Imputing row 1201/1344 with 7098 missing, elapsed time: 138.740
# Imputing row 1301/1344 with 90 missing, elapsed time: 144.006
# [KNN] Warning: 752896/14880768 still missing after imputation, replacing with 0
# Imputing row 1/1344 with 8021 missing, elapsed time: 80.425
# Imputing row 101/1344 with 0 missing, elapsed time: 85.895
# Imputing row 201/1344 with 8021 missing, elapsed time: 90.584
# Imputing row 301/1344 with 7931 missing, elapsed time: 94.782
# Imputing row 401/1344 with 3113 missing, elapsed time: 99.456
# Imputing row 501/1344 with 7931 missing, elapsed time: 103.561
# Imputing row 601/1344 with 8021 missing, elapsed time: 109.531
# Imputing row 701/1344 with 830 missing, elapsed time: 114.483
# Imputing row 801/1344 with 3881 missing, elapsed time: 119.621
# Imputing row 901/1344 with 465 missing, elapsed time: 124.401
# Imputing row 1001/1344 with 3974 missing, elapsed time: 128.988
# Imputing row 1101/1344 with 1299 missing, elapsed time: 133.050
# Imputing row 1201/1344 with 7098 missing, elapsed time: 137.355
# Imputing row 1301/1344 with 90 missing, elapsed time: 142.463
# [KNN] Warning: 752896/14880768 still missing after imputation, replacing with 0
# Imputing row 1/1344 with 8021 missing, elapsed time: 80.542
# Imputing row 101/1344 with 0 missing, elapsed time: 86.148
# Imputing row 201/1344 with 8021 missing, elapsed time: 90.870
# Imputing row 301/1344 with 7931 missing, elapsed time: 95.089
# Imputing row 401/1344 with 3113 missing, elapsed time: 99.866
# Imputing row 501/1344 with 7931 missing, elapsed time: 104.132
# Imputing row 601/1344 with 8021 missing, elapsed time: 110.291
# Imputing row 701/1344 with 830 missing, elapsed time: 115.324
# Imputing row 801/1344 with 3881 missing, elapsed time: 120.536
# Imputing row 901/1344 with 465 missing, elapsed time: 125.419
# Imputing row 1001/1344 with 3974 missing, elapsed time: 130.224
# Imputing row 1101/1344 with 1299 missing, elapsed time: 134.460
# Imputing row 1201/1344 with 7098 missing, elapsed time: 138.866
# Imputing row 1301/1344 with 90 missing, elapsed time: 144.068
# [KNN] Warning: 752896/14880768 still missing after imputation, replacing with 0
# best hyperpar: (15,)
# mse: -0.006385286825058878
# mse for each fold: [-0.00665755 -0.00643053 -0.00649254 -0.00596052]
# --- tuning end ---
# target size: 7
# ------ best hyper pars:  (15,) ------
# TKNN starts:
# concatenated feature shape:  (1344, 11072)
# Imputing row 1/1344 with 11072 missing, elapsed time: 80.930
# Imputing row 101/1344 with 4630 missing, elapsed time: 86.769
# Imputing row 201/1344 with 11072 missing, elapsed time: 91.105
# Imputing row 301/1344 with 7931 missing, elapsed time: 95.502
# Imputing row 401/1344 with 830 missing, elapsed time: 100.602
# Imputing row 501/1344 with 8021 missing, elapsed time: 105.184
# Imputing row 601/1344 with 8021 missing, elapsed time: 111.134
# Imputing row 701/1344 with 5889 missing, elapsed time: 116.380
# Imputing row 801/1344 with 1854 missing, elapsed time: 121.541
# Imputing row 901/1344 with 1764 missing, elapsed time: 126.126
# Imputing row 1001/1344 with 3141 missing, elapsed time: 130.952
# Imputing row 1101/1344 with 275 missing, elapsed time: 135.015
# Imputing row 1201/1344 with 4815 missing, elapsed time: 139.495
# Imputing row 1301/1344 with 3141 missing, elapsed time: 144.958
# [KNN] Warning: 631104/14880768 still missing after imputation, replacing with 0
# TKNN ends:
# -----------
# mse: 0.005886705633894381
# AUPR: 0.1581663010867448
# AUROC: 0.7242807050239718
# -----------
# Fold: 1
# number of hyperpars combination:  3
# Inner Fold: 0
# Imputing row 1/1344 with 8021 missing, elapsed time: 79.876
# Imputing row 101/1344 with 2283 missing, elapsed time: 85.324
# Imputing row 201/1344 with 8021 missing, elapsed time: 89.853
# Imputing row 301/1344 with 10982 missing, elapsed time: 94.314
# Imputing row 401/1344 with 1854 missing, elapsed time: 99.736
# Imputing row 501/1344 with 10982 missing, elapsed time: 103.732
# Imputing row 601/1344 with 8021 missing, elapsed time: 108.502
# Imputing row 701/1344 with 555 missing, elapsed time: 113.375
# Imputing row 801/1344 with 830 missing, elapsed time: 118.231
# Imputing row 901/1344 with 6632 missing, elapsed time: 122.622
# Imputing row 1001/1344 with 90 missing, elapsed time: 127.355
# Imputing row 1101/1344 with 2558 missing, elapsed time: 131.309
# Imputing row 1201/1344 with 8699 missing, elapsed time: 136.261
# Imputing row 1301/1344 with 90 missing, elapsed time: 141.465
# [KNN] Warning: 752896/14880768 still missing after imputation, replacing with 0
# Imputing row 1/1344 with 8021 missing, elapsed time: 80.455
# Imputing row 101/1344 with 2283 missing, elapsed time: 86.023
# Imputing row 201/1344 with 8021 missing, elapsed time: 90.530
# Imputing row 301/1344 with 10982 missing, elapsed time: 95.011
# Imputing row 401/1344 with 1854 missing, elapsed time: 100.492
# Imputing row 501/1344 with 10982 missing, elapsed time: 104.556
# Imputing row 601/1344 with 8021 missing, elapsed time: 109.724
# Imputing row 701/1344 with 555 missing, elapsed time: 114.834
# Imputing row 801/1344 with 830 missing, elapsed time: 119.705
# Imputing row 901/1344 with 6632 missing, elapsed time: 124.255
# Imputing row 1001/1344 with 90 missing, elapsed time: 129.133
# Imputing row 1101/1344 with 2558 missing, elapsed time: 133.065
# Imputing row 1201/1344 with 8699 missing, elapsed time: 138.142
# Imputing row 1301/1344 with 90 missing, elapsed time: 143.477
# [KNN] Warning: 752896/14880768 still missing after imputation, replacing with 0
# Imputing row 1/1344 with 8021 missing, elapsed time: 80.708
# Imputing row 101/1344 with 2283 missing, elapsed time: 86.187
# Imputing row 201/1344 with 8021 missing, elapsed time: 90.697
# Imputing row 301/1344 with 10982 missing, elapsed time: 95.214
# Imputing row 401/1344 with 1854 missing, elapsed time: 100.673
# Imputing row 501/1344 with 10982 missing, elapsed time: 104.710
# Imputing row 601/1344 with 8021 missing, elapsed time: 109.701
# Imputing row 701/1344 with 555 missing, elapsed time: 114.577
# Imputing row 801/1344 with 830 missing, elapsed time: 119.406
# Imputing row 901/1344 with 6632 missing, elapsed time: 123.895
# Imputing row 1001/1344 with 90 missing, elapsed time: 128.736
# Imputing row 1101/1344 with 2558 missing, elapsed time: 132.695
# Imputing row 1201/1344 with 8699 missing, elapsed time: 137.634
# Imputing row 1301/1344 with 90 missing, elapsed time: 142.888
# [KNN] Warning: 752896/14880768 still missing after imputation, replacing with 0
# Inner Fold: 1
# Imputing row 1/1344 with 11072 missing, elapsed time: 81.076
# Imputing row 101/1344 with 0 missing, elapsed time: 86.186
# Imputing row 201/1344 with 8021 missing, elapsed time: 91.147
# Imputing row 301/1344 with 7931 missing, elapsed time: 95.735
# Imputing row 401/1344 with 830 missing, elapsed time: 100.284
# Imputing row 501/1344 with 7931 missing, elapsed time: 104.560
# Imputing row 601/1344 with 8021 missing, elapsed time: 110.575
# Imputing row 701/1344 with 1579 missing, elapsed time: 116.075
# Imputing row 801/1344 with 830 missing, elapsed time: 121.371
# Imputing row 901/1344 with 465 missing, elapsed time: 126.391
# Imputing row 1001/1344 with 555 missing, elapsed time: 131.282
# Imputing row 1101/1344 with 3416 missing, elapsed time: 135.219
# Imputing row 1201/1344 with 4815 missing, elapsed time: 140.024
# Imputing row 1301/1344 with 2648 missing, elapsed time: 145.276
# [KNN] Warning: 597888/14880768 still missing after imputation, replacing with 0
# Imputing row 1/1344 with 11072 missing, elapsed time: 81.134
# Imputing row 101/1344 with 0 missing, elapsed time: 86.162
# Imputing row 201/1344 with 8021 missing, elapsed time: 91.196
# Imputing row 301/1344 with 7931 missing, elapsed time: 95.818
# Imputing row 401/1344 with 830 missing, elapsed time: 100.315
# Imputing row 501/1344 with 7931 missing, elapsed time: 104.469
# Imputing row 601/1344 with 8021 missing, elapsed time: 110.047
# Imputing row 701/1344 with 1579 missing, elapsed time: 115.320
# Imputing row 801/1344 with 830 missing, elapsed time: 120.470
# Imputing row 901/1344 with 465 missing, elapsed time: 125.314
# Imputing row 1001/1344 with 555 missing, elapsed time: 130.175
# Imputing row 1101/1344 with 3416 missing, elapsed time: 133.993
# Imputing row 1201/1344 with 4815 missing, elapsed time: 138.692
# Imputing row 1301/1344 with 2648 missing, elapsed time: 143.989
# [KNN] Warning: 597888/14880768 still missing after imputation, replacing with 0
# Imputing row 1/1344 with 11072 missing, elapsed time: 80.575
# Imputing row 101/1344 with 0 missing, elapsed time: 85.626
# Imputing row 201/1344 with 8021 missing, elapsed time: 90.598
# Imputing row 301/1344 with 7931 missing, elapsed time: 95.179
# Imputing row 401/1344 with 830 missing, elapsed time: 99.773
# Imputing row 501/1344 with 7931 missing, elapsed time: 104.049
# Imputing row 601/1344 with 8021 missing, elapsed time: 109.823
# Imputing row 701/1344 with 1579 missing, elapsed time: 115.216
# Imputing row 801/1344 with 830 missing, elapsed time: 120.503
# Imputing row 901/1344 with 465 missing, elapsed time: 125.395
# Imputing row 1001/1344 with 555 missing, elapsed time: 130.253
# Imputing row 1101/1344 with 3416 missing, elapsed time: 134.071
# Imputing row 1201/1344 with 4815 missing, elapsed time: 138.794
# Imputing row 1301/1344 with 2648 missing, elapsed time: 143.985
# [KNN] Warning: 597888/14880768 still missing after imputation, replacing with 0
# Inner Fold: 2
# Imputing row 1/1344 with 8021 missing, elapsed time: 80.746
# Imputing row 101/1344 with 3326 missing, elapsed time: 86.558
# Imputing row 201/1344 with 8021 missing, elapsed time: 91.057
# Imputing row 301/1344 with 7931 missing, elapsed time: 95.808
# Imputing row 401/1344 with 4714 missing, elapsed time: 100.865
# Imputing row 501/1344 with 7931 missing, elapsed time: 105.112
# Imputing row 601/1344 with 8021 missing, elapsed time: 110.896
# Imputing row 701/1344 with 3606 missing, elapsed time: 116.194
# Imputing row 801/1344 with 3113 missing, elapsed time: 121.233
# Imputing row 901/1344 with 465 missing, elapsed time: 125.995
# Imputing row 1001/1344 with 6448 missing, elapsed time: 130.887
# Imputing row 1101/1344 with 4159 missing, elapsed time: 134.916
# Imputing row 1201/1344 with 4905 missing, elapsed time: 139.596
# Imputing row 1301/1344 with 8049 missing, elapsed time: 144.828
# [KNN] Warning: 597888/14880768 still missing after imputation, replacing with 0
# Imputing row 1/1344 with 8021 missing, elapsed time: 80.970
# Imputing row 101/1344 with 3326 missing, elapsed time: 86.743
# Imputing row 201/1344 with 8021 missing, elapsed time: 91.235
# Imputing row 301/1344 with 7931 missing, elapsed time: 95.892
# Imputing row 401/1344 with 4714 missing, elapsed time: 100.859
# Imputing row 501/1344 with 7931 missing, elapsed time: 105.059
# Imputing row 601/1344 with 8021 missing, elapsed time: 110.744
# Imputing row 701/1344 with 3606 missing, elapsed time: 115.997
# Imputing row 801/1344 with 3113 missing, elapsed time: 121.086
# Imputing row 901/1344 with 465 missing, elapsed time: 125.891
# Imputing row 1001/1344 with 6448 missing, elapsed time: 130.806
# Imputing row 1101/1344 with 4159 missing, elapsed time: 134.914
# Imputing row 1201/1344 with 4905 missing, elapsed time: 139.650
# Imputing row 1301/1344 with 8049 missing, elapsed time: 144.816
# [KNN] Warning: 597888/14880768 still missing after imputation, replacing with 0
# Imputing row 1/1344 with 8021 missing, elapsed time: 81.095
# Imputing row 101/1344 with 3326 missing, elapsed time: 86.939
# Imputing row 201/1344 with 8021 missing, elapsed time: 91.408
# Imputing row 301/1344 with 7931 missing, elapsed time: 96.209
# Imputing row 401/1344 with 4714 missing, elapsed time: 101.277
# Imputing row 501/1344 with 7931 missing, elapsed time: 105.580
# Imputing row 601/1344 with 8021 missing, elapsed time: 111.339
# Imputing row 701/1344 with 3606 missing, elapsed time: 116.627
# Imputing row 801/1344 with 3113 missing, elapsed time: 121.664
# Imputing row 901/1344 with 465 missing, elapsed time: 126.481
# Imputing row 1001/1344 with 6448 missing, elapsed time: 131.373
# Imputing row 1101/1344 with 4159 missing, elapsed time: 135.418
# Imputing row 1201/1344 with 4905 missing, elapsed time: 140.214
# Imputing row 1301/1344 with 8049 missing, elapsed time: 145.475
# [KNN] Warning: 597888/14880768 still missing after imputation, replacing with 0
# Inner Fold: 3
# Imputing row 1/1344 with 8021 missing, elapsed time: 80.617
# Imputing row 101/1344 with 0 missing, elapsed time: 85.822
# Imputing row 201/1344 with 11072 missing, elapsed time: 90.285
# Imputing row 301/1344 with 7931 missing, elapsed time: 94.483
# Imputing row 401/1344 with 3113 missing, elapsed time: 99.055
# Imputing row 501/1344 with 7931 missing, elapsed time: 103.089
# Imputing row 601/1344 with 8021 missing, elapsed time: 108.919
# Imputing row 701/1344 with 830 missing, elapsed time: 113.823
# Imputing row 801/1344 with 3881 missing, elapsed time: 119.041
# Imputing row 901/1344 with 465 missing, elapsed time: 123.840
# Imputing row 1001/1344 with 3974 missing, elapsed time: 128.674
# Imputing row 1101/1344 with 1299 missing, elapsed time: 132.772
# Imputing row 1201/1344 with 7098 missing, elapsed time: 137.009
# Imputing row 1301/1344 with 90 missing, elapsed time: 141.906
# [KNN] Warning: 719680/14880768 still missing after imputation, replacing with 0
# Imputing row 1/1344 with 8021 missing, elapsed time: 79.649
# Imputing row 101/1344 with 0 missing, elapsed time: 84.908
# Imputing row 201/1344 with 11072 missing, elapsed time: 89.408
# Imputing row 301/1344 with 7931 missing, elapsed time: 93.679
# Imputing row 401/1344 with 3113 missing, elapsed time: 98.375
# Imputing row 501/1344 with 7931 missing, elapsed time: 102.602
# Imputing row 601/1344 with 8021 missing, elapsed time: 108.459
# Imputing row 701/1344 with 830 missing, elapsed time: 113.330
# Imputing row 801/1344 with 3881 missing, elapsed time: 118.490
# Imputing row 901/1344 with 465 missing, elapsed time: 123.226
# Imputing row 1001/1344 with 3974 missing, elapsed time: 128.222
# Imputing row 1101/1344 with 1299 missing, elapsed time: 132.423
# Imputing row 1201/1344 with 7098 missing, elapsed time: 136.706
# Imputing row 1301/1344 with 90 missing, elapsed time: 141.652
# [KNN] Warning: 719680/14880768 still missing after imputation, replacing with 0
# Imputing row 1/1344 with 8021 missing, elapsed time: 79.351
# Imputing row 101/1344 with 0 missing, elapsed time: 84.019
# Imputing row 201/1344 with 11072 missing, elapsed time: 88.446
# Imputing row 301/1344 with 7931 missing, elapsed time: 92.625
# Imputing row 401/1344 with 3113 missing, elapsed time: 97.314
# Imputing row 501/1344 with 7931 missing, elapsed time: 101.431
# Imputing row 601/1344 with 8021 missing, elapsed time: 107.450
# Imputing row 701/1344 with 830 missing, elapsed time: 112.463
# Imputing row 801/1344 with 3881 missing, elapsed time: 117.531
# Imputing row 901/1344 with 465 missing, elapsed time: 122.167
# Imputing row 1001/1344 with 3974 missing, elapsed time: 127.052
# Imputing row 1101/1344 with 1299 missing, elapsed time: 131.065
# Imputing row 1201/1344 with 7098 missing, elapsed time: 135.413
# Imputing row 1301/1344 with 90 missing, elapsed time: 140.322
# [KNN] Warning: 719680/14880768 still missing after imputation, replacing with 0
# best hyperpar: (15,)
# mse: -0.006263997924850179
# mse for each fold: [-0.00661426 -0.00627261 -0.00617669 -0.00599243]
# --- tuning end ---
# target size: 7
# ------ best hyper pars:  (15,) ------
# TKNN starts:
# concatenated feature shape:  (1344, 11072)
# Imputing row 1/1344 with 8021 missing, elapsed time: 78.858
# Imputing row 101/1344 with 1579 missing, elapsed time: 84.413
# Imputing row 201/1344 with 8021 missing, elapsed time: 88.761
# Imputing row 301/1344 with 7931 missing, elapsed time: 93.172
# Imputing row 401/1344 with 3881 missing, elapsed time: 98.340
# Imputing row 501/1344 with 8021 missing, elapsed time: 102.533
# Imputing row 601/1344 with 11072 missing, elapsed time: 108.295
# Imputing row 701/1344 with 2838 missing, elapsed time: 113.265
# Imputing row 801/1344 with 1854 missing, elapsed time: 118.078
# Imputing row 901/1344 with 4815 missing, elapsed time: 122.533
# Imputing row 1001/1344 with 90 missing, elapsed time: 127.106
# Imputing row 1101/1344 with 275 missing, elapsed time: 130.784
# Imputing row 1201/1344 with 4815 missing, elapsed time: 134.950
# Imputing row 1301/1344 with 90 missing, elapsed time: 140.490
# [KNN] Warning: 775040/14880768 still missing after imputation, replacing with 0
# TKNN ends:
# -----------
# mse: 0.0062568069635865
# AUPR: 0.1424097462830281
# AUROC: 0.7232346911051709
# -----------
# Fold: 2
# number of hyperpars combination:  3
# Inner Fold: 0
# Imputing row 1/1344 with 8021 missing, elapsed time: 79.182
# Imputing row 101/1344 with 2283 missing, elapsed time: 84.677
# Imputing row 201/1344 with 8021 missing, elapsed time: 89.045
# Imputing row 301/1344 with 7931 missing, elapsed time: 93.215
# Imputing row 401/1344 with 4905 missing, elapsed time: 98.252
# Imputing row 501/1344 with 10982 missing, elapsed time: 102.045
# Imputing row 601/1344 with 11072 missing, elapsed time: 106.828
# Imputing row 701/1344 with 555 missing, elapsed time: 111.479
# Imputing row 801/1344 with 830 missing, elapsed time: 116.091
# Imputing row 901/1344 with 6632 missing, elapsed time: 120.407
# Imputing row 1001/1344 with 90 missing, elapsed time: 125.053
# Imputing row 1101/1344 with 2558 missing, elapsed time: 128.554
# Imputing row 1201/1344 with 8699 missing, elapsed time: 132.969
# Imputing row 1301/1344 with 90 missing, elapsed time: 137.939
# [KNN] Warning: 741824/14880768 still missing after imputation, replacing with 0
# Imputing row 1/1344 with 8021 missing, elapsed time: 78.903
# Imputing row 101/1344 with 2283 missing, elapsed time: 84.308
# Imputing row 201/1344 with 8021 missing, elapsed time: 88.457
# Imputing row 301/1344 with 7931 missing, elapsed time: 92.644
# Imputing row 401/1344 with 4905 missing, elapsed time: 97.810
# Imputing row 501/1344 with 10982 missing, elapsed time: 101.786
# Imputing row 601/1344 with 11072 missing, elapsed time: 106.672
# Imputing row 701/1344 with 555 missing, elapsed time: 111.144
# Imputing row 801/1344 with 830 missing, elapsed time: 115.827
# Imputing row 901/1344 with 6632 missing, elapsed time: 120.125
# Imputing row 1001/1344 with 90 missing, elapsed time: 124.724
# Imputing row 1101/1344 with 2558 missing, elapsed time: 128.277
# Imputing row 1201/1344 with 8699 missing, elapsed time: 132.971
# Imputing row 1301/1344 with 90 missing, elapsed time: 138.043
# [KNN] Warning: 741824/14880768 still missing after imputation, replacing with 0
# Imputing row 1/1344 with 8021 missing, elapsed time: 79.385
# Imputing row 101/1344 with 2283 missing, elapsed time: 85.007
# Imputing row 201/1344 with 8021 missing, elapsed time: 89.441
# Imputing row 301/1344 with 7931 missing, elapsed time: 93.779
# Imputing row 401/1344 with 4905 missing, elapsed time: 99.057
# Imputing row 501/1344 with 10982 missing, elapsed time: 103.100
# Imputing row 601/1344 with 11072 missing, elapsed time: 108.281
# Imputing row 701/1344 with 555 missing, elapsed time: 113.210
# Imputing row 801/1344 with 830 missing, elapsed time: 118.091
# Imputing row 901/1344 with 6632 missing, elapsed time: 122.688
# Imputing row 1001/1344 with 90 missing, elapsed time: 127.297
# Imputing row 1101/1344 with 2558 missing, elapsed time: 130.927
# Imputing row 1201/1344 with 8699 missing, elapsed time: 135.680
# Imputing row 1301/1344 with 90 missing, elapsed time: 140.972
# [KNN] Warning: 741824/14880768 still missing after imputation, replacing with 0
# Inner Fold: 1
# Imputing row 1/1344 with 11072 missing, elapsed time: 78.925
# Imputing row 101/1344 with 0 missing, elapsed time: 83.457
# Imputing row 201/1344 with 8021 missing, elapsed time: 88.429
# Imputing row 301/1344 with 7931 missing, elapsed time: 92.761
# Imputing row 401/1344 with 830 missing, elapsed time: 97.267
# Imputing row 501/1344 with 7931 missing, elapsed time: 101.562
# Imputing row 601/1344 with 8021 missing, elapsed time: 107.141
# Imputing row 701/1344 with 1579 missing, elapsed time: 111.912
# Imputing row 801/1344 with 830 missing, elapsed time: 116.760
# Imputing row 901/1344 with 3516 missing, elapsed time: 121.203
# Imputing row 1001/1344 with 555 missing, elapsed time: 125.891
# Imputing row 1101/1344 with 3416 missing, elapsed time: 129.508
# Imputing row 1201/1344 with 4815 missing, elapsed time: 133.875
# Imputing row 1301/1344 with 2648 missing, elapsed time: 138.980
# [KNN] Warning: 675392/14880768 still missing after imputation, replacing with 0
# Imputing row 1/1344 with 11072 missing, elapsed time: 79.103
# Imputing row 101/1344 with 0 missing, elapsed time: 84.097
# Imputing row 201/1344 with 8021 missing, elapsed time: 89.127
# Imputing row 301/1344 with 7931 missing, elapsed time: 93.261
# Imputing row 401/1344 with 830 missing, elapsed time: 97.791
# Imputing row 501/1344 with 7931 missing, elapsed time: 101.981
# Imputing row 601/1344 with 8021 missing, elapsed time: 107.205
# Imputing row 701/1344 with 1579 missing, elapsed time: 112.326
# Imputing row 801/1344 with 830 missing, elapsed time: 117.376
# Imputing row 901/1344 with 3516 missing, elapsed time: 121.818
# Imputing row 1001/1344 with 555 missing, elapsed time: 126.495
# Imputing row 1101/1344 with 3416 missing, elapsed time: 130.285
# Imputing row 1201/1344 with 4815 missing, elapsed time: 134.767
# Imputing row 1301/1344 with 2648 missing, elapsed time: 139.664
# [KNN] Warning: 675392/14880768 still missing after imputation, replacing with 0
# Imputing row 1/1344 with 11072 missing, elapsed time: 79.492
# Imputing row 101/1344 with 0 missing, elapsed time: 84.540
# Imputing row 201/1344 with 8021 missing, elapsed time: 89.615
# Imputing row 301/1344 with 7931 missing, elapsed time: 93.850
# Imputing row 401/1344 with 830 missing, elapsed time: 98.378
# Imputing row 501/1344 with 7931 missing, elapsed time: 102.701
# Imputing row 601/1344 with 8021 missing, elapsed time: 108.330
# Imputing row 701/1344 with 1579 missing, elapsed time: 113.392
# Imputing row 801/1344 with 830 missing, elapsed time: 118.486
# Imputing row 901/1344 with 3516 missing, elapsed time: 123.002
# Imputing row 1001/1344 with 555 missing, elapsed time: 127.552
# Imputing row 1101/1344 with 3416 missing, elapsed time: 131.179
# Imputing row 1201/1344 with 4815 missing, elapsed time: 135.567
# Imputing row 1301/1344 with 2648 missing, elapsed time: 140.829
# [KNN] Warning: 675392/14880768 still missing after imputation, replacing with 0
# Inner Fold: 2
# Imputing row 1/1344 with 8021 missing, elapsed time: 79.622
# Imputing row 101/1344 with 3326 missing, elapsed time: 84.814
# Imputing row 201/1344 with 8021 missing, elapsed time: 88.742
# Imputing row 301/1344 with 7931 missing, elapsed time: 93.023
# Imputing row 401/1344 with 4714 missing, elapsed time: 97.819
# Imputing row 501/1344 with 7931 missing, elapsed time: 101.570
# Imputing row 601/1344 with 8021 missing, elapsed time: 106.646
# Imputing row 701/1344 with 3606 missing, elapsed time: 111.512
# Imputing row 801/1344 with 3113 missing, elapsed time: 116.210
# Imputing row 901/1344 with 465 missing, elapsed time: 120.645
# Imputing row 1001/1344 with 6448 missing, elapsed time: 125.197
# Imputing row 1101/1344 with 4159 missing, elapsed time: 128.929
# Imputing row 1201/1344 with 4905 missing, elapsed time: 133.233
# Imputing row 1301/1344 with 8049 missing, elapsed time: 138.211
# [KNN] Warning: 664320/14880768 still missing after imputation, replacing with 0
# Imputing row 1/1344 with 8021 missing, elapsed time: 78.920
# Imputing row 101/1344 with 3326 missing, elapsed time: 83.999
# Imputing row 201/1344 with 8021 missing, elapsed time: 87.851
# Imputing row 301/1344 with 7931 missing, elapsed time: 91.884
# Imputing row 401/1344 with 4714 missing, elapsed time: 96.789
# Imputing row 501/1344 with 7931 missing, elapsed time: 100.513
# Imputing row 601/1344 with 8021 missing, elapsed time: 105.838
# Imputing row 701/1344 with 3606 missing, elapsed time: 110.755
# Imputing row 801/1344 with 3113 missing, elapsed time: 115.460
# Imputing row 901/1344 with 465 missing, elapsed time: 119.899
# Imputing row 1001/1344 with 6448 missing, elapsed time: 124.324
# Imputing row 1101/1344 with 4159 missing, elapsed time: 128.218
# Imputing row 1201/1344 with 4905 missing, elapsed time: 132.370
# Imputing row 1301/1344 with 8049 missing, elapsed time: 137.205
# [KNN] Warning: 664320/14880768 still missing after imputation, replacing with 0
# Imputing row 1/1344 with 8021 missing, elapsed time: 79.086
# Imputing row 101/1344 with 3326 missing, elapsed time: 84.722
# Imputing row 201/1344 with 8021 missing, elapsed time: 88.853
# Imputing row 301/1344 with 7931 missing, elapsed time: 93.344
# Imputing row 401/1344 with 4714 missing, elapsed time: 98.471
# Imputing row 501/1344 with 7931 missing, elapsed time: 102.520
# Imputing row 601/1344 with 8021 missing, elapsed time: 108.118
# Imputing row 701/1344 with 3606 missing, elapsed time: 113.208
# Imputing row 801/1344 with 3113 missing, elapsed time: 118.140
# Imputing row 901/1344 with 465 missing, elapsed time: 122.903
# Imputing row 1001/1344 with 6448 missing, elapsed time: 127.562
# Imputing row 1101/1344 with 4159 missing, elapsed time: 131.588
# Imputing row 1201/1344 with 4905 missing, elapsed time: 136.032
# Imputing row 1301/1344 with 8049 missing, elapsed time: 141.200
# [KNN] Warning: 664320/14880768 still missing after imputation, replacing with 0
# Inner Fold: 3
# Imputing row 1/1344 with 8021 missing, elapsed time: 79.093
# Imputing row 101/1344 with 0 missing, elapsed time: 83.485
# Imputing row 201/1344 with 11072 missing, elapsed time: 87.519
# Imputing row 301/1344 with 7931 missing, elapsed time: 91.524
# Imputing row 401/1344 with 3113 missing, elapsed time: 95.959
# Imputing row 501/1344 with 7931 missing, elapsed time: 99.958
# Imputing row 601/1344 with 8021 missing, elapsed time: 105.355
# Imputing row 701/1344 with 830 missing, elapsed time: 110.161
# Imputing row 801/1344 with 3881 missing, elapsed time: 114.940
# Imputing row 901/1344 with 465 missing, elapsed time: 119.456
# Imputing row 1001/1344 with 3974 missing, elapsed time: 124.149
# Imputing row 1101/1344 with 1299 missing, elapsed time: 128.153
# Imputing row 1201/1344 with 7098 missing, elapsed time: 132.460
# Imputing row 1301/1344 with 90 missing, elapsed time: 137.304
# [KNN] Warning: 763968/14880768 still missing after imputation, replacing with 0
# Imputing row 1/1344 with 8021 missing, elapsed time: 79.010
# Imputing row 101/1344 with 0 missing, elapsed time: 83.948
# Imputing row 201/1344 with 11072 missing, elapsed time: 88.021
# Imputing row 301/1344 with 7931 missing, elapsed time: 92.071
# Imputing row 401/1344 with 3113 missing, elapsed time: 96.574
# Imputing row 501/1344 with 7931 missing, elapsed time: 100.450
# Imputing row 601/1344 with 8021 missing, elapsed time: 105.856
# Imputing row 701/1344 with 830 missing, elapsed time: 110.588
# Imputing row 801/1344 with 3881 missing, elapsed time: 115.356
# Imputing row 901/1344 with 465 missing, elapsed time: 119.888
# Imputing row 1001/1344 with 3974 missing, elapsed time: 124.596
# Imputing row 1101/1344 with 1299 missing, elapsed time: 128.540
# Imputing row 1201/1344 with 7098 missing, elapsed time: 132.771
# Imputing row 1301/1344 with 90 missing, elapsed time: 137.723
# [KNN] Warning: 763968/14880768 still missing after imputation, replacing with 0
# Imputing row 1/1344 with 8021 missing, elapsed time: 78.952
# Imputing row 101/1344 with 0 missing, elapsed time: 84.059
# Imputing row 201/1344 with 11072 missing, elapsed time: 88.501
# Imputing row 301/1344 with 7931 missing, elapsed time: 92.680
# Imputing row 401/1344 with 3113 missing, elapsed time: 97.112
# Imputing row 501/1344 with 7931 missing, elapsed time: 101.237
# Imputing row 601/1344 with 8021 missing, elapsed time: 107.010
# Imputing row 701/1344 with 830 missing, elapsed time: 111.906
# Imputing row 801/1344 with 3881 missing, elapsed time: 116.918
# Imputing row 901/1344 with 465 missing, elapsed time: 121.510
# Imputing row 1001/1344 with 3974 missing, elapsed time: 126.268
# Imputing row 1101/1344 with 1299 missing, elapsed time: 130.260
# Imputing row 1201/1344 with 7098 missing, elapsed time: 134.391
# Imputing row 1301/1344 with 90 missing, elapsed time: 139.389
# [KNN] Warning: 763968/14880768 still missing after imputation, replacing with 0
# best hyperpar: (15,)
# mse: -0.006207056339426708
# mse for each fold: [-0.00659436 -0.00627863 -0.00600112 -0.00595411]
# --- tuning end ---
# target size: 7
# ------ best hyper pars:  (15,) ------
# TKNN starts:
# concatenated feature shape:  (1344, 11072)
# Imputing row 1/1344 with 8021 missing, elapsed time: 79.017
# Imputing row 101/1344 with 1579 missing, elapsed time: 84.607
# Imputing row 201/1344 with 8021 missing, elapsed time: 88.963
# Imputing row 301/1344 with 10982 missing, elapsed time: 93.905
# Imputing row 401/1344 with 830 missing, elapsed time: 99.142
# Imputing row 501/1344 with 8021 missing, elapsed time: 103.359
# Imputing row 601/1344 with 8021 missing, elapsed time: 109.016
# Imputing row 701/1344 with 2838 missing, elapsed time: 113.652
# Imputing row 801/1344 with 1854 missing, elapsed time: 118.687
# Imputing row 901/1344 with 1764 missing, elapsed time: 123.163
# Imputing row 1001/1344 with 90 missing, elapsed time: 127.773
# Imputing row 1101/1344 with 275 missing, elapsed time: 131.397
# Imputing row 1201/1344 with 4815 missing, elapsed time: 135.854
# Imputing row 1301/1344 with 90 missing, elapsed time: 141.145
# [KNN] Warning: 642176/14880768 still missing after imputation, replacing with 0
# TKNN ends:
# -----------
# mse: 0.006598012757127434
# AUPR: 0.13078463656887732
# AUROC: 0.7239917624539249
# -----------
# Fold: 3
# number of hyperpars combination:  3
# Inner Fold: 0
# Imputing row 1/1344 with 8021 missing, elapsed time: 78.945
# Imputing row 101/1344 with 2283 missing, elapsed time: 84.107
# Imputing row 201/1344 with 8021 missing, elapsed time: 88.265
# Imputing row 301/1344 with 7931 missing, elapsed time: 92.445
# Imputing row 401/1344 with 4905 missing, elapsed time: 97.432
# Imputing row 501/1344 with 10982 missing, elapsed time: 101.098
# Imputing row 601/1344 with 11072 missing, elapsed time: 105.943
# Imputing row 701/1344 with 555 missing, elapsed time: 110.596
# Imputing row 801/1344 with 830 missing, elapsed time: 114.936
# Imputing row 901/1344 with 6632 missing, elapsed time: 119.523
# Imputing row 1001/1344 with 90 missing, elapsed time: 124.004
# Imputing row 1101/1344 with 2558 missing, elapsed time: 127.487
# Imputing row 1201/1344 with 8699 missing, elapsed time: 132.111
# Imputing row 1301/1344 with 90 missing, elapsed time: 137.206
# [KNN] Warning: 697536/14880768 still missing after imputation, replacing with 0
# Imputing row 1/1344 with 8021 missing, elapsed time: 79.030
# Imputing row 101/1344 with 2283 missing, elapsed time: 84.411
# Imputing row 201/1344 with 8021 missing, elapsed time: 88.777
# Imputing row 301/1344 with 7931 missing, elapsed time: 93.062
# Imputing row 401/1344 with 4905 missing, elapsed time: 98.376
# Imputing row 501/1344 with 10982 missing, elapsed time: 102.345
# Imputing row 601/1344 with 11072 missing, elapsed time: 107.226
# Imputing row 701/1344 with 555 missing, elapsed time: 111.980
# Imputing row 801/1344 with 830 missing, elapsed time: 116.574
# Imputing row 901/1344 with 6632 missing, elapsed time: 121.056
# Imputing row 1001/1344 with 90 missing, elapsed time: 125.611
# Imputing row 1101/1344 with 2558 missing, elapsed time: 129.110
# Imputing row 1201/1344 with 8699 missing, elapsed time: 133.692
# Imputing row 1301/1344 with 90 missing, elapsed time: 138.953
# [KNN] Warning: 697536/14880768 still missing after imputation, replacing with 0
# Imputing row 1/1344 with 8021 missing, elapsed time: 79.377
# Imputing row 101/1344 with 2283 missing, elapsed time: 84.583
# Imputing row 201/1344 with 8021 missing, elapsed time: 89.049
# Imputing row 301/1344 with 7931 missing, elapsed time: 93.539
# Imputing row 401/1344 with 4905 missing, elapsed time: 98.909
# Imputing row 501/1344 with 10982 missing, elapsed time: 102.957
# Imputing row 601/1344 with 11072 missing, elapsed time: 108.130
# Imputing row 701/1344 with 555 missing, elapsed time: 113.054
# Imputing row 801/1344 with 830 missing, elapsed time: 117.946
# Imputing row 901/1344 with 6632 missing, elapsed time: 122.608
# Imputing row 1001/1344 with 90 missing, elapsed time: 127.195
# Imputing row 1101/1344 with 2558 missing, elapsed time: 130.832
# Imputing row 1201/1344 with 8699 missing, elapsed time: 135.641
# Imputing row 1301/1344 with 90 missing, elapsed time: 140.827
# [KNN] Warning: 697536/14880768 still missing after imputation, replacing with 0
# Inner Fold: 1
# Imputing row 1/1344 with 11072 missing, elapsed time: 79.342
# Imputing row 101/1344 with 0 missing, elapsed time: 84.244
# Imputing row 201/1344 with 8021 missing, elapsed time: 89.188
# Imputing row 301/1344 with 7931 missing, elapsed time: 93.633
# Imputing row 401/1344 with 830 missing, elapsed time: 97.918
# Imputing row 501/1344 with 7931 missing, elapsed time: 101.940
# Imputing row 601/1344 with 8021 missing, elapsed time: 107.125
# Imputing row 701/1344 with 1579 missing, elapsed time: 111.755
# Imputing row 801/1344 with 830 missing, elapsed time: 116.567
# Imputing row 901/1344 with 3516 missing, elapsed time: 120.914
# Imputing row 1001/1344 with 555 missing, elapsed time: 125.523
# Imputing row 1101/1344 with 365 missing, elapsed time: 129.048
# Imputing row 1201/1344 with 4815 missing, elapsed time: 133.317
# Imputing row 1301/1344 with 2648 missing, elapsed time: 138.025
# [KNN] Warning: 653248/14880768 still missing after imputation, replacing with 0
# Imputing row 1/1344 with 11072 missing, elapsed time: 79.049
# Imputing row 101/1344 with 0 missing, elapsed time: 83.778
# Imputing row 201/1344 with 8021 missing, elapsed time: 88.616
# Imputing row 301/1344 with 7931 missing, elapsed time: 93.049
# Imputing row 401/1344 with 830 missing, elapsed time: 97.608
# Imputing row 501/1344 with 7931 missing, elapsed time: 101.986
# Imputing row 601/1344 with 8021 missing, elapsed time: 107.324
# Imputing row 701/1344 with 1579 missing, elapsed time: 112.120
# Imputing row 801/1344 with 830 missing, elapsed time: 116.924
# Imputing row 901/1344 with 3516 missing, elapsed time: 121.475
# Imputing row 1001/1344 with 555 missing, elapsed time: 125.975
# Imputing row 1101/1344 with 365 missing, elapsed time: 129.413
# Imputing row 1201/1344 with 4815 missing, elapsed time: 133.899
# Imputing row 1301/1344 with 2648 missing, elapsed time: 138.758
# [KNN] Warning: 653248/14880768 still missing after imputation, replacing with 0
# Imputing row 1/1344 with 11072 missing, elapsed time: 79.231
# Imputing row 101/1344 with 0 missing, elapsed time: 84.047
# Imputing row 201/1344 with 8021 missing, elapsed time: 89.127
# Imputing row 301/1344 with 7931 missing, elapsed time: 93.435
# Imputing row 401/1344 with 830 missing, elapsed time: 97.986
# Imputing row 501/1344 with 7931 missing, elapsed time: 102.376
# Imputing row 601/1344 with 8021 missing, elapsed time: 107.929
# Imputing row 701/1344 with 1579 missing, elapsed time: 112.969
# Imputing row 801/1344 with 830 missing, elapsed time: 118.006
# Imputing row 901/1344 with 3516 missing, elapsed time: 122.590
# Imputing row 1001/1344 with 555 missing, elapsed time: 127.269
# Imputing row 1101/1344 with 365 missing, elapsed time: 130.785
# Imputing row 1201/1344 with 4815 missing, elapsed time: 135.276
# Imputing row 1301/1344 with 2648 missing, elapsed time: 140.214
# [KNN] Warning: 653248/14880768 still missing after imputation, replacing with 0
# Inner Fold: 2
# Imputing row 1/1344 with 8021 missing, elapsed time: 79.201
# Imputing row 101/1344 with 3326 missing, elapsed time: 84.489
# Imputing row 201/1344 with 8021 missing, elapsed time: 88.702
# Imputing row 301/1344 with 7931 missing, elapsed time: 93.309
# Imputing row 401/1344 with 4714 missing, elapsed time: 98.279
# Imputing row 501/1344 with 7931 missing, elapsed time: 102.187
# Imputing row 601/1344 with 8021 missing, elapsed time: 107.237
# Imputing row 701/1344 with 3606 missing, elapsed time: 112.024
# Imputing row 801/1344 with 3113 missing, elapsed time: 116.716
# Imputing row 901/1344 with 465 missing, elapsed time: 121.190
# Imputing row 1001/1344 with 6448 missing, elapsed time: 125.655
# Imputing row 1101/1344 with 4159 missing, elapsed time: 129.560
# Imputing row 1201/1344 with 4905 missing, elapsed time: 133.770
# Imputing row 1301/1344 with 8049 missing, elapsed time: 138.713
# [KNN] Warning: 730752/14880768 still missing after imputation, replacing with 0
# Imputing row 1/1344 with 8021 missing, elapsed time: 79.135
# Imputing row 101/1344 with 3326 missing, elapsed time: 84.428
# Imputing row 201/1344 with 8021 missing, elapsed time: 88.349
# Imputing row 301/1344 with 7931 missing, elapsed time: 92.803
# Imputing row 401/1344 with 4714 missing, elapsed time: 97.794
# Imputing row 501/1344 with 7931 missing, elapsed time: 101.720
# Imputing row 601/1344 with 8021 missing, elapsed time: 106.890
# Imputing row 701/1344 with 3606 missing, elapsed time: 111.667
# Imputing row 801/1344 with 3113 missing, elapsed time: 116.453
# Imputing row 901/1344 with 465 missing, elapsed time: 120.949
# Imputing row 1001/1344 with 6448 missing, elapsed time: 125.430
# Imputing row 1101/1344 with 4159 missing, elapsed time: 129.370
# Imputing row 1201/1344 with 4905 missing, elapsed time: 133.658
# Imputing row 1301/1344 with 8049 missing, elapsed time: 138.705
# [KNN] Warning: 730752/14880768 still missing after imputation, replacing with 0
# Imputing row 1/1344 with 8021 missing, elapsed time: 79.037
# Imputing row 101/1344 with 3326 missing, elapsed time: 84.427
# Imputing row 201/1344 with 8021 missing, elapsed time: 88.424
# Imputing row 301/1344 with 7931 missing, elapsed time: 93.078
# Imputing row 401/1344 with 4714 missing, elapsed time: 98.332
# Imputing row 501/1344 with 7931 missing, elapsed time: 102.328
# Imputing row 601/1344 with 8021 missing, elapsed time: 107.600
# Imputing row 701/1344 with 3606 missing, elapsed time: 112.373
# Imputing row 801/1344 with 3113 missing, elapsed time: 117.294
# Imputing row 901/1344 with 465 missing, elapsed time: 121.877
# Imputing row 1001/1344 with 6448 missing, elapsed time: 126.436
# Imputing row 1101/1344 with 4159 missing, elapsed time: 130.451
# Imputing row 1201/1344 with 4905 missing, elapsed time: 134.838
# Imputing row 1301/1344 with 8049 missing, elapsed time: 139.797
# [KNN] Warning: 730752/14880768 still missing after imputation, replacing with 0
# Inner Fold: 3
# Imputing row 1/1344 with 8021 missing, elapsed time: 79.042
# Imputing row 101/1344 with 0 missing, elapsed time: 83.771
# Imputing row 201/1344 with 11072 missing, elapsed time: 87.695
# Imputing row 301/1344 with 10982 missing, elapsed time: 91.775
# Imputing row 401/1344 with 3113 missing, elapsed time: 96.106
# Imputing row 501/1344 with 7931 missing, elapsed time: 100.002
# Imputing row 601/1344 with 8021 missing, elapsed time: 105.527
# Imputing row 701/1344 with 830 missing, elapsed time: 110.317
# Imputing row 801/1344 with 3881 missing, elapsed time: 115.056
# Imputing row 901/1344 with 465 missing, elapsed time: 119.588
# Imputing row 1001/1344 with 3974 missing, elapsed time: 124.367
# Imputing row 1101/1344 with 1299 missing, elapsed time: 128.441
# Imputing row 1201/1344 with 7098 missing, elapsed time: 132.727
# Imputing row 1301/1344 with 90 missing, elapsed time: 137.565
# [KNN] Warning: 719680/14880768 still missing after imputation, replacing with 0
# Imputing row 1/1344 with 8021 missing, elapsed time: 78.728
# Imputing row 101/1344 with 0 missing, elapsed time: 83.749
# Imputing row 201/1344 with 11072 missing, elapsed time: 87.968
# Imputing row 301/1344 with 10982 missing, elapsed time: 92.331
# Imputing row 401/1344 with 3113 missing, elapsed time: 96.543
# Imputing row 501/1344 with 7931 missing, elapsed time: 100.533
# Imputing row 601/1344 with 8021 missing, elapsed time: 106.122
# Imputing row 701/1344 with 830 missing, elapsed time: 110.735
# Imputing row 801/1344 with 3881 missing, elapsed time: 115.451
# Imputing row 901/1344 with 465 missing, elapsed time: 119.924
# Imputing row 1001/1344 with 3974 missing, elapsed time: 124.648
# Imputing row 1101/1344 with 1299 missing, elapsed time: 128.693
# Imputing row 1201/1344 with 7098 missing, elapsed time: 132.957
# Imputing row 1301/1344 with 90 missing, elapsed time: 137.925
# [KNN] Warning: 719680/14880768 still missing after imputation, replacing with 0
# Imputing row 1/1344 with 8021 missing, elapsed time: 78.786
# Imputing row 101/1344 with 0 missing, elapsed time: 83.619
# Imputing row 201/1344 with 11072 missing, elapsed time: 87.934
# Imputing row 301/1344 with 10982 missing, elapsed time: 92.417
# Imputing row 401/1344 with 3113 missing, elapsed time: 96.908
# Imputing row 501/1344 with 7931 missing, elapsed time: 101.004
# Imputing row 601/1344 with 8021 missing, elapsed time: 106.883
# Imputing row 701/1344 with 830 missing, elapsed time: 111.989
# Imputing row 801/1344 with 3881 missing, elapsed time: 117.042
# Imputing row 901/1344 with 465 missing, elapsed time: 121.830
# Imputing row 1001/1344 with 3974 missing, elapsed time: 126.839
# Imputing row 1101/1344 with 1299 missing, elapsed time: 131.164
# Imputing row 1201/1344 with 7098 missing, elapsed time: 135.720
# Imputing row 1301/1344 with 90 missing, elapsed time: 141.102
# [KNN] Warning: 719680/14880768 still missing after imputation, replacing with 0
# best hyperpar: (15,)
# mse: -0.0063049690957827685
# mse for each fold: [-0.00666805 -0.0063743  -0.00615689 -0.00602064]
# --- tuning end ---
# target size: 7
# ------ best hyper pars:  (15,) ------
# TKNN starts:
# concatenated feature shape:  (1344, 11072)
# Imputing row 1/1344 with 8021 missing, elapsed time: 79.525
# Imputing row 101/1344 with 1579 missing, elapsed time: 85.086
# Imputing row 201/1344 with 8021 missing, elapsed time: 89.458
# Imputing row 301/1344 with 7931 missing, elapsed time: 93.682
# Imputing row 401/1344 with 830 missing, elapsed time: 98.606
# Imputing row 501/1344 with 8021 missing, elapsed time: 102.693
# Imputing row 601/1344 with 8021 missing, elapsed time: 108.475
# Imputing row 701/1344 with 2838 missing, elapsed time: 113.565
# Imputing row 801/1344 with 1854 missing, elapsed time: 118.631
# Imputing row 901/1344 with 1764 missing, elapsed time: 122.806
# Imputing row 1001/1344 with 90 missing, elapsed time: 127.387
# Imputing row 1101/1344 with 3326 missing, elapsed time: 130.937
# Imputing row 1201/1344 with 4815 missing, elapsed time: 135.308
# Imputing row 1301/1344 with 90 missing, elapsed time: 140.360
# [KNN] Warning: 697536/14880768 still missing after imputation, replacing with 0
# TKNN ends:
# -----------
# mse: 0.006166374128206517
# AUPR: 0.13682329625939627
# AUROC: 0.7301993030624285
# -----------
# Fold: 4
# number of hyperpars combination:  3
# Inner Fold: 0
# Imputing row 1/1344 with 8021 missing, elapsed time: 79.581
# Imputing row 101/1344 with 2283 missing, elapsed time: 84.505
# Imputing row 201/1344 with 8021 missing, elapsed time: 88.710
# Imputing row 301/1344 with 7931 missing, elapsed time: 93.000
# Imputing row 401/1344 with 4905 missing, elapsed time: 98.071
# Imputing row 501/1344 with 7931 missing, elapsed time: 102.036
# Imputing row 601/1344 with 11072 missing, elapsed time: 106.937
# Imputing row 701/1344 with 555 missing, elapsed time: 111.760
# Imputing row 801/1344 with 830 missing, elapsed time: 116.347
# Imputing row 901/1344 with 6632 missing, elapsed time: 120.718
# Imputing row 1001/1344 with 90 missing, elapsed time: 125.171
# Imputing row 1101/1344 with 2558 missing, elapsed time: 128.566
# Imputing row 1201/1344 with 8699 missing, elapsed time: 133.436
# Imputing row 1301/1344 with 90 missing, elapsed time: 138.382
# [KNN] Warning: 697536/14880768 still missing after imputation, replacing with 0
# Imputing row 1/1344 with 8021 missing, elapsed time: 78.978
# Imputing row 101/1344 with 2283 missing, elapsed time: 84.372
# Imputing row 201/1344 with 8021 missing, elapsed time: 88.568
# Imputing row 301/1344 with 7931 missing, elapsed time: 92.548
# Imputing row 401/1344 with 4905 missing, elapsed time: 97.574
# Imputing row 501/1344 with 7931 missing, elapsed time: 101.343
# Imputing row 601/1344 with 11072 missing, elapsed time: 106.198
# Imputing row 701/1344 with 555 missing, elapsed time: 111.176
# Imputing row 801/1344 with 830 missing, elapsed time: 115.921
# Imputing row 901/1344 with 6632 missing, elapsed time: 120.377
# Imputing row 1001/1344 with 90 missing, elapsed time: 124.863
# Imputing row 1101/1344 with 2558 missing, elapsed time: 128.337
# Imputing row 1201/1344 with 8699 missing, elapsed time: 133.170
# Imputing row 1301/1344 with 90 missing, elapsed time: 138.176
# [KNN] Warning: 697536/14880768 still missing after imputation, replacing with 0
# Imputing row 1/1344 with 8021 missing, elapsed time: 80.687
# Imputing row 101/1344 with 2283 missing, elapsed time: 86.209
# Imputing row 201/1344 with 8021 missing, elapsed time: 90.798
# Imputing row 301/1344 with 7931 missing, elapsed time: 95.220
# Imputing row 401/1344 with 4905 missing, elapsed time: 100.491
# Imputing row 501/1344 with 7931 missing, elapsed time: 104.595
# Imputing row 601/1344 with 11072 missing, elapsed time: 110.082
# Imputing row 701/1344 with 555 missing, elapsed time: 115.303
# Imputing row 801/1344 with 830 missing, elapsed time: 120.090
# Imputing row 901/1344 with 6632 missing, elapsed time: 124.909
# Imputing row 1001/1344 with 90 missing, elapsed time: 129.617
# Imputing row 1101/1344 with 2558 missing, elapsed time: 133.124
# Imputing row 1201/1344 with 8699 missing, elapsed time: 138.212
# Imputing row 1301/1344 with 90 missing, elapsed time: 143.695
# [KNN] Warning: 697536/14880768 still missing after imputation, replacing with 0
# Inner Fold: 1
# Imputing row 1/1344 with 11072 missing, elapsed time: 80.645
# Imputing row 101/1344 with 0 missing, elapsed time: 85.672
# Imputing row 201/1344 with 8021 missing, elapsed time: 90.800
# Imputing row 301/1344 with 7931 missing, elapsed time: 95.158
# Imputing row 401/1344 with 830 missing, elapsed time: 100.006
# Imputing row 501/1344 with 7931 missing, elapsed time: 104.391
# Imputing row 601/1344 with 8021 missing, elapsed time: 110.049
# Imputing row 701/1344 with 1579 missing, elapsed time: 114.956
# Imputing row 801/1344 with 830 missing, elapsed time: 120.124
# Imputing row 901/1344 with 3516 missing, elapsed time: 124.890
# Imputing row 1001/1344 with 555 missing, elapsed time: 129.820
# Imputing row 1101/1344 with 365 missing, elapsed time: 133.683
# Imputing row 1201/1344 with 4815 missing, elapsed time: 138.179
# Imputing row 1301/1344 with 2648 missing, elapsed time: 143.329
# [KNN] Warning: 675392/14880768 still missing after imputation, replacing with 0
# Imputing row 1/1344 with 11072 missing, elapsed time: 81.130
# Imputing row 101/1344 with 0 missing, elapsed time: 86.355
# Imputing row 201/1344 with 8021 missing, elapsed time: 91.344
# Imputing row 301/1344 with 7931 missing, elapsed time: 95.681
# Imputing row 401/1344 with 830 missing, elapsed time: 100.551
# Imputing row 501/1344 with 7931 missing, elapsed time: 104.995
# Imputing row 601/1344 with 8021 missing, elapsed time: 110.773
# Imputing row 701/1344 with 1579 missing, elapsed time: 115.933
# Imputing row 801/1344 with 830 missing, elapsed time: 121.106
# Imputing row 901/1344 with 3516 missing, elapsed time: 126.016
# Imputing row 1001/1344 with 555 missing, elapsed time: 130.996
# Imputing row 1101/1344 with 365 missing, elapsed time: 134.838
# Imputing row 1201/1344 with 4815 missing, elapsed time: 139.433
# Imputing row 1301/1344 with 2648 missing, elapsed time: 144.624
# [KNN] Warning: 675392/14880768 still missing after imputation, replacing with 0
# Imputing row 1/1344 with 11072 missing, elapsed time: 82.163
# Imputing row 101/1344 with 0 missing, elapsed time: 87.307
# Imputing row 201/1344 with 8021 missing, elapsed time: 92.297
# Imputing row 301/1344 with 7931 missing, elapsed time: 96.627
# Imputing row 401/1344 with 830 missing, elapsed time: 101.613
# Imputing row 501/1344 with 7931 missing, elapsed time: 106.033
# Imputing row 601/1344 with 8021 missing, elapsed time: 111.834
# Imputing row 701/1344 with 1579 missing, elapsed time: 116.926
# Imputing row 801/1344 with 830 missing, elapsed time: 122.092
# Imputing row 901/1344 with 3516 missing, elapsed time: 126.861
# Imputing row 1001/1344 with 555 missing, elapsed time: 131.777
# Imputing row 1101/1344 with 365 missing, elapsed time: 135.640
# Imputing row 1201/1344 with 4815 missing, elapsed time: 140.111
# Imputing row 1301/1344 with 2648 missing, elapsed time: 145.273
# [KNN] Warning: 675392/14880768 still missing after imputation, replacing with 0
# Inner Fold: 2
# Imputing row 1/1344 with 8021 missing, elapsed time: 79.841
# Imputing row 101/1344 with 3326 missing, elapsed time: 85.396
# Imputing row 201/1344 with 8021 missing, elapsed time: 89.514
# Imputing row 301/1344 with 7931 missing, elapsed time: 94.139
# Imputing row 401/1344 with 4714 missing, elapsed time: 99.347
# Imputing row 501/1344 with 7931 missing, elapsed time: 103.312
# Imputing row 601/1344 with 8021 missing, elapsed time: 108.594
# Imputing row 701/1344 with 3606 missing, elapsed time: 113.695
# Imputing row 801/1344 with 3113 missing, elapsed time: 118.681
# Imputing row 901/1344 with 465 missing, elapsed time: 123.327
# Imputing row 1001/1344 with 6448 missing, elapsed time: 127.915
# Imputing row 1101/1344 with 4159 missing, elapsed time: 132.018
# Imputing row 1201/1344 with 4905 missing, elapsed time: 136.568
# Imputing row 1301/1344 with 8049 missing, elapsed time: 141.766
# [KNN] Warning: 752896/14880768 still missing after imputation, replacing with 0
# Imputing row 1/1344 with 8021 missing, elapsed time: 80.207
# Imputing row 101/1344 with 3326 missing, elapsed time: 85.732
# Imputing row 201/1344 with 8021 missing, elapsed time: 89.914
# Imputing row 301/1344 with 7931 missing, elapsed time: 94.763
# Imputing row 401/1344 with 4714 missing, elapsed time: 100.084
# Imputing row 501/1344 with 7931 missing, elapsed time: 103.978
# Imputing row 601/1344 with 8021 missing, elapsed time: 109.179
# Imputing row 701/1344 with 3606 missing, elapsed time: 114.269
# Imputing row 801/1344 with 3113 missing, elapsed time: 119.212
# Imputing row 901/1344 with 465 missing, elapsed time: 123.824
# Imputing row 1001/1344 with 6448 missing, elapsed time: 128.482
# Imputing row 1101/1344 with 4159 missing, elapsed time: 132.597
# Imputing row 1201/1344 with 4905 missing, elapsed time: 137.137
# Imputing row 1301/1344 with 8049 missing, elapsed time: 142.158
# [KNN] Warning: 752896/14880768 still missing after imputation, replacing with 0
# Imputing row 1/1344 with 8021 missing, elapsed time: 77.297
# Imputing row 101/1344 with 3326 missing, elapsed time: 83.024
# Imputing row 201/1344 with 8021 missing, elapsed time: 87.374
# Imputing row 301/1344 with 7931 missing, elapsed time: 92.261
# Imputing row 401/1344 with 4714 missing, elapsed time: 97.814
# Imputing row 501/1344 with 7931 missing, elapsed time: 101.896
# Imputing row 601/1344 with 8021 missing, elapsed time: 107.171
# Imputing row 701/1344 with 3606 missing, elapsed time: 111.979
# Imputing row 801/1344 with 3113 missing, elapsed time: 117.038
# Imputing row 901/1344 with 465 missing, elapsed time: 121.851
# Imputing row 1001/1344 with 6448 missing, elapsed time: 126.748
# Imputing row 1101/1344 with 4159 missing, elapsed time: 131.163
# Imputing row 1201/1344 with 4905 missing, elapsed time: 136.059
# Imputing row 1301/1344 with 8049 missing, elapsed time: 141.323
# [KNN] Warning: 752896/14880768 still missing after imputation, replacing with 0
# Inner Fold: 3

# %%
# method = "TNMF"
# validation = "nested_cv"
# fhyperparsOut[validation][method] = {}
# fresults[validation][method] = {}
# hyperparList = loadHyperpar(*all_hyperparlist[method],method_option=method)
# fresults[validation][method], fhyperparsOut[validation][method], features_new = completion(Y=SEs[SEs_name], X=features_dict, method_option=method,tuning_metrice=metrice,hyperparList=hyperparList,Validation=validation,n_jobs=3)

# validation = "cv"
# fhyperparsOut[validation][method] = {}
# fresults[validation][method] = {}
# hyperparList = loadHyperpar(*all_hyperparlist[method],method_option=method)
# fresults[validation], fhyperparsOut[validation][method], features_new = completion(Y=SEs[SEs_name], X=features_dict, method_option=method,tuning_metrice=metrice,hyperparList=hyperparList,Validation=validation,n_jobs=1)
method = "TKNN"
validation = "completion"
hyperparList = loadHyperpar(*all_hyperparlist[method],method_option=method)
features_new = completion(Y=SEs[SEs_name], X=features_dict,method_option=method,tuning_metrice=metrice,hyperparList=hyperparList,hyperparfixed=(15,),Validation=validation,n_jobs=1)
hyperpars = {}
hyperpars["nested_cv"] = {}
hyperpars["cv"] = {}
hyperparsOut = {}
hyperparsOut["nested_cv"] = {}
hyperparsOut["cv"] = {}
results = {}
results["nested_cv"] = {}
results["cv"] = {}
method = "KRR"
metrice = "AUPR"
validation = "nested_cv"
hyperparsOut[validation][method] = {}
results[validation][method] = {}
hyperparsOut[validation][method]["noAPPFC"] = {}
results[validation][method]["noAPPFC"] = {}
hyperparsOut[validation][method]["APPFC"] = {}
results[validation][method]["APPFC"] = {}
for str in features_names:
    print(f"using feature {str}")
    # print("without APPFC")
    # hyperparList = loadHyperpar(*all_hyperparlist[method],method_option=method)
    # results[validation][method]["noAPPFC"][str], hyperparsOut[validation][method]["noAPPFC"][str] = evaluation(Y=SEs[SEs_name], X=features_dict[str], method_option=method,tuning_metrice=metrice,hyperparList=hyperparList,Validation=validation,n_jobs=1)
    print("with APPFC")
    hyperparList = loadHyperpar(*all_hyperparlist[method],method_option=method)
    results[validation][method]["APPFC"][str], hyperparsOut[validation][method]["APPFC"][str] = evaluation2(Y=SEs[SEs_name], X=features_dict[str], X2=features_new[str], method_option=method,tuning_metrice=metrice,hyperparList=hyperparList,Validation=validation,n_jobs=10)
method = "KRR"
validation = "cv"
hyperparsOut[validation][method] = {}
results[validation][method] = {}
hyperparsOut[validation][method]["noAPPFC"] = {}
results[validation][method]["noAPPFC"] = {}
hyperparsOut[validation][method]["APPFC"] = {}
results[validation][method]["APPFC"] = {}
for str in features_names:
    print(f"using feature {str}")
    # print("without APPFC")
    # hyperparList = loadHyperpar(*all_hyperparlist[method],method_option=method)
    # results[validation][method]["noAPPFC"][str], hyperparsOut[validation][method]["noAPPFC"][str] = evaluation(Y=SEs[SEs_name], X=features_dict[str], method_option=method,tuning_metrice=metrice,hyperparList=hyperparList,Validation=validation,n_jobs=1)
    print("with APPFC")
    hyperparList = loadHyperpar(*all_hyperparlist[method],method_option=method)
    results[validation][method]["APPFC"][str], hyperparsOut[validation][method]["APPFC"][str] = evaluation2(Y=SEs[SEs_name], X=features_dict[str], X2=features_new[str], method_option=method,tuning_metrice=metrice,hyperparList=hyperparList,Validation=validation,n_jobs=10)
# Out:
# The TKNN requires hyperparameter k
# common drugs chosen to be the test set:  set()
# TKNN starts:
# Imputing row 1/1344 with 8021 missing, elapsed time: 78.504
# Imputing row 101/1344 with 0 missing, elapsed time: 82.919
# Imputing row 201/1344 with 8021 missing, elapsed time: 86.217
# Imputing row 301/1344 with 7931 missing, elapsed time: 88.980
# Imputing row 401/1344 with 830 missing, elapsed time: 92.562
# Imputing row 501/1344 with 7931 missing, elapsed time: 95.185
# Imputing row 601/1344 with 8021 missing, elapsed time: 99.952
# Imputing row 701/1344 with 555 missing, elapsed time: 104.070
# Imputing row 801/1344 with 830 missing, elapsed time: 107.867
# Imputing row 901/1344 with 465 missing, elapsed time: 111.523
# Imputing row 1001/1344 with 90 missing, elapsed time: 114.946
# Imputing row 1101/1344 with 275 missing, elapsed time: 117.295
# Imputing row 1201/1344 with 4815 missing, elapsed time: 120.555
# Imputing row 1301/1344 with 90 missing, elapsed time: 124.687
# [KNN] Warning: 298944/14880768 still missing after imputation, replacing with 0
# TKNN ends:
# using feature target
# with APPFC
# The KRR requires hyperparameter lambda, sigma_X
# ---------- nested cv start ----------
# Fold: 0
# number of hyperpars combination:  25
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [ 153  283  397  440  800  857  858 1177 1230 1327]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0)
# AUPR: 0.40805169842142963
# AUPR for each fold: [0.42990219 0.40445118 0.39683775 0.40101567]
# --- tuning end ---
# target size: 142
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.46249897978790133
# AUROCperdrug: 0.8984809581051735
# AUPR+AUROCperdrug: 1.3609799378930747
# AUPR: 0.4075164811491212
# AUROC: 0.8687157649136915
# AUPR+AUROC: 1.2762322460628126
# -----------
# Fold: 1
# number of hyperpars combination:  25
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [ 125  164  480  518  552  696  913  919 1277 1310]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0)
# AUPR: 0.40181874480718305
# AUPR for each fold: [0.40061991 0.43798729 0.40767887 0.3609889 ]
# --- tuning end ---
# target size: 142
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.4662176612124642
# AUROCperdrug: 0.9026287702419897
# AUPR+AUROCperdrug: 1.368846431454454
# AUPR: 0.40567200494591993
# AUROC: 0.8706551046109592
# AUPR+AUROC: 1.2763271095568791
# -----------
# Fold: 2
# number of hyperpars combination:  25
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [ 210  425  672  709  807  864 1014 1027 1049 1228]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0)
# AUPR: 0.40645710874545615
# AUPR for each fold: [0.40948842 0.4150803  0.40748477 0.39377494]
# --- tuning end ---
# target size: 142
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.4505557117733529
# AUROCperdrug: 0.8944603096665733
# AUPR+AUROCperdrug: 1.3450160214399263
# AUPR: 0.4017764842834336
# AUROC: 0.8730333213814793
# AUPR+AUROC: 1.2748098056649129
# -----------
# Fold: 3
# number of hyperpars combination:  25
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [  45   58   79  192  286  658  678  782  809 1022]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0)
# AUPR: 0.39135298766234705
# AUPR for each fold: [0.36963695 0.4097547  0.38568946 0.40033084]
# --- tuning end ---
# target size: 142
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.4953669592655649
# AUROCperdrug: 0.901359500525688
# AUPR+AUROCperdrug: 1.396726459791253
# AUPR: 0.4401630844473724
# AUROC: 0.8737853094842407
# AUPR+AUROC: 1.313948393931613
# -----------
# Fold: 4
# number of hyperpars combination:  25
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [  46  110  294  381  396  511 1025 1066 1093 1286]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0)
# AUPR: 0.4054195857807592
# AUPR for each fold: [0.39807841 0.42023019 0.41675618 0.38661357]
# --- tuning end ---
# target size: 142
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.45126982841111124
# AUROCperdrug: 0.900414152986895
# AUPR+AUROCperdrug: 1.3516839813980062
# AUPR: 0.4030535219307632
# AUROC: 0.8746545282374996
# AUPR+AUROC: 1.2777080501682627
# -----------
# Mean AUPRperdrug: 0.4651818280900789, std: 0.016290363918152466
# Mean AUROCperdrug: 0.899468738305264, std: 0.0028465649364839995
# Mean AUPR+AUROCperdrug: 1.3646505663953428, std: 0.017964350344174183
# Mean AUPR: 0.41163631535132206, std: 0.014402799721667116
# Mean AUROC: 0.872168805725574, std: 0.0021796362100265565
# Mean AUPR+AUROC: 1.283805121076896, std: 0.015099509685366053
# -----------
# using feature enzyme
# with APPFC
# The KRR requires hyperparameter lambda, sigma_X
# ---------- nested cv start ----------
# Fold: 0
# number of hyperpars combination:  25
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [ 296  392  440  510  560 1147 1198 1207 1261 1300]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (10.0, 10.0)
# AUPR: 0.3912505091259048
# AUPR for each fold: [0.40659287 0.39511626 0.37743506 0.38585784]
# --- tuning end ---
# target size: 108
# ------ best hyper pars:  (10.0, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.44741087798485224
# AUROCperdrug: 0.8880436079992969
# AUPR+AUROCperdrug: 1.3354544859841493
# AUPR: 0.40798309369515706
# AUROC: 0.8727909884254117
# AUPR+AUROC: 1.2807740821205686
# -----------
# Fold: 1
# number of hyperpars combination:  25
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [ 107  110  423  445  477  660 1128 1132 1157 1162]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (10.0, 10.0)
# AUPR: 0.3878894092652961
# AUPR for each fold: [0.3907717  0.37723193 0.3741325  0.4094215 ]
# --- tuning end ---
# target size: 108
# ------ best hyper pars:  (10.0, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.4557737343760535
# AUROCperdrug: 0.8870631358730691
# AUPR+AUROCperdrug: 1.3428368702491227
# AUPR: 0.41698536358447796
# AUROC: 0.8709574555680923
# AUPR+AUROC: 1.2879428191525704
# -----------
# Fold: 2
# number of hyperpars combination:  25
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [  67  164  302  334  387  390  509  721  787 1102]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (10.0, 10.0)
# AUPR: 0.4037293247002061
# AUPR for each fold: [0.41552275 0.39237242 0.42998129 0.37704084]
# --- tuning end ---
# target size: 108
# ------ best hyper pars:  (10.0, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.4211205291345721
# AUROCperdrug: 0.887100884251601
# AUPR+AUROCperdrug: 1.3082214133861731
# AUPR: 0.35728730668940967
# AUROC: 0.8655151868041772
# AUPR+AUROC: 1.2228024934935868
# -----------
# Fold: 3
# number of hyperpars combination:  25
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [  80   87  393  521  558  593  873 1101 1125 1253]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (10.0, 10.0)
# AUPR: 0.38981711959685833
# AUPR for each fold: [0.35891403 0.39711384 0.3987936  0.404447  ]
# --- tuning end ---
# target size: 108
# ------ best hyper pars:  (10.0, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.44643784880592324
# AUROCperdrug: 0.8863943867619712
# AUPR+AUROCperdrug: 1.3328322355678945
# AUPR: 0.4124261657337335
# AUROC: 0.8730524827467181
# AUPR+AUROC: 1.2854786484804515
# -----------
# Fold: 4
# number of hyperpars combination:  25
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [ 139  209  404  504  512  623  697  983 1163 1192]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (10.0, 10.0)
# AUPR: 0.3985895887330901
# AUPR for each fold: [0.39381172 0.37972762 0.4034269  0.41739212]
# --- tuning end ---
# target size: 108
# ------ best hyper pars:  (10.0, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.436953200367983
# AUROCperdrug: 0.885241635042638
# AUPR+AUROCperdrug: 1.322194835410621
# AUPR: 0.38407314462120234
# AUROC: 0.8553718925831305
# AUPR+AUROC: 1.2394450372043329
# -----------
# Mean AUPRperdrug: 0.44153923813387685, std: 0.011824118097455589
# Mean AUROCperdrug: 0.8867687299857152, std: 0.0009267650238009576
# Mean AUPR+AUROCperdrug: 1.3283079681195922, std: 0.012028888420779454
# Mean AUPR: 0.3957510148647961, std: 0.022335673146742382
# Mean AUROC: 0.8675376012255059, std: 0.006660360738765053
# Mean AUPR+AUROC: 1.263288616090302, std: 0.02688349369190968
# -----------
# using feature Chem
# with APPFC
# The KRR requires hyperparameter lambda, sigma_X
# ---------- nested cv start ----------
# Fold: 0
# number of hyperpars combination:  25
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [  42  356  481  524  545  661  770 1235 1312 1331]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (10.0, 10.0)
# AUPR: 0.4009502983815226
# AUPR for each fold: [0.41745363 0.40389163 0.38458955 0.39786639]
# --- tuning end ---
# target size: 129
# ------ best hyper pars:  (10.0, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.45229505857999125
# AUROCperdrug: 0.8973283707429378
# AUPR+AUROCperdrug: 1.349623429322929
# AUPR: 0.3996974874202428
# AUROC: 0.8741433894208666
# AUPR+AUROC: 1.2738408768411094
# -----------
# Fold: 1
# number of hyperpars combination:  25
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [  89   92   94  146  199  205  398  813 1183 1228]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (10.0, 10.0)
# AUPR: 0.38869447335550983
# AUPR for each fold: [0.37141434 0.38828646 0.40361009 0.39146701]
# --- tuning end ---
# target size: 129
# ------ best hyper pars:  (10.0, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.4913892378036055
# AUROCperdrug: 0.9011553763518935
# AUPR+AUROCperdrug: 1.392544614155499
# AUPR: 0.43626195281588864
# AUROC: 0.880433570628228
# AUPR+AUROC: 1.3166955234441167
# -----------
# Fold: 2
# number of hyperpars combination:  25
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [  80  211  312  439  660  765  909  911  962 1240]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (10.0, 10.0)
# AUPR: 0.3945772550175005
# AUPR for each fold: [0.40487556 0.39517632 0.39105166 0.38720548]
# --- tuning end ---
# target size: 129
# ------ best hyper pars:  (10.0, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.4650120337358978
# AUROCperdrug: 0.8957838645313428
# AUPR+AUROCperdrug: 1.3607958982672406
# AUPR: 0.4081840513237271
# AUROC: 0.8738447929526092
# AUPR+AUROC: 1.2820288442763363
# -----------
# Fold: 3
# number of hyperpars combination:  25
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [  56  176  208  339  386  554  616  808 1016 1253]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (10.0, 10.0)
# AUPR: 0.40294730558948955
# AUPR for each fold: [0.39738358 0.39422409 0.42238901 0.39779254]
# --- tuning end ---
# target size: 129
# ------ best hyper pars:  (10.0, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.44481934221523034
# AUROCperdrug: 0.894109856842557
# AUPR+AUROCperdrug: 1.3389291990577874
# AUPR: 0.38694398713227424
# AUROC: 0.8688964328872528
# AUPR+AUROC: 1.255840420019527
# -----------
# Fold: 4
# number of hyperpars combination:  25
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [  48  115  232  242  316  546 1049 1084 1126 1283]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (10.0, 10.0)
# AUPR: 0.40379598259123356
# AUPR for each fold: [0.40766813 0.40078611 0.41998627 0.38674342]
# --- tuning end ---
# target size: 129
# ------ best hyper pars:  (10.0, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.44956694449421014
# AUROCperdrug: 0.8906284390002344
# AUPR+AUROCperdrug: 1.3401953834944444
# AUPR: 0.38550193833878565
# AUROC: 0.8547562127778922
# AUPR+AUROC: 1.2402581511166777
# -----------
# Mean AUPRperdrug: 0.46061652336578707, std: 0.01677600290301127
# Mean AUROCperdrug: 0.895801181493793, std: 0.0034818918259747083
# Mean AUPR+AUROCperdrug: 1.3564177048595802, std: 0.019695156148207788
# Mean AUPR: 0.4033178834061837, std: 0.018480318960458954
# Mean AUROC: 0.8704148797333697, std: 0.008643376517021985
# Mean AUPR+AUROC: 1.2737327631395534, std: 0.025904906933608998
# -----------
# using feature DGI
# with APPFC
# The KRR requires hyperparameter lambda, sigma_X
# ---------- nested cv start ----------
# Fold: 0
# number of hyperpars combination:  25
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [ 167  216  247  334  416  604  681  786 1162 1222]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0)
# AUPR: 0.41173144563282255
# AUPR for each fold: [0.41758618 0.41652083 0.39651726 0.4163015 ]
# --- tuning end ---
# target size: 150
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.45664601738047433
# AUROCperdrug: 0.8876001534157909
# AUPR+AUROCperdrug: 1.3442461707962652
# AUPR: 0.41522919298943767
# AUROC: 0.8671923704689062
# AUPR+AUROC: 1.2824215634583438
# -----------
# Fold: 1
# number of hyperpars combination:  25
# first few training idx:  [ 0  2  4  7  9 10 12 13 16 17]
# first few testing idx:  [  92  102  121  206  316  433  442  460  739 1262]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0)
# AUPR: 0.4148179139684661
# AUPR for each fold: [0.44322752 0.41544596 0.42366161 0.37693657]
# --- tuning end ---
# target size: 150
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.4585045101727857
# AUROCperdrug: 0.8913465310144633
# AUPR+AUROCperdrug: 1.3498510411872489
# AUPR: 0.40467117511343065
# AUROC: 0.8532758973791622
# AUPR+AUROC: 1.257947072492593
# -----------
# Fold: 2
# number of hyperpars combination:  25
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 17]
# first few testing idx:  [ 23 191 197 388 398 526 709 838 928 958]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0)
# AUPR: 0.41366598548397937
# AUPR for each fold: [0.42191136 0.41983013 0.41683943 0.39608301]
# --- tuning end ---
# target size: 150
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.4591842858391255
# AUROCperdrug: 0.8893820437890739
# AUPR+AUROCperdrug: 1.3485663296281993
# AUPR: 0.4359675780713341
# AUROC: 0.8701734667401564
# AUPR+AUROC: 1.3061410448114905
# -----------
# Fold: 3
# number of hyperpars combination:  25
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [  78  210  226  431  530  750  766  784 1166 1246]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0)
# AUPR: 0.4169779405510195
# AUPR for each fold: [0.41934448 0.40784171 0.4225181  0.41820747]
# --- tuning end ---
# target size: 150
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.45196817249696514
# AUROCperdrug: 0.879085971213187
# AUPR+AUROCperdrug: 1.3310541437101522
# AUPR: 0.4181800188505963
# AUROC: 0.8474545928560082
# AUPR+AUROC: 1.2656346117066044
# -----------
# Fold: 4
# number of hyperpars combination:  25
# first few training idx:  [ 0  2  4  7  9 10 11 12 16 17]
# first few testing idx:  [  42   94  201  209  462  910  912 1075 1128 1303]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0)
# AUPR: 0.4158329811941758
# AUPR for each fold: [0.4359923  0.40537679 0.39487877 0.42708406]
# --- tuning end ---
# target size: 150
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.470390400636518
# AUROCperdrug: 0.8857552820613256
# AUPR+AUROCperdrug: 1.3561456826978435
# AUPR: 0.4400661351244753
# AUROC: 0.8558883495257371
# AUPR+AUROC: 1.2959544846502125
# -----------
# Mean AUPRperdrug: 0.4593386773051737, std: 0.006073467192963706
# Mean AUROCperdrug: 0.8866339962987683, std: 0.004205663548930845
# Mean AUPR+AUROCperdrug: 1.3459726736039417, std: 0.008376183460799212
# Mean AUPR: 0.42282282002985483, std: 0.01325758324139379
# Mean AUROC: 0.8587969353939939, std: 0.00857320549538531
# Mean AUPR+AUROC: 1.2816197554238487, std: 0.018018555592358366
# -----------
# using feature transporter
# with APPFC
# The KRR requires hyperparameter lambda, sigma_X
# ---------- nested cv start ----------
# Fold: 0
# number of hyperpars combination:  25
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [ 131  255  305  371  509  654 1015 1028 1128 1242]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (1.0, 10.0)
# AUPR: 0.4262341290617183
# AUPR for each fold: [0.40993694 0.40660309 0.43036084 0.45803564]
# --- tuning end ---
# target size: 74
# ------ best hyper pars:  (1.0, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.45469493937126815
# AUROCperdrug: 0.8809301152332928
# AUPR+AUROCperdrug: 1.335625054604561
# AUPR: 0.38675193123123175
# AUROC: 0.8440537660617804
# AUPR+AUROC: 1.2308056972930121
# -----------
# Fold: 1
# number of hyperpars combination:  25
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [ 233  518  545  551  617  717  939 1008 1226 1306]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (1.0, 10.0)
# AUPR: 0.4059490186188327
# AUPR for each fold: [0.38573385 0.39851067 0.41726874 0.42228282]
# --- tuning end ---
# target size: 74
# ------ best hyper pars:  (1.0, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.5252859512389216
# AUROCperdrug: 0.8939920938752597
# AUPR+AUROCperdrug: 1.4192780451141813
# AUPR: 0.46861364030996955
# AUROC: 0.8692524786487391
# AUPR+AUROC: 1.3378661189587087
# -----------
# Fold: 2
# number of hyperpars combination:  25
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [  45  254  267  319  393  422  635  871 1017 1162]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (1.0, 10.0)
# AUPR: 0.4179912286090525
# AUPR for each fold: [0.43425606 0.41289248 0.3972687  0.42754767]
# --- tuning end ---
# target size: 74
# ------ best hyper pars:  (1.0, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.4620864201080829
# AUROCperdrug: 0.8873246661582681
# AUPR+AUROCperdrug: 1.3494110862663509
# AUPR: 0.4082998197828075
# AUROC: 0.8629949311867944
# AUPR+AUROC: 1.2712947509696018
# -----------
# Fold: 3
# number of hyperpars combination:  25
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [ 604  676  764  790  910  932  969 1102 1158 1243]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (1.0, 10.0)
# AUPR: 0.42466944424728503
# AUPR for each fold: [0.45546768 0.40104273 0.4251989  0.41696847]
# --- tuning end ---
# target size: 74
# ------ best hyper pars:  (1.0, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.43584442819036245
# AUROCperdrug: 0.8819357691000007
# AUPR+AUROCperdrug: 1.317780197290363
# AUPR: 0.3857064926547968
# AUROC: 0.856819678855507
# AUPR+AUROC: 1.2425261715103038
# -----------
# Fold: 4
# number of hyperpars combination:  25
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [ 379  679  692  750  795  809  882  984 1010 1327]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (1.0, 10.0)
# AUPR: 0.4086289591430409
# AUPR for each fold: [0.3907317  0.40529767 0.42145009 0.41703638]
# --- tuning end ---
# target size: 74
# ------ best hyper pars:  (1.0, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.4962179853396679
# AUROCperdrug: 0.8927864408698571
# AUPR+AUROCperdrug: 1.389004426209525
# AUPR: 0.4563820961001983
# AUROC: 0.8726805902176222
# AUPR+AUROC: 1.3290626863178205
# -----------
# Mean AUPRperdrug: 0.4748259448496606, std: 0.031909068160640014
# Mean AUROCperdrug: 0.8873938170473357, std: 0.005370142626986226
# Mean AUPR+AUROCperdrug: 1.362219761896996, std: 0.03693042500658738
# Mean AUPR: 0.42115079601580074, std: 0.03492475976577156
# Mean AUROC: 0.8611602889940887, std: 0.01012956868649187
# Mean AUPR+AUROC: 1.2823110850098893, std: 0.04388411544883358
# -----------
# using feature pathway
# with APPFC
# The KRR requires hyperparameter lambda, sigma_X
# ---------- nested cv start ----------
# Fold: 0
# number of hyperpars combination:  25
# first few training idx:  [ 0  2  4  7  9 10 11 12 16 17]
# first few testing idx:  [ 142  212  239  421  476  926 1006 1017 1211 1228]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0)
# AUPR: 0.43932290321794154
# AUPR for each fold: [0.439078   0.45493137 0.44794459 0.41533765]
# --- tuning end ---
# target size: 106
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.47204818560886885
# AUROCperdrug: 0.8996483774474208
# AUPR+AUROCperdrug: 1.3716965630562896
# AUPR: 0.4171863928288315
# AUROC: 0.8735395527629901
# AUPR+AUROC: 1.2907259455918216
# -----------
# Fold: 1
# number of hyperpars combination:  25
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [ 242  315  495  545  711  984 1003 1049 1144 1221]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0)
# AUPR: 0.4302185900877408
# AUPR for each fold: [0.42468922 0.42982304 0.42279697 0.44356513]
# --- tuning end ---
# target size: 106
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.4948657935114486
# AUROCperdrug: 0.9084311172067467
# AUPR+AUROCperdrug: 1.4032969107181954
# AUPR: 0.4582768759607776
# AUROC: 0.8817138679887645
# AUPR+AUROC: 1.3399907439495422
# -----------
# Fold: 2
# number of hyperpars combination:  25
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [  72  154  171  307  395  511  524  755 1080 1091]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0)
# AUPR: 0.4322277559343236
# AUPR for each fold: [0.42924832 0.42048857 0.42000332 0.45917081]
# --- tuning end ---
# target size: 106
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.48952850232955686
# AUROCperdrug: 0.8997898022012396
# AUPR+AUROCperdrug: 1.3893183045307964
# AUPR: 0.44579270200939064
# AUROC: 0.8715256144590565
# AUPR+AUROC: 1.3173183164684472
# -----------
# Fold: 3
# number of hyperpars combination:  25
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [  92  267  286  543  559  598  651  654 1059 1094]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0)
# AUPR: 0.43778725729825313
# AUPR for each fold: [0.41748075 0.45166588 0.43292347 0.44907893]
# --- tuning end ---
# target size: 106
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.4873943634728651
# AUROCperdrug: 0.9026482392502901
# AUPR+AUROCperdrug: 1.3900426027231552
# AUPR: 0.4354575686904448
# AUROC: 0.8714460957419985
# AUPR+AUROC: 1.3069036644324432
# -----------
# Fold: 4
# number of hyperpars combination:  25
# first few training idx:  [ 0  2  4  7  9 10 11 12 13 16]
# first few testing idx:  [  80  289  416  526  685  834  972 1029 1102 1261]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.01, 10.0)
# AUPR: 0.4348088632981765
# AUPR for each fold: [0.41515661 0.46105203 0.42688656 0.43614026]
# --- tuning end ---
# target size: 106
# ------ best hyper pars:  (0.01, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.4997813956962043
# AUROCperdrug: 0.8823801653057602
# AUPR+AUROCperdrug: 1.3821615610019644
# AUPR: 0.4730264064320772
# AUROC: 0.8637144654596262
# AUPR+AUROC: 1.3367408718917033
# -----------
# Mean AUPRperdrug: 0.48872364812378866, std: 0.009386006279569977
# Mean AUROCperdrug: 0.8985795402822916, std: 0.008702123598512454
# Mean AUPR+AUROCperdrug: 1.38730318840608, std: 0.010366940960237197
# Mean AUPR: 0.4459479891843043, std: 0.01909211665034241
# Mean AUROC: 0.872387919282487, std: 0.00574732949034182
# Mean AUPR+AUROC: 1.3183359084667916, std: 0.01844839464858957
# -----------
# using feature indication
# with APPFC
# The KRR requires hyperparameter lambda, sigma_X
# ---------- nested cv start ----------
# Fold: 0
# number of hyperpars combination:  25
# first few training idx:  [ 0  2  4  7 10 11 12 13 16 17]
# first few testing idx:  [  74  231  339  343  374  412  752  811  823 1329]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0)
# AUPR: 0.4495991820446619
# AUPR for each fold: [0.42687945 0.44266629 0.45456989 0.47428111]
# --- tuning end ---
# target size: 193
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.46927209853599866
# AUROCperdrug: 0.8892177064324557
# AUPR+AUROCperdrug: 1.3584898049684544
# AUPR: 0.45291389112914876
# AUROC: 0.8673650536819582
# AUPR+AUROC: 1.320278944811107
# -----------
# Fold: 1
# number of hyperpars combination:  25
# first few training idx:  [ 0  2  9 10 11 12 16 17 18 19]
# first few testing idx:  [  85  361  455  534  543  588  770  839 1243 1247]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0)
# AUPR: 0.44027154104579885
# AUPR for each fold: [0.42815088 0.47993653 0.39999799 0.45300076]
# --- tuning end ---
# target size: 193
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.45974539183962815
# AUROCperdrug: 0.893927738012811
# AUPR+AUROCperdrug: 1.3536731298524391
# AUPR: 0.46816829861867176
# AUROC: 0.8803007263148432
# AUPR+AUROC: 1.348469024933515
# -----------
# Fold: 2
# number of hyperpars combination:  25
# first few training idx:  [ 2  4  7  9 10 11 13 17 18 19]
# first few testing idx:  [ 114  243  391  449  758  759  877  992 1040 1186]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0)
# AUPR: 0.44583189446421445
# AUPR for each fold: [0.44740797 0.4541666  0.43761461 0.4441384 ]
# --- tuning end ---
# target size: 193
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.46601509653266293
# AUROCperdrug: 0.895528056948414
# AUPR+AUROCperdrug: 1.361543153481077
# AUPR: 0.4511668927451304
# AUROC: 0.8713205705416773
# AUPR+AUROC: 1.3224874632868078
# -----------
# Fold: 3
# number of hyperpars combination:  25
# first few training idx:  [ 0  2  4  7  9 11 12 13 16 17]
# first few testing idx:  [  19   87  512  638  694  943 1098 1137 1249 1284]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0)
# AUPR: 0.4397152862291462
# AUPR for each fold: [0.4225506  0.43622754 0.44878384 0.45129916]
# --- tuning end ---
# target size: 193
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.4731456963990185
# AUROCperdrug: 0.8950079298001431
# AUPR+AUROCperdrug: 1.3681536261991616
# AUPR: 0.4688530319106194
# AUROC: 0.8754949324528754
# AUPR+AUROC: 1.3443479643634948
# -----------
# Fold: 4
# number of hyperpars combination:  25
# first few training idx:  [ 0  4  7  9 10 12 13 16 18 19]
# first few testing idx:  [  22   70  161  218  381  883  956 1085 1110 1281]
# Inner Fold: 0
# Inner Fold: 1
# Inner Fold: 2
# Inner Fold: 3
# best hyperpar: (0.1, 10.0)
# AUPR: 0.4484561141429735
# AUPR for each fold: [0.42544269 0.44602158 0.4704072  0.45195298]
# --- tuning end ---
# target size: 193
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.4622394868847275
# AUROCperdrug: 0.89564162055084
# AUPR+AUROCperdrug: 1.3578811074355674
# AUPR: 0.45948424748982386
# AUROC: 0.8753529236149493
# AUPR+AUROC: 1.3348371711047733
# -----------
# Mean AUPRperdrug: 0.4660835540384071, std: 0.0047957170372069455
# Mean AUROCperdrug: 0.8938646103489327, std: 0.002401237194674468
# Mean AUPR+AUROCperdrug: 1.35994816438734, std: 0.004809348995552808
# Mean AUPR: 0.4601172723786789, std: 0.007396367157430397
# Mean AUROC: 0.8739668413212607, std: 0.0043579980453564045
# Mean AUPR+AUROC: 1.3340841136999395, std: 0.011295170525053284
# -----------
# using feature target
# with APPFC
# The KRR requires hyperparameter lambda, sigma_X
# ---------- cv start ----------
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# best hyperpar: (0.1, 10.0)
# AUPR: 0.41163631535132206
# AUPR for each fold: [0.40751648 0.405672   0.40177648 0.44016308 0.40305352]
# --- tuning end ---
# target size: 227
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.4766081384470573
# AUROCperdrug: 0.9005922591718531
# AUPR+AUROCperdrug: 1.3772003976189104
# AUPR: 0.42293984787113187
# AUROC: 0.8725340838617601
# AUPR+AUROC: 1.295473931732892
# -----------
# using feature enzyme
# with APPFC
# The KRR requires hyperparameter lambda, sigma_X
# ---------- cv start ----------
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# best hyperpar: (10.0, 10.0)
# AUPR: 0.3957510148647961
# AUPR for each fold: [0.40798309 0.41698536 0.35728731 0.41242617 0.38407314]
# --- tuning end ---
# target size: 175
# ------ best hyper pars:  (10.0, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.4776276723239896
# AUROCperdrug: 0.8837556871046802
# AUPR+AUROCperdrug: 1.36138335942867
# AUPR: 0.42783489912102945
# AUROC: 0.8625376642092629
# AUPR+AUROC: 1.2903725633302923
# -----------
# using feature Chem
# with APPFC
# The KRR requires hyperparameter lambda, sigma_X
# ---------- cv start ----------
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# best hyperpar: (10.0, 10.0)
# AUPR: 0.4033178834061837
# AUPR for each fold: [0.39969749 0.43626195 0.40818405 0.38694399 0.38550194]
# --- tuning end ---
# target size: 212
# ------ best hyper pars:  (10.0, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.47537040447864287
# AUROCperdrug: 0.8954094710198075
# AUPR+AUROCperdrug: 1.3707798754984504
# AUPR: 0.41075951438451325
# AUROC: 0.8685540907227111
# AUPR+AUROC: 1.2793136051072242
# -----------
# using feature DGI
# with APPFC
# The KRR requires hyperparameter lambda, sigma_X
# ---------- cv start ----------
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# best hyperpar: (0.1, 10.0)
# AUPR: 0.42282282002985483
# AUPR for each fold: [0.41522919 0.40467118 0.43596758 0.41818002 0.44006614]
# --- tuning end ---
# target size: 241
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.47735981335835015
# AUROCperdrug: 0.888758919620915
# AUPR+AUROCperdrug: 1.3661187329792652
# AUPR: 0.4525015044973767
# AUROC: 0.8616615847967742
# AUPR+AUROC: 1.314163089294151
# -----------
# using feature transporter
# with APPFC
# The KRR requires hyperparameter lambda, sigma_X
# ---------- cv start ----------
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# best hyperpar: (1.0, 10.0)
# AUPR: 0.42115079601580074
# AUPR for each fold: [0.38675193 0.46861364 0.40829982 0.38570649 0.4563821 ]
# --- tuning end ---
# target size: 110
# ------ best hyper pars:  (1.0, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.508010543755042
# AUROCperdrug: 0.8845186153355369
# AUPR+AUROCperdrug: 1.3925291590905788
# AUPR: 0.4544422255193068
# AUROC: 0.8637680982491738
# AUPR+AUROC: 1.3182103237684806
# -----------
# using feature pathway
# with APPFC
# The KRR requires hyperparameter lambda, sigma_X
# ---------- cv start ----------
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# best hyperpar: (0.01, 10.0)
# AUPR: 0.4464652014524876
# AUPR for each fold: [0.42456719 0.45543093 0.4453965  0.43390498 0.47302641]
# --- tuning end ---
# target size: 180
# ------ best hyper pars:  (0.01, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.5080676465461638
# AUROCperdrug: 0.8866600010906857
# AUPR+AUROCperdrug: 1.3947276476368495
# AUPR: 0.44885547984510576
# AUROC: 0.8591952474856493
# AUPR+AUROC: 1.3080507273307551
# -----------
# using feature indication
# with APPFC
# The KRR requires hyperparameter lambda, sigma_X
# ---------- cv start ----------
# Fold: 0
# Fold: 1
# Fold: 2
# Fold: 3
# Fold: 4
# best hyperpar: (0.1, 10.0)
# AUPR: 0.4601172723786789
# AUPR for each fold: [0.45291389 0.4681683  0.45116689 0.46885303 0.45948425]
# --- tuning end ---
# target size: 315
# ------ best hyper pars:  (0.1, 10.0) ------
# KRR starts:
# KRR ends:
# -----------
# AUPRperdrug: 0.4827925248440804
# AUROCperdrug: 0.8958651914411796
# AUPR+AUROCperdrug: 1.37865771628526
# AUPR: 0.48119144173341233
# AUROC: 0.874497326187182
# AUPR+AUROC: 1.3556887679205945
# -----------
#                        score
# metric                 AUROC      AUPR AUROCperdrug AUPRperdrug
# feature     method
# pathway     APPFC   0.859195  0.448855     0.886660    0.508068
# Chem        APPFC   0.868554  0.410760     0.895409    0.475370
# DGI         APPFC   0.861662  0.452502     0.888759    0.477360
# indication  APPFC   0.874497  0.481191     0.895865    0.482793
# target      APPFC   0.872534  0.422940     0.900592    0.476608
# transporter APPFC   0.863768  0.454442     0.884519    0.508011
# enzyme      APPFC   0.862538  0.427835     0.883756    0.477628

# %%
df = pd.DataFrame()
for m, fs in results["nested_cv"]["KRR"].items():
    for f, mes in fs.items():
        for me, scores in mes.items():
            temp_df = pd.DataFrame({
                'method': m,
                'feature': f,
                'metric': me,
                "score": scores
            })
            df = pd.concat([df, temp_df], ignore_index=True)

custom_order = ["pathway","Chem", "DGI", "indication", "target", "transporter", "enzyme"]
metrice_names = ["AUROC", "AUPR", "AUROCperdrug", "AUPRperdrug"]
# APPFC = ["APPFC", "noAPPFC"]
df['feature'] = pd.Categorical(df['feature'], categories=custom_order, ordered=True)
# df['method'] = pd.Categorical(df['method'], categories=APPFC, ordered=True)
df['metric'] = pd.Categorical(df['metric'], categories=metrice_names, ordered=True)
df2 = pd.pivot_table(df, values=['score'], index=["feature", "method"], aggfunc={'score': ["mean","std"]}, columns=["metric"])
df3 = df2.sort_index(axis=1, level='metric').sort_index(level='feature')
df3.to_excel(f'results/nested_cv_results_{SEs_name}_{method}_KNN.xlsx')
df3
# Out:
#                        score                                             \
#                         mean       std      mean       std         mean
# metric                 AUROC     AUROC      AUPR      AUPR AUROCperdrug
# feature     method
# pathway     APPFC   0.872388  0.006426  0.445948  0.021346     0.898580
# Chem        APPFC   0.870415  0.009664  0.403318  0.020662     0.895801
# DGI         APPFC   0.858797  0.009585  0.422823  0.014822     0.886634
# indication  APPFC   0.873967  0.004872  0.460117  0.008269     0.893865
# target      APPFC   0.872169  0.002437  0.411636  0.016103     0.899469
# transporter APPFC   0.861160  0.011325  0.421151  0.039047     0.887394
# enzyme      APPFC   0.867538  0.007447  0.395751  0.024972     0.886769
#
#
#                             std        mean         std
# metric             AUROCperdrug AUPRperdrug AUPRperdrug
# feature     method
# pathway     APPFC      0.009729    0.488724    0.010494
# Chem        APPFC      0.003893    0.460617    0.018756
# DGI         APPFC      0.004702    0.459339    0.006790
# indication  APPFC      0.002685    0.466084    0.005362
# target      APPFC      0.003183    0.465182    0.018213
# transporter APPFC      0.006004    0.474826    0.035675
# enzyme      APPFC      0.001036    0.441539    0.013220

# %%
df = pd.DataFrame()
for m, fs in results["cv"]["KRR"].items():
    for f, mes in fs.items():
        for me, scores in mes.items():
            temp_df = pd.DataFrame({
                'method': m,
                'feature': f,
                'metric': me,
                "score": scores
            },index=["1"])
            df = pd.concat([df, temp_df], ignore_index=True)
df['feature'] = pd.Categorical(df['feature'], categories=custom_order, ordered=True)
# df['method'] = pd.Categorical(df['method'], categories=APPFC, ordered=True)
df['metric'] = pd.Categorical(df['metric'], categories=metrice_names, ordered=True)
df2 = pd.pivot_table(df, values=['score'], index=["feature", "method"], columns="metric")
df2.to_excel(f'results/cv_results_{SEs_name}_{method}_KNN.xlsx')
df2
# Out:
#                        score
# metric                 AUROC      AUPR AUROCperdrug AUPRperdrug
# feature     method
# pathway     APPFC   0.859195  0.448855     0.886660    0.508068
# Chem        APPFC   0.868554  0.410760     0.895409    0.475370
# DGI         APPFC   0.861662  0.452502     0.888759    0.477360
# indication  APPFC   0.874497  0.481191     0.895865    0.482793
# target      APPFC   0.872534  0.422940     0.900592    0.476608
# transporter APPFC   0.863768  0.454442     0.884519    0.508011
# enzyme      APPFC   0.862538  0.427835     0.883756    0.477628

# %%
# with open(f'results/hyperpars_{SEs_name}.xml', 'w') as xml_file:
#    json.dump(hyperparsOut, xml_file, cls=NpEncoder)
# with open(f'results/results_{SEs_name}.xml', 'w') as xml_file:
#    json.dump(results, xml_file)

# %%
results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-100f62972f2f> in <module>
# ----> 1 results
#
# NameError: name 'results' is not defined
